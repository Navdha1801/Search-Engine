# %%
import os
import json
import pandas as pd

# List of folders containing JSON files
folders = [
    "./dataset/Crime, Law and Justice_negative_20240526070023",
    "./dataset/Crime, Law and Justice_negative_20240714070027",
    "./dataset/Crime, Law and Justice_negative_20250511073514",
    "./dataset/Crime, Law and Justice_positive_20240128131953",
    "./dataset/Disaster and Accident_negative_20240128131143",
    "./dataset/Disaster and Accident_positive_20240721070030",
    "./dataset/Economy, Business and Finance_negative_20250622073519",
    "./dataset/Education_positive_20250105070106",
    "./dataset/Environment_negative_20250608073516",
    "./dataset/Health_positive_20240505070030",
    # add more folder paths here
]

# List to store all texts
all_texts = []

for folder_path in folders:
    # Loop through all JSON files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".json"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
                # Assuming each JSON file has a 'text' field
                all_texts.append(data['text'])

# Convert to DataFrame
df = pd.DataFrame({'text': all_texts})

print("Dataset size:", len(df))
df.head(3)
# Out:
# Dataset size: 10000
#                                                 text
# 0  COATZACOALCOS, VER. - Tras un operativo implem...
# 1  The corruption scandal in the Russian Ministry...
# 2  BOISE, Idaho — Idaho Attorney General Raúl Lab...

# %%
import re
import pandas as pd
from tqdm import tqdm
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# Download NLTK data (first run only)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

def preprocess_text(text):
    # 1. Lowercase
    text = text.lower()
    # 2. Remove punctuation & special characters
    text = re.sub(r'[^a-z\s]', '', text)
    # 3. Tokenize
    tokens = word_tokenize(text)
    # 4. Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    # 5. Apply stemming
    tokens = [stemmer.stem(word) for word in tokens]
    return ' '.join(tokens)

# Apply to a manageable subset first
subset = df.head(10000).copy()

tqdm.pandas()
subset['clean_text'] = subset['text'].progress_apply(preprocess_text)

subset.to_csv("cleaned_news.csv", index=False)
print("✅ Preprocessing done safely.")
# Out:
# [nltk_data] Downloading package punkt to /home/navdha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/navdha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/navdha/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 100%|██████████| 10000/10000 [00:34<00:00, 290.38it/s]
# ✅ Preprocessing done safely.

# %%
# es_bulk_index.py
from elasticsearch import Elasticsearch, helpers
import pandas as pd
import time

# connect (fill your password)
es = Elasticsearch(
    hosts=["https://localhost:9200"],
    basic_auth=("elastic", "oHRdNMmqOk4t+KO9cbIi"),
    verify_certs=False
)
INDEX_NAME = "esindex-v1.0"

# Create index with simple mapping if doesn't exist
if es.indices.exists(index=INDEX_NAME):
    print("Index exists — deleting and recreating for a clean baseline.")
    es.indices.delete(index=INDEX_NAME)
mapping = {
  "mappings": {
    "properties": {
      "text": {"type": "text"}
    }
  }
}
es.indices.create(index=INDEX_NAME, body=mapping)

def bulk_index_chunked(df, index_name, chunk_size=500):
    total = len(df)
    for start in range(0, total, chunk_size):
        chunk = df.iloc[start:start+chunk_size]
        actions = [
            {"_index": index_name, "_id": int(idx), "_source": {"text": txt}}
            for idx, txt in zip(chunk.index, chunk['clean_text'])
        ]
        t0 = time.time()
        helpers.bulk(es, actions)
        print(f"Indexed docs {start}..{min(start+chunk_size-1,total-1)} in {time.time()-t0:.2f}s")

# Use only subset if you want (safer): e.g., subset = df.head(5000)
bulk_index_chunked(subset, INDEX_NAME, chunk_size=500)
# Out:
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/elasticsearch/_sync/client/__init__.py:400: SecurityWarning: Connecting to 'https://localhost:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Index exists — deleting and recreating for a clean baseline.
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 0..499 in 0.50s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 500..999 in 0.47s
# Indexed docs 1000..1499 in 0.20s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 1500..1999 in 0.18s
# Indexed docs 2000..2499 in 0.11s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 2500..2999 in 0.13s
# Indexed docs 3000..3499 in 0.14s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 3500..3999 in 0.15s
# Indexed docs 4000..4499 in 0.14s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 4500..4999 in 0.15s
# Indexed docs 5000..5499 in 0.15s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 5500..5999 in 0.13s
# Indexed docs 6000..6499 in 0.05s
# Indexed docs 6500..6999 in 0.06s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 7000..7499 in 0.14s
# Indexed docs 7500..7999 in 0.14s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 8000..8499 in 0.11s
# Indexed docs 8500..8999 in 0.09s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Indexed docs 9000..9499 in 0.13s
# Indexed docs 9500..9999 in 0.13s
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import time
import numpy as np
from tqdm import tqdm
import psutil
import os
import gc
import matplotlib.pyplot as plt
import pandas as pd
import threading
import subprocess

# --- Boolean Query Parser ---
def parse_boolean_query(query):
    query = query.strip()
    if query.startswith("(") and query.endswith(")"):
        return parse_boolean_query(query[1:-1].strip())
    if query.upper().startswith("NOT "):
        inner = parse_boolean_query(query[4:].strip())
        return {"bool": {"must_not": [inner]}}
    # Split by OR
    parts, depth, last, i = [], 0, 0, 0
    while i < len(query):
        if query[i] == "(": depth += 1
        elif query[i] == ")": depth -= 1
        elif depth == 0 and query[i:i+3].upper() == "OR ":
            parts.append(query[last:i].strip())
            last = i + 3
            i += 2
        i += 1
    if parts:
        parts.append(query[last:].strip())
        return {"bool": {"should": [parse_boolean_query(p) for p in parts], "minimum_should_match": 1}}
    # Split by AND
    parts, depth, last, i = [], 0, 0, 0
    while i < len(query):
        if query[i] == "(": depth += 1
        elif query[i] == ")": depth -= 1
        elif depth == 0 and query[i:i+4].upper() == "AND ":
            parts.append(query[last:i].strip())
            last = i + 4
            i += 3
        i += 1
    if parts:
        parts.append(query[last:].strip())
        return {"bool": {"must": [parse_boolean_query(p) for p in parts]}}
    # TERM or PHRASE
    query = query.strip('"')
    return {"match_phrase": {"text": query}} if " " in query else {"match": {"text": query}}

# --- Helper to find Elasticsearch process ---
def get_es_process():
    # First try finding process by name
    es_processes = []
    for p in psutil.process_iter(['pid', 'name', 'memory_info']):
        try:
            if 'java' in p.info['name'].lower():
                # Check command line for Elasticsearch
                if 'elasticsearch' in ' '.join(p.cmdline()).lower():
                    es_processes.append(p)
        except (psutil.NoSuchProcess, psutil.AccessDenied):
            continue
    if not es_processes:
        return None
    # Return the process using the maximum memory
    return max(es_processes, key=lambda x: x.memory_info().rss)

# --- Memory monitor thread ---
def monitor_memory(stop_event, log_path, interval=0.5):
    process_client = psutil.Process(os.getpid())
    process_es = get_es_process()
    records = []
    while not stop_event.is_set():
        client_mem = process_client.memory_info().rss / (1024 * 1024)
        es_mem = process_es.memory_info().rss / (1024 * 1024) if process_es else np.nan
        records.append((time.time(), client_mem, es_mem))
        time.sleep(interval)
    pd.DataFrame(records, columns=["timestamp", "client_MB", "elasticsearch_MB"]).to_csv(log_path, index=False)

# --- Measure metrics ---
def measure_metrics(es, index_name, queries, size=10):
    latencies, results = [], []
    gc.collect()
    stop_event = threading.Event()
    log_path = "memory_usage_log.csv"
    monitor_thread = threading.Thread(target=monitor_memory, args=(stop_event, log_path))
    monitor_thread.start()

    process = psutil.Process(os.getpid())
    start_mem = process.memory_info().rss / (1024 * 1024)

    # Warmup
    for q in queries[:3]:
        es.search(index=index_name, body={"query": parse_boolean_query(q)}, size=1)

    start_time = time.time()
    for q in tqdm(queries, desc="Running queries"):
        es_query = parse_boolean_query(q)
        t0 = time.time()
        res = es.search(index=index_name, body={"query": es_query}, size=size)
        latencies.append(time.time() - t0)
        results.append(res)
    total_time = time.time() - start_time

    gc.collect()
    end_mem = process.memory_info().rss / (1024 * 1024)
    stop_event.set()
    monitor_thread.join()

    mem_usage = max(0, end_mem - start_mem)
    throughput = len(queries) / total_time
    return np.array(latencies), throughput, mem_usage, results, log_path

# --- Load queries ---
queries = [line.strip() for line in open("queries.txt") if line.strip()]

# --- Run metrics ---
latencies, throughput, mem_usage, results, log_path = measure_metrics(es, INDEX_NAME, queries)

# --- Print summary ---
print("\n=== PERFORMANCE SUMMARY ===")
print("Latency percentiles (seconds): p50, p95, p99:", np.percentile(latencies, [50, 95, 99]))
print(f"Throughput (queries/sec): {throughput:.2f}")

mem_df = pd.read_csv(log_path)
print(f"Client Memory (MB): Min={mem_df['client_MB'].min():.2f}, Max={mem_df['client_MB'].max():.2f}, Mean={mem_df['client_MB'].mean():.2f}")
if mem_df['elasticsearch_MB'].notna().any():
    print(f"Elasticsearch Memory (MB): Min={mem_df['elasticsearch_MB'].min():.2f}, Max={mem_df['elasticsearch_MB'].max():.2f}, Mean={mem_df['elasticsearch_MB'].mean():.2f}")
else:
    print("Elasticsearch process not found — skipping server memory.")

print(f"Memory footprint increase (Client): {mem_usage:.2f} MB")
print("✅ Metrics saved to es_metrics.csv")
print("✅ Memory usage logged to memory_usage_log.csv")

# --- Save metrics ---
pd.DataFrame({"query": queries, "latency_sec": latencies}).to_csv("es_metrics.csv", index=False)

# --- Plot latency histogram ---
plt.figure(figsize=(10,5))
plt.hist(latencies, bins=25, color='skyblue', edgecolor='black')
plt.title("Query Latency Distribution")
plt.xlabel("Latency (seconds)")
plt.ylabel("Number of Queries")
plt.axvline(np.percentile(latencies, 50), color='red', linestyle='--', label='p50')
plt.axvline(np.percentile(latencies, 95), color='green', linestyle='--', label='p95')
plt.axvline(np.percentile(latencies, 99), color='orange', linestyle='--', label='p99')
plt.legend()
plt.show()

# --- Plot memory usage ---
plt.figure(figsize=(10,5))
plt.plot(mem_df["timestamp"] - mem_df["timestamp"].min(), mem_df["client_MB"], label="Client Memory (MB)", color="blue")
if mem_df["elasticsearch_MB"].notna().any():
    plt.plot(mem_df["timestamp"] - mem_df["timestamp"].min(), mem_df["elasticsearch_MB"], label="Elasticsearch Memory (MB)", color="orange")
plt.title("Live Memory Usage (Client + Elasticsearch)")
plt.xlabel("Time (seconds)")
plt.ylabel("Memory (MB)")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_7389/1400469601.py:93: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   es.search(index=index_name, body={"query": parse_boolean_query(q)}, size=1)
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:   0%|          | 0/227 [00:00<?, ?it/s]/tmp/ipykernel_7389/1400469601.py:99: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   res = es.search(index=index_name, body={"query": es_query}, size=size)
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:   2%|▏         | 5/227 [00:00<00:04, 46.38it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:   4%|▍         | 10/227 [00:00<00:04, 44.62it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:   7%|▋         | 16/227 [00:00<00:04, 47.95it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  10%|▉         | 22/227 [00:00<00:03, 52.17it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  12%|█▏        | 28/227 [00:00<00:04, 49.73it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  15%|█▌        | 35/227 [00:00<00:03, 54.44it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  18%|█▊        | 41/227 [00:00<00:03, 55.85it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  21%|██        | 47/227 [00:00<00:03, 55.81it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  24%|██▍       | 54/227 [00:00<00:02, 58.75it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  26%|██▋       | 60/227 [00:01<00:02, 58.30it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  30%|██▉       | 67/227 [00:01<00:02, 60.16it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  33%|███▎      | 74/227 [00:01<00:02, 59.39it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  36%|███▌      | 81/227 [00:01<00:02, 61.55it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  39%|███▉      | 88/227 [00:01<00:02, 62.27it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  42%|████▏     | 95/227 [00:01<00:02, 54.77it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  45%|████▍     | 102/227 [00:01<00:02, 58.27it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  48%|████▊     | 109/227 [00:01<00:02, 58.64it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  51%|█████     | 115/227 [00:02<00:01, 58.39it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  54%|█████▎    | 122/227 [00:02<00:01, 61.39it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  57%|█████▋    | 129/227 [00:02<00:01, 62.97it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  82%|████████▏ | 187/227 [00:03<00:00, 57.08it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  85%|████████▌ | 194/227 [00:03<00:00, 59.87it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  89%|████████▉ | 202/227 [00:03<00:00, 63.19it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  92%|█████████▏| 209/227 [00:03<00:00, 62.27it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  95%|█████████▌| 216/227 [00:03<00:00, 59.76it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries:  98%|█████████▊| 223/227 [00:03<00:00, 57.40it/s]/home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/navdha/PycharmProjects/pythonProject/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Running queries: 100%|██████████| 227/227 [00:03<00:00, 57.50it/s]
# === PERFORMANCE SUMMARY ===
# Latency percentiles (seconds): p50, p95, p99: [0.01646519 0.02474604 0.03210959]
# Throughput (queries/sec): 57.47
# Client Memory (MB): Min=326.11, Max=327.48, Mean=326.99
# Elasticsearch Memory (MB): Min=945.13, Max=967.38, Mean=962.17
# Memory footprint increase (Client): 2.38 MB
# ✅ Metrics saved to es_metrics.csv
# ✅ Memory usage logged to memory_usage_log.csv

# %%
VERSION_CONFIG = {
    "v1.x1.y1.z1.i0.qT0": {
        "info": "BOOLEAN", "dstore": "CUSTOM", "compr": "NONE", "optim": "Null", "qproc": "TERMatat"
    },
    "v1.x1.y2.z1.i0.qT0": {
        "info": "BOOLEAN", "dstore": "DB1", "compr": "NONE", "optim": "Null", "qproc": "TERMatat"
    },
    "v1.x1.y3.z1.i0.qT0": {
        "info": "BOOLEAN", "dstore": "DB2", "compr": "NONE", "optim": "Null", "qproc": "TERMatat"
    },
    # Add all other combinations as needed
}

# %%
# selfindex_impl.py
# Drop into a notebook cell or a .py file and run/import it.

import sqlite3
import json
import pickle
import math
import shutil
from collections import defaultdict
from typing import Iterable, List, Tuple, Dict, Set
from pathlib import Path
import zlib
import lzma

# reuse the Enum classes from your boilerplate or redefine minimal ones here
from enum import Enum
class IndexInfo(Enum):
    BOOLEAN = 1
    WORDCOUNT = 2
    TFIDF = 3
class DataStore(Enum):
    CUSTOM = 1
    DB1 = 2
    DB2 = 3
class Compression(Enum):
    NONE = 1
    CODE = 2
    CLIB = 3
class QueryProc(Enum):
    TERMatat = 'T'   # Term-at-a-time
    DOCatat = 'D'    # Doc-at-a-time
class Optimizations(Enum):
    Null = '0'
    Skipping = 'sp'
    Thresholding = 'th'
    EarlyStopping = 'es'

# Simple boolean query parser -> AST similar to our previous parse_boolean_query but adapted
def parse_boolean_query_to_ast(query: str):
    """Parse a query string into a simple AST:
       - {"match": "word"} for single term
       - {"match_phrase": "a b"} for phrase
       - {"bool": {"must": [expr,...]}} OR {"bool":{"should":[...]}} OR {"bool":{"must_not":[...]}}
    """
    q = query.strip()
    # strip outer parentheses
    if q.startswith("(") and q.endswith(")"):
        # check balanced parentheses inside before trimming aggressively
        depth = 0
        balanced = True
        for i, ch in enumerate(q):
            if ch == "(":
                depth += 1
            elif ch == ")":
                depth -= 1
                if depth == 0 and i != len(q)-1:
                    balanced = False
                    break
        if balanced:
            return parse_boolean_query_to_ast(q[1:-1].strip())

    # NOT at top
    if q.upper().startswith("NOT "):
        inner = parse_boolean_query_to_ast(q[4:].strip())
        return {"bool": {"must_not": [inner]}}

    # top-level OR split
    parts = []
    depth = 0
    last = 0
    i = 0
    while i < len(q):
        if q[i] == "(":
            depth += 1
        elif q[i] == ")":
            depth -= 1
        elif depth == 0 and q[i:i+3].upper() == "OR ":
            parts.append(q[last:i].strip())
            last = i + 3
            i += 2
        i += 1
    if parts:
        parts.append(q[last:].strip())
        return {"bool": {"should": [parse_boolean_query_to_ast(p) for p in parts], "minimum_should_match": 1}}

    # top-level AND split
    parts = []
    depth = 0
    last = 0
    i = 0
    while i < len(q):
        if q[i] == "(":
            depth += 1
        elif q[i] == ")":
            depth -= 1
        elif depth == 0 and q[i:i+4].upper() == "AND ":
            parts.append(q[last:i].strip())
            last = i + 4
            i += 3
        i += 1
    if parts:
        parts.append(q[last:].strip())
        return {"bool": {"must": [parse_boolean_query_to_ast(p) for p in parts]}}

    # TERM or PHRASE
    if q.startswith('"') and q.endswith('"'):
        phrase = q.strip('"')
        return {"match_phrase": phrase}
    # treat if contains spaces but no quotes as phrase too
    if " " in q:
        return {"match_phrase": q}
    return {"match": q}


class SelfIndex:
    """
    Simple SelfIndex implementation (pickled storage).
    Supports index variants: BOOLEAN / WORDCOUNT / TFIDF
    Query processors: TERMatat, DOCatat
    Persistence: folder per index_id under base_dir
    """
    base_dir = Path("./selfindex_store")
    
    def __init__(self, version: str = None):
    # default placeholders if version not given
     self.core = "SelfIndex"
     if version and version in VERSION_CONFIG:
        cfg = VERSION_CONFIG[version]
        self.info = IndexInfo[cfg["info"]]
        self.dstore = DataStore[cfg["dstore"]]
        self.compr = Compression[cfg["compr"]]
        self.optim = Optimizations[cfg["optim"]]
        self.qproc = QueryProc[cfg["qproc"]]
     else:
        # defaults
        self.info = IndexInfo.BOOLEAN
        self.dstore = DataStore.CUSTOM
        self.compr = Compression.NONE
        self.optim = Optimizations.Null
        self.qproc = QueryProc.TERMatat

    # runtime structures
     self.postings: Dict[str, List[Tuple[int,int,List[int]]]] = {}
     self.doc_len: Dict[int,int] = {}
     self.df: Dict[str,int] = {}
     self.N: int = 0
     self.index_id: str = None
     self.index_path: Path = None
     self.doc_ids_indexed: List[int] = []

     SelfIndex.base_dir.mkdir(parents=True, exist_ok=True)
     self.stemmer = PorterStemmer()

    # ------------------------
    # Persistence helpers
    # ------------------------
        # ------------------------
    # Compression utilities
    # ------------------------
    def _compress_postings(self, postings: Dict) -> bytes:
        """Compress postings dictionary according to chosen compression method."""
        data = pickle.dumps(postings, protocol=pickle.HIGHEST_PROTOCOL)
        if self.compr == Compression.NONE:
            return data
        elif self.compr == Compression.CODE:
            # Simple compression with zlib
            return zlib.compress(data, level=9)
        elif self.compr == Compression.CLIB:
            # Stronger compression using lzma (off-the-shelf library)
            return lzma.compress(data)
        else:
            raise ValueError(f"Unknown compression type: {self.compr}")

    def _decompress_postings(self, data: bytes) -> Dict:
        """Decompress postings according to chosen compression method."""
        if self.compr == Compression.NONE:
            raw = data
        elif self.compr == Compression.CODE:
            raw = zlib.decompress(data)
        elif self.compr == Compression.CLIB:
            raw = lzma.decompress(data)
        else:
            raise ValueError(f"Unknown compression type: {self.compr}")
        return pickle.loads(raw)

# ------------------ DB1: SQLite ------------------
    def _save_postings_db1(self, postings, folder):
     db_path = Path(folder) / "postings.db"
     if db_path.exists():
        db_path.unlink()
     conn = sqlite3.connect(db_path)
     cur = conn.cursor()
     cur.execute("CREATE TABLE postings(term TEXT PRIMARY KEY, data BLOB)")

     for term, plist in postings.items():
        # compress per-term if needed
        data = pickle.dumps(plist, protocol=pickle.HIGHEST_PROTOCOL)
        if self.compr == Compression.CODE:
            data = zlib.compress(data)
        elif self.compr == Compression.CLIB:
            data = lzma.compress(data)
        # store in DB
        cur.execute("INSERT INTO postings VALUES(?, ?)", (term, data))

     conn.commit()
     conn.close()

    def _load_postings_db1(self, folder):
     db_path = Path(folder) / "postings.db"
     conn = sqlite3.connect(db_path)
     cur = conn.cursor()
     postings = {}

     for term, blob in cur.execute("SELECT term, data FROM postings"):
        if self.compr == Compression.CODE:
            blob = zlib.decompress(blob)
        elif self.compr == Compression.CLIB:
            blob = lzma.decompress(blob)
        plist = pickle.loads(blob)
        postings[term] = plist

     conn.close()
     return postings

# ------------------ DB2: JSON-lines ------------------
    def _save_postings_db2(self, postings, folder):
     file_path = Path(folder) / "postings.jsonl"
     with open(file_path, "wb") as f:  # open in binary for compressed writes
        for term, plist in postings.items():
            data = pickle.dumps(plist, protocol=pickle.HIGHEST_PROTOCOL)
            if self.compr == Compression.CODE:
                data = zlib.compress(data)
            elif self.compr == Compression.CLIB:
                data = lzma.compress(data)
            # write as length-prefixed record for safe JSONL-like reading
            # format: <len_bytes(4)><data>
            f.write(len(data).to_bytes(4, "big") + data)

    def _load_postings_db2(self, folder):
     file_path = Path(folder) / "postings.jsonl"
     postings = {}
     with open(file_path, "rb") as f:
        while True:
            len_bytes = f.read(4)
            if not len_bytes:
                break
            data_len = int.from_bytes(len_bytes, "big")
            data = f.read(data_len)
            if self.compr == Compression.CODE:
                data = zlib.decompress(data)
            elif self.compr == Compression.CLIB:
                data = lzma.decompress(data)
            plist = pickle.loads(data)
            # retrieve term from plist (original key)
            # DB2 already writes term separately in JSON, so here we assume plist is just list
            # store using first element's term if needed; or keep a dict {term: plist} before saving
            # simpler: store as {term: plist}
            # for DB2, we need to save term explicitly:
            term = plist[0][0] if plist else None
            if term is not None:
                postings[term] = plist
     return postings


    def _index_folder(self, index_id: str) -> Path:
        return SelfIndex.base_dir / index_id

    def _meta_path(self, index_id: str) -> Path:
        return self._index_folder(index_id) / "meta.json"

    def _postings_path(self, index_id: str) -> Path:
        return self._index_folder(index_id) / "postings.pkl"

    # ------------------------
    # Create index
    # ------------------------
    def create_index(self, index_id: str, files: Iterable[Tuple[str,str]]) -> None:
        """
        files: iterable of (doc_id_str, content_str)
        doc_id_str should be convertible to int or unique string; we'll convert to int if possible.
        """
        print(f"[SelfIndex] Building index '{index_id}' with config info={self.info.name}, dstore={self.dstore.name}, optim={self.optim.name}, compr={self.compr.name}, qproc={self.qproc.name}")
        # init
        temp = defaultdict(lambda: defaultdict(list))  # token -> doc -> list of positions
        doc_len = {}
        doc_ids = []

        # ingest
        for doc_id_raw, text in files:
            try:
                doc_id = int(doc_id_raw)
            except:
                # fallback: use hash
                doc_id = abs(hash(doc_id_raw)) % (10**9)
            doc_ids.append(doc_id)
            tokens = self._tokenize(text)
            doc_len[doc_id] = len(tokens)
            for pos, tok in enumerate(tokens):
                temp[tok][doc_id].append(pos)

        # convert temp -> postings lists
        postings = {}
        df = {}
        for tok, dmap in temp.items():
            plist = []
            for doc in sorted(dmap.keys()):
                positions = dmap[doc]
                freq = len(positions)
                plist.append((doc, freq, positions))
            postings[tok] = plist
            df[tok] = len(plist)

        # metadata
        N = len(doc_len)

        # compute TF-IDF weights if requested (we will store df and doc_len and calculate on-the-fly)
        # store state
        folder = self._index_folder(index_id)
        if folder.exists():
            print("[SelfIndex] Warning: index folder exists. Overwriting.")
            shutil.rmtree(folder)
        folder.mkdir(parents=True, exist_ok=True)

        # persist postings (pickle) and metadata (json)
        #with open(self._postings_path(index_id), "wb") as f:
            #pickle.dump(postings, f, protocol=pickle.HIGHEST_PROTOCOL)
        compressed_data = self._compress_postings(postings)
        #with open(self._postings_path(index_id), "wb") as f:
         #f.write(compressed_data)
        if self.dstore == DataStore.CUSTOM:
          with open(folder / "postings.pkl", "wb") as f:
           f.write(compressed_data)
        elif self.dstore == DataStore.DB1:
          self._save_postings_db1(postings, folder)
        elif self.dstore == DataStore.DB2:
          self._save_postings_db2(postings, folder)


        meta = {
            "info": self.info.name,
            "dstore": self.dstore.name,
            "qproc": self.qproc.name,
            "compr": self.compr.name,
            "optim": self.optim.name,
            "N": N,
            "df": df,
            "doc_len": doc_len,
            "doc_ids": doc_ids
        }
        with open(self._meta_path(index_id), "w", encoding="utf8") as f:
            json.dump(meta, f)

        # update instance if desired to keep loaded
        self.index_id = index_id
        self.index_path = folder
        self.postings = postings
        self.df = df
        self.doc_len = doc_len
        self.N = N
        self.doc_ids_indexed = doc_ids

        print(f"[SelfIndex] Index '{index_id}' created: {N} documents, {len(postings)} terms.")

    # ------------------------
    # Load index into memory
    # ------------------------
    def load_index(self, serialized_index_dump: str) -> None:
        """
        serialized_index_dump: path to the folder that contains postings.pkl and meta.json
        """
        folder = Path(serialized_index_dump)
        if not folder.exists():
            raise FileNotFoundError(f"Index folder not found: {serialized_index_dump}")
        # load meta
        with open(folder / "meta.json", "r", encoding="utf8") as f:
            meta = json.load(f)
        
         # update config if present
        if "compr" in meta:
            self.compr = Compression[meta["compr"]]
        if "info" in meta:
            self.info = IndexInfo[meta["info"]]
        if "qproc" in meta:
            self.qproc = QueryProc[meta["qproc"]]
        if "optim" in meta:
            self.optim = Optimizations[meta["optim"]]
        if "dstore" in meta:
            self.dstore = DataStore[meta["dstore"]]
        
        # load postings
        #with open(folder / "postings.pkl", "rb") as f:
            #postings = pickle.load(f)
        if self.dstore == DataStore.CUSTOM:
         with open(folder / "postings.pkl", "rb") as f:
          data = f.read()
         postings = self._decompress_postings(data)
        elif self.dstore == DataStore.DB1:
         postings = self._load_postings_db1(folder)
        elif self.dstore == DataStore.DB2:
         postings = self._load_postings_db2(folder)

        # set instance state (note: assume meta consistent with this instance)
        self.index_id = folder.name
        self.index_path = folder
        self.postings = postings
        self.df = meta.get("df", {})
        self.doc_len = meta.get("doc_len", {})
        self.N = meta.get("N", len(self.doc_len))
        self.doc_ids_indexed = meta.get("doc_ids", list(self.doc_len.keys()))
        
        print(f"[SelfIndex] Loaded index '{self.index_id}' (N={self.N}, terms={len(self.postings)})")

    # ------------------------
    # Update index: remove/add docs
    # ------------------------
    def update_index(self, index_id: str, remove_files: Iterable[Tuple[str, str]], add_files: Iterable[Tuple[str, str]]) -> None:
        """
        Removes then adds — simple but inefficient approach: load postings, apply changes in memory, re-persist.
        """
        # load current
        self.load_index(str(self._index_folder(index_id)))
        postings = self.postings
        # remove docs
        remove_ids = []
        for doc_id_raw, _ in remove_files:
            try:
                remove_id = int(doc_id_raw)
            except:
                remove_id = abs(hash(doc_id_raw)) % (10**9)
            remove_ids.append(remove_id)
        if remove_ids:
            for tok in list(postings.keys()):
                new_pl = [tup for tup in postings[tok] if tup[0] not in remove_ids]
                if new_pl:
                    postings[tok] = new_pl
                else:
                    del postings[tok]
            # update doc_len and df
            for rid in remove_ids:
                if rid in self.doc_len:
                    del self.doc_len[rid]
            self.N = len(self.doc_len)
        # add docs (reuse create logic for tokens -> update postings)
        for doc_id_raw, text in add_files:
            try:
                doc_id = int(doc_id_raw)
            except:
                doc_id = abs(hash(doc_id_raw)) % (10**9)
            tokens = self._tokenize(text)
            self.doc_len[doc_id] = len(tokens)
            for pos, tok in enumerate(tokens):
                # find if term exists
                if tok not in postings:
                    postings[tok] = [(doc_id, 1, [pos])]
                else:
                    # append or update last entry if same doc
                    if postings[tok] and postings[tok][-1][0] == doc_id:
                        # update freq and positions
                        old_doc, old_freq, old_pos = postings[tok][-1]
                        old_pos.append(pos)
                        postings[tok][-1] = (old_doc, old_freq+1, old_pos)
                    else:
                        postings[tok].append((doc_id, 1, [pos]))
        # recompute df
        self.df = {tok: len(plist) for tok, plist in postings.items()}
        self.postings = postings
        self.N = len(self.doc_len)
        # persist
        #compressed_data = self._compress_postings(self.postings)
        #with open(self._postings_path(index_id), "wb") as f:
         #f.write(compressed_data)
        folder = self._index_folder(index_id)
        if self.dstore == DataStore.CUSTOM:
         compressed_data = self._compress_postings(self.postings)
         with open(folder / "postings.pkl", "wb") as f:
            f.write(compressed_data)
        elif self.dstore == DataStore.DB1:
         self._save_postings_db1(self.postings, folder)
        elif self.dstore == DataStore.DB2:
         self._save_postings_db2(self.postings, folder)
        else:
         raise ValueError(f"Unknown datastore type: {self.dstore}")

        meta = {
            "info": self.info.name,
            "dstore": self.dstore.name,
            "qproc": self.qproc.name,
            "compr": self.compr.name,
            "optim": self.optim.name,
            "N": self.N,
            "df": self.df,
            "doc_len": self.doc_len,
            "doc_ids": self.doc_ids_indexed
        }
        with open(self._meta_path(index_id), "w", encoding="utf8") as f:
            json.dump(meta, f)
        print(f"[SelfIndex] Updated index '{index_id}': N={self.N} documents, terms={len(self.postings)}")

    # ------------------------
    # Delete index
    # ------------------------
    def delete_index(self, index_id: str) -> None:
     folder = self._index_folder(index_id)
     if not folder.exists():
        print(f"[SelfIndex] Index '{index_id}' not found.")
        return

    # Remove specific datastore files if needed
     try:
        if self.dstore == DataStore.CUSTOM:
            file_path = folder / "postings.pkl"
            if file_path.exists():
                file_path.unlink()
        elif self.dstore == DataStore.DB1:
            file_path = folder / "postings.db"
            if file_path.exists():
                file_path.unlink()
        elif self.dstore == DataStore.DB2:
            file_path = folder / "postings.jsonl"
            if file_path.exists():
                file_path.unlink()

        # Delete meta file and folder
        meta_path = folder / "meta.json"
        if meta_path.exists():
            meta_path.unlink()

        shutil.rmtree(folder)
        print(f"[SelfIndex] Deleted index '{index_id}'.")
     except Exception as e:
        print(f"[SelfIndex] Failed to delete index '{index_id}': {e}")

    # ------------------------
    # List indices and files
    # ------------------------
    @staticmethod
    def list_indices() -> Iterable[str]:
        base = SelfIndex.base_dir
        if not base.exists():
            return []
        return [p.name for p in base.iterdir() if p.is_dir()]

    def list_indexed_files(self, index_id: str) -> Iterable[str]:
        folder = self._index_folder(index_id)
        meta_p = folder / "meta.json"
        if not meta_p.exists():
            return []
        with open(meta_p, "r", encoding="utf8") as f:
            meta = json.load(f)
        # doc_ids stored; return as strings
        return [str(d) for d in meta.get("doc_ids", [])]

    # ------------------------
    # Query support
    # ------------------------
    def query(self, query_str: str, k: int = 10) -> Dict:
        """
        Main query entrypoint. Returns a JSON-serializable dict:
        {"query": query_str, "hits": [{"doc_id":..., "score":...}, ...], "total": X}
        """
        if not self.postings:
            raise RuntimeError("No index loaded. Call load_index() or create_index() first.")
        ast = parse_boolean_query_to_ast(query_str)
        # evaluate boolean AST to get candidate set (for boolean ops)
        candidate_docs = self._eval_ast(ast)
        # if index type is BOOLEAN with no ranking, return candidate docs with score=1
        if self.info == IndexInfo.BOOLEAN:
            hits = [{"doc_id": d, "score": 1.0} for d in sorted(candidate_docs)[:k]]
            return {"query": query_str, "hits": hits, "total": len(candidate_docs)}
        # otherwise compute ranking according to WORDCOUNT or TFIDF
        if self.qproc == QueryProc.TERMatat:
            scored = self._score_taat(ast, candidate_docs)
        else:
            scored = self._score_daat(ast, candidate_docs)
        # sorted top-k
        hits = [{"doc_id": int(d), "score": float(score)} for d, score in sorted(scored.items(), key=lambda x: -x[1])[:k]]
        return {"query": query_str, "hits": hits, "total": len(scored)}

    # ------------------------
    # Internal helpers
    # ------------------------
   # def _tokenize(self, text: str) -> List[str]:
        # Assumes preprocessed text (lowercased, tokens separated by whitespace).
        # If raw text, use a simple tokenizer:
        #return [t for t in text.split() if t]

    def _normalize_term(self, term: str) -> str:
        """Normalize term: lowercase, remove non-letters, stem."""
        term = term.lower()
        term = re.sub(r'[^a-z\s]', '', term)
        return self.stemmer.stem(term.strip())

    def _normalize_tokens(self, tokens: List[str]) -> List[str]:
        """Normalize token list."""
        return [self._normalize_term(t) for t in tokens if t.strip()]

    # --- 🔧 Tokenizer (updated to normalize tokens) ---
    def _tokenize(self, text: str) -> List[str]:
        # assumes text might be raw or pre-cleaned
        tokens = text.split()
        return self._normalize_tokens(tokens)
    
        # ------------------------
    # Optimization: Skip pointers
    # ------------------------
    def _intersect_with_skips(self, list1: List[Tuple[int,int,List[int]]], list2: List[Tuple[int,int,List[int]]]) -> Set[int]:
        """
        Perform intersection of two postings lists using skip pointers.
        Each list element is (doc_id, freq, positions).
        """
        result = set()
        n1, n2 = len(list1), len(list2)
        if n1 == 0 or n2 == 0:
            return result

        skip1 = int(math.sqrt(n1))
        skip2 = int(math.sqrt(n2))
        i = j = 0

        while i < n1 and j < n2:
            doc1 = list1[i][0]
            doc2 = list2[j][0]
            if doc1 == doc2:
                result.add(doc1)
                i += 1
                j += 1
            elif doc1 < doc2:
                # try skipping
                if i + skip1 < n1 and list1[i + skip1][0] <= doc2:
                    i += skip1
                else:
                    i += 1
            else:
                if j + skip2 < n2 and list2[j + skip2][0] <= doc1:
                    j += skip2
                else:
                    j += 1
        return result

    def _eval_ast(self, ast) -> Set[int]:
        """Evaluate boolean AST and return set of matching doc_ids."""
        if "match" in ast:
            term = self._normalize_term(ast["match"])
            #term = ast["match"]
            return set([tup[0] for tup in self.postings.get(term, [])])
        if "match_phrase" in ast:
            phrase = ast["match_phrase"]
            toks = self._normalize_tokens(phrase.split())
            #toks = self._tokenize(phrase)
            if not toks:
                return set()
            # positional phrase eval: intersect postings and check positions
            lists = [self.postings.get(t, []) for t in toks]
            if not all(lists):
                return set()
            # for efficiency, start with smallest df list
            lists_sorted = sorted(lists, key=lambda l: len(l))
            base = lists_sorted[0]
            result = set()
            # build dict of doc->positions for each term for random access
            postings_map = []
            for lst in lists_sorted:
                postings_map.append({doc: pos for doc, freq, pos in lst})
            for doc, freq, poslist in base:
                doc_positions_ok = False
                if doc not in postings_map[0]:
                    continue
                base_positions = postings_map[0][doc]
                # check sequence
                for p in base_positions:
                    ok = True
                    offset = 1
                    for j in range(1, len(toks)):
                        # find if any position in postings_map[j][doc] equals p+offset
                        posj = postings_map[j].get(doc, [])
                        if (p + offset) not in posj:
                            ok = False
                            break
                        offset += 1
                    if ok:
                        doc_positions_ok = True
                        break
                if doc_positions_ok:
                    result.add(doc)
            return result
        if "bool" in ast:
            b = ast["bool"]
            # handle must / should / must_not
            if "must" in b:
    # Optimization: Skipping pointers for AND intersection
             if self.optim == Optimizations.Skipping:
        # retrieve postings lists for all terms
              sub_terms = [self._extract_terms_from_ast(sub) for sub in b["must"]]
        # flatten and fetch postings
              posting_lists = [self.postings.get(t[0], []) for t in sub_terms if t]
              if not posting_lists:
                s = set()
              else:
            # start with smallest posting list
               posting_lists.sort(key=len)
               base = posting_lists[0]
               s = set([doc for doc, _, _ in base])
               for pl in posting_lists[1:]:
                s = s.intersection(self._intersect_with_skips(base, pl))
             else:
        # Default (Null optimization)
              sets = [self._eval_ast(sub) for sub in b["must"]]
              if not sets:
                s = set()
              else:
                s = sets[0].copy()
                for ss in sets[1:]:
                 s &= ss

            elif "should" in b:
                sets = [self._eval_ast(sub) for sub in b["should"]]
                s = set().union(*sets) if sets else set()
            else:
                s = set(self.doc_len.keys())
            if "must_not" in b:
                for sub in b["must_not"]:
                    s = s - self._eval_ast(sub)
            return s
        return set()

    def _score_taat(self, ast, candidate_docs: Set[int]) -> Dict[int,float]:
        """Term-at-a-time scoring over candidate_docs for WORDCOUNT or TFIDF."""
        # extract terms from AST (flatten)
        terms = self._extract_terms_from_ast(ast)
        acc = defaultdict(float)
        if self.info == IndexInfo.WORDCOUNT:
            # For each term, iterate postings and add freq to accumulator
            for t in terms:
                plist = self.postings.get(t, [])
                for doc, freq, pos in plist:
                    if doc in candidate_docs:
                        acc[doc] += freq
        elif self.info == IndexInfo.TFIDF:
            for t in terms:
                plist = self.postings.get(t, [])
                df = max(1, self.df.get(t, 0))
                idf = math.log((self.N + 1) / (df + 1)) + 1.0
                for doc, freq, pos in plist:
                    if doc in candidate_docs:
                        tf = 1 + math.log(freq) if freq > 0 else 0
                        acc[doc] += tf * idf
        return acc

    def _score_daat(self, ast, candidate_docs: Set[int]) -> Dict[int,float]:
        """Doc-at-a-time scoring (simple): iterate candidate_docs and compute score per doc."""
        terms = self._extract_terms_from_ast(ast)
        acc = {}
        for doc in candidate_docs:
            score = 0.0
            if self.info == IndexInfo.WORDCOUNT:
                for t in terms:
                    # find freq for doc in postings (linear scan)
                    plist = self.postings.get(t, [])
                    # small optimization: if plist small, linear scan ok
                    for d, freq, pos in plist:
                        if d == doc:
                            score += freq
                            break
            elif self.info == IndexInfo.TFIDF:
                for t in terms:
                    plist = self.postings.get(t, [])
                    df = max(1, self.df.get(t, 0))
                    idf = math.log((self.N + 1) / (df + 1)) + 1.0
                    for d, freq, pos in plist:
                        if d == doc:
                            tf = 1 + math.log(freq) if freq > 0 else 0
                            score += tf * idf
                            break
            acc[doc] = score
        return acc

    def _extract_terms_from_ast(self, ast) -> List[str]:
        """Collect all terms/phrase tokens from AST (flatten)."""
        terms = []
        if "match" in ast:
            terms.append(self._normalize_term(ast["match"])) 
            #terms.append(ast["match"])
        elif "match_phrase" in ast:
            #toks = self._tokenize(ast["match_phrase"])
            toks = self._normalize_tokens(ast["match_phrase"].split())
            terms.extend(toks)
        elif "bool" in ast:
            b = ast["bool"]
            for k in ("must","should","must_not"):
                if k in b:
                    for sub in b[k]:
                        terms.extend(self._extract_terms_from_ast(sub))
        return terms

# End of SelfIndex implementation

# %%
#graph part a
# --- Prepare files iterable: (doc_id, text) for full dataset ---
files_iterable = [(int(idx), txt) for idx, txt in zip(subset.index, subset['clean_text'])]

# --- Load queries from file ---
with open("queries.txt", "r") as f:
    queries = [line.strip() for line in f if line.strip()]

# --- Dictionary to store results ---
all_results = {}

# --- Iterate over all versions ---
for version in VERSION_CONFIG.keys():
    print(f"\n=== Processing version {version} ===")
    
    # Create SelfIndex instance using the version
    si = SelfIndex(version=version)
    
    # Build or load index for the full dataset
    index_id = f"SelfIndex-{version}"
    
    if index_id in SelfIndex.list_indices():
        print("🟢 Loading existing index...")
        si.load_index(f"./selfindex_store/{index_id}")
    else:
        print("🟡 Building new index...")
        si.create_index(index_id, files_iterable)
    
    # Run queries and store results
    version_results = {}
    for q in queries:
        res = si.query(q, k=10)
        version_results[q] = res
        print(f"\nQuery: {q}")
        print(res)
    
    all_results[version] = version_results

# --- all_results now has results for all versions and all queries ---
# Out:
# === Processing version v1.x1.y1.z1.i0.qT0 ===
# 🟡 Building new index...
# [SelfIndex] Building index 'SelfIndex-v1.x1.y1.z1.i0.qT0' with config info=BOOLEAN, dstore=CUSTOM, optim=Null, compr=NONE, qproc=TERMatat
# [SelfIndex] Index 'SelfIndex-v1.x1.y1.z1.i0.qT0' created: 10000 documents, 134822 terms.
#
# Query: "crime"
# {'query': '"crime"', 'hits': [{'doc_id': 3, 'score': 1.0}, {'doc_id': 13, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 27, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 46, 'score': 1.0}], 'total': 811}
#
# Query: "law"
# {'query': '"law"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 45, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 67, 'score': 1.0}, {'doc_id': 74, 'score': 1.0}, {'doc_id': 86, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 91, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}], 'total': 962}
#
# Query: "justice"
# {'query': '"justice"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 13, 'score': 1.0}, {'doc_id': 20, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 68, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}], 'total': 548}
#
# Query: "police"
# {'query': '"police"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 18, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 24, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 47, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}], 'total': 1638}
#
# Query: "fraud"
# {'query': '"fraud"', 'hits': [{'doc_id': 13, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 52, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 115, 'score': 1.0}, {'doc_id': 130, 'score': 1.0}, {'doc_id': 188, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}], 'total': 159}
#
# Query: "theft"
# {'query': '"theft"', 'hits': [{'doc_id': 26, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 103, 'score': 1.0}, {'doc_id': 106, 'score': 1.0}, {'doc_id': 281, 'score': 1.0}, {'doc_id': 282, 'score': 1.0}, {'doc_id': 312, 'score': 1.0}, {'doc_id': 326, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}], 'total': 180}
#
# Query: "corruption"
# {'query': '"corruption"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 23, 'score': 1.0}, {'doc_id': 74, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 139, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 234, 'score': 1.0}, {'doc_id': 241, 'score': 1.0}, {'doc_id': 304, 'score': 1.0}, {'doc_id': 416, 'score': 1.0}], 'total': 59}
#
# Query: "violence"
# {'query': '"violence"', 'hits': [{'doc_id': 23, 'score': 1.0}, {'doc_id': 54, 'score': 1.0}, {'doc_id': 68, 'score': 1.0}, {'doc_id': 78, 'score': 1.0}, {'doc_id': 89, 'score': 1.0}, {'doc_id': 116, 'score': 1.0}, {'doc_id': 139, 'score': 1.0}, {'doc_id': 164, 'score': 1.0}, {'doc_id': 168, 'score': 1.0}, {'doc_id': 185, 'score': 1.0}], 'total': 375}
#
# Query: "investigation"
# {'query': '"investigation"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 8, 'score': 1.0}, {'doc_id': 11, 'score': 1.0}, {'doc_id': 15, 'score': 1.0}, {'doc_id': 18, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 24, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}], 'total': 1212}
#
# Query: "disaster"
# {'query': '"disaster"', 'hits': [{'doc_id': 54, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 446, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 773, 'score': 1.0}, {'doc_id': 793, 'score': 1.0}, {'doc_id': 1457, 'score': 1.0}, {'doc_id': 1510, 'score': 1.0}], 'total': 203}
#
# Query: "accident"
# {'query': '"accident"', 'hits': [{'doc_id': 20, 'score': 1.0}, {'doc_id': 75, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 107, 'score': 1.0}, {'doc_id': 116, 'score': 1.0}, {'doc_id': 160, 'score': 1.0}, {'doc_id': 179, 'score': 1.0}, {'doc_id': 265, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 288, 'score': 1.0}], 'total': 450}
#
# Query: "emergency"
# {'query': '"emergency"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}, {'doc_id': 54, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 87, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 129, 'score': 1.0}], 'total': 801}
#
# Query: "flood"
# {'query': '"flood"', 'hits': [{'doc_id': 428, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 588, 'score': 1.0}, {'doc_id': 820, 'score': 1.0}, {'doc_id': 878, 'score': 1.0}, {'doc_id': 1258, 'score': 1.0}, {'doc_id': 1469, 'score': 1.0}, {'doc_id': 1496, 'score': 1.0}, {'doc_id': 1510, 'score': 1.0}, {'doc_id': 1511, 'score': 1.0}], 'total': 290}
#
# Query: "earthquake"
# {'query': '"earthquake"', 'hits': [{'doc_id': 446, 'score': 1.0}, {'doc_id': 3088, 'score': 1.0}, {'doc_id': 3146, 'score': 1.0}, {'doc_id': 3299, 'score': 1.0}, {'doc_id': 4186, 'score': 1.0}, {'doc_id': 4195, 'score': 1.0}, {'doc_id': 4273, 'score': 1.0}, {'doc_id': 4355, 'score': 1.0}, {'doc_id': 4397, 'score': 1.0}, {'doc_id': 4450, 'score': 1.0}], 'total': 37}
#
# Query: "storm"
# {'query': '"storm"', 'hits': [{'doc_id': 82, 'score': 1.0}, {'doc_id': 161, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 302, 'score': 1.0}, {'doc_id': 527, 'score': 1.0}, {'doc_id': 615, 'score': 1.0}, {'doc_id': 677, 'score': 1.0}, {'doc_id': 736, 'score': 1.0}, {'doc_id': 824, 'score': 1.0}, {'doc_id': 1101, 'score': 1.0}], 'total': 269}
#
# Query: "fire"
# {'query': '"fire"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 8, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 42, 'score': 1.0}, {'doc_id': 80, 'score': 1.0}, {'doc_id': 87, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 112, 'score': 1.0}, {'doc_id': 124, 'score': 1.0}, {'doc_id': 144, 'score': 1.0}], 'total': 870}
#
# Query: "evacuation"
# {'query': '"evacuation"', 'hits': [{'doc_id': 54, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 161, 'score': 1.0}, {'doc_id': 286, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 993, 'score': 1.0}, {'doc_id': 1497, 'score': 1.0}, {'doc_id': 1661, 'score': 1.0}, {'doc_id': 1897, 'score': 1.0}, {'doc_id': 2130, 'score': 1.0}], 'total': 117}
#
# Query: "rescue"
# {'query': '"rescue"', 'hits': [{'doc_id': 33, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 57, 'score': 1.0}, {'doc_id': 118, 'score': 1.0}, {'doc_id': 153, 'score': 1.0}, {'doc_id': 165, 'score': 1.0}, {'doc_id': 346, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 421, 'score': 1.0}, {'doc_id': 453, 'score': 1.0}], 'total': 464}
#
# Query: "damage"
# {'query': '"damage"', 'hits': [{'doc_id': 4, 'score': 1.0}, {'doc_id': 7, 'score': 1.0}, {'doc_id': 10, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 64, 'score': 1.0}, {'doc_id': 72, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 134, 'score': 1.0}, {'doc_id': 135, 'score': 1.0}], 'total': 569}
#
# Query: "economy"
# {'query': '"economy"', 'hits': [{'doc_id': 34, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 95, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 163, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 659, 'score': 1.0}, {'doc_id': 666, 'score': 1.0}], 'total': 163}
#
# Query: "finance"
# {'query': '"finance"', 'hits': [{'doc_id': 23, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 72, 'score': 1.0}, {'doc_id': 78, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 103, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 123, 'score': 1.0}, {'doc_id': 183, 'score': 1.0}], 'total': 625}
#
# Query: "business"
# {'query': '"business"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 16, 'score': 1.0}, {'doc_id': 34, 'score': 1.0}, {'doc_id': 45, 'score': 1.0}, {'doc_id': 46, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 67, 'score': 1.0}, {'doc_id': 68, 'score': 1.0}], 'total': 829}
#
# Query: "market"
# {'query': '"market"', 'hits': [{'doc_id': 4, 'score': 1.0}, {'doc_id': 7, 'score': 1.0}, {'doc_id': 34, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 64, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 95, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 103, 'score': 1.0}], 'total': 596}
#
# Query: "investment"
# {'query': '"investment"', 'hits': [{'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 154, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 164, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 330, 'score': 1.0}, {'doc_id': 421, 'score': 1.0}, {'doc_id': 476, 'score': 1.0}, {'doc_id': 576, 'score': 1.0}], 'total': 344}
#
# Query: "budget"
# {'query': '"budget"', 'hits': [{'doc_id': 29, 'score': 1.0}, {'doc_id': 72, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 172, 'score': 1.0}, {'doc_id': 215, 'score': 1.0}, {'doc_id': 470, 'score': 1.0}, {'doc_id': 472, 'score': 1.0}, {'doc_id': 538, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}], 'total': 147}
#
# Query: "revenue"
# {'query': '"revenue"', 'hits': [{'doc_id': 70, 'score': 1.0}, {'doc_id': 86, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 370, 'score': 1.0}, {'doc_id': 437, 'score': 1.0}, {'doc_id': 673, 'score': 1.0}, {'doc_id': 719, 'score': 1.0}, {'doc_id': 731, 'score': 1.0}, {'doc_id': 779, 'score': 1.0}, {'doc_id': 812, 'score': 1.0}], 'total': 127}
#
# Query: "tax"
# {'query': '"tax"', 'hits': [{'doc_id': 45, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 64, 'score': 1.0}, {'doc_id': 151, 'score': 1.0}, {'doc_id': 194, 'score': 1.0}, {'doc_id': 207, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}, {'doc_id': 335, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 372, 'score': 1.0}], 'total': 147}
#
# Query: "inflation"
# {'query': '"inflation"', 'hits': [{'doc_id': 62, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 163, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}, {'doc_id': 372, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 865, 'score': 1.0}, {'doc_id': 1441, 'score': 1.0}, {'doc_id': 1665, 'score': 1.0}, {'doc_id': 1683, 'score': 1.0}], 'total': 61}
#
# Query: "stock"
# {'query': '"stock"', 'hits': [{'doc_id': 34, 'score': 1.0}, {'doc_id': 92, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 399, 'score': 1.0}, {'doc_id': 445, 'score': 1.0}, {'doc_id': 452, 'score': 1.0}, {'doc_id': 493, 'score': 1.0}, {'doc_id': 525, 'score': 1.0}, {'doc_id': 615, 'score': 1.0}], 'total': 279}
#
# Query: "education"
# {'query': '"education"', 'hits': [{'doc_id': 29, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 128, 'score': 1.0}, {'doc_id': 154, 'score': 1.0}, {'doc_id': 177, 'score': 1.0}, {'doc_id': 267, 'score': 1.0}, {'doc_id': 277, 'score': 1.0}, {'doc_id': 282, 'score': 1.0}], 'total': 774}
#
# Query: "school"
# {'query': '"school"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 42, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 57, 'score': 1.0}, {'doc_id': 77, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 100, 'score': 1.0}], 'total': 1031}
#
# Query: "college"
# {'query': '"college"', 'hits': [{'doc_id': 33, 'score': 1.0}, {'doc_id': 77, 'score': 1.0}, {'doc_id': 108, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 196, 'score': 1.0}, {'doc_id': 243, 'score': 1.0}, {'doc_id': 245, 'score': 1.0}, {'doc_id': 264, 'score': 1.0}, {'doc_id': 271, 'score': 1.0}], 'total': 474}
#
# Query: "university"
# {'query': '"university"', 'hits': [{'doc_id': 4119, 'score': 1.0}, {'doc_id': 9727, 'score': 1.0}], 'total': 2}
#
# Query: "learning"
# {'query': '"learning"', 'hits': [{'doc_id': 32, 'score': 1.0}, {'doc_id': 37, 'score': 1.0}, {'doc_id': 54, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 80, 'score': 1.0}, {'doc_id': 81, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 129, 'score': 1.0}, {'doc_id': 137, 'score': 1.0}], 'total': 899}
#
# Query: "curriculum"
# {'query': '"curriculum"', 'hits': [{'doc_id': 454, 'score': 1.0}, {'doc_id': 1731, 'score': 1.0}, {'doc_id': 3300, 'score': 1.0}, {'doc_id': 3425, 'score': 1.0}, {'doc_id': 3586, 'score': 1.0}, {'doc_id': 3711, 'score': 1.0}, {'doc_id': 5070, 'score': 1.0}, {'doc_id': 5717, 'score': 1.0}, {'doc_id': 5998, 'score': 1.0}, {'doc_id': 6036, 'score': 1.0}], 'total': 93}
#
# Query: "teacher"
# {'query': '"teacher"', 'hits': [{'doc_id': 29, 'score': 1.0}, {'doc_id': 42, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 121, 'score': 1.0}, {'doc_id': 142, 'score': 1.0}, {'doc_id': 177, 'score': 1.0}, {'doc_id': 245, 'score': 1.0}, {'doc_id': 282, 'score': 1.0}, {'doc_id': 301, 'score': 1.0}, {'doc_id': 328, 'score': 1.0}], 'total': 276}
#
# Query: "student"
# {'query': '"student"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 57, 'score': 1.0}, {'doc_id': 77, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 121, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 128, 'score': 1.0}, {'doc_id': 137, 'score': 1.0}, {'doc_id': 142, 'score': 1.0}], 'total': 839}
#
# Query: "exam"
# {'query': '"exam"', 'hits': [{'doc_id': 464, 'score': 1.0}, {'doc_id': 898, 'score': 1.0}, {'doc_id': 1261, 'score': 1.0}, {'doc_id': 1301, 'score': 1.0}, {'doc_id': 1342, 'score': 1.0}, {'doc_id': 1412, 'score': 1.0}, {'doc_id': 1843, 'score': 1.0}, {'doc_id': 2020, 'score': 1.0}, {'doc_id': 2065, 'score': 1.0}, {'doc_id': 2259, 'score': 1.0}], 'total': 64}
#
# Query: "scholarship"
# {'query': '"scholarship"', 'hits': [{'doc_id': 96, 'score': 1.0}, {'doc_id': 219, 'score': 1.0}, {'doc_id': 461, 'score': 1.0}, {'doc_id': 659, 'score': 1.0}, {'doc_id': 686, 'score': 1.0}, {'doc_id': 1064, 'score': 1.0}, {'doc_id': 1958, 'score': 1.0}, {'doc_id': 1980, 'score': 1.0}, {'doc_id': 2089, 'score': 1.0}, {'doc_id': 2589, 'score': 1.0}], 'total': 107}
#
# Query: "environment"
# {'query': '"environment"', 'hits': [{'doc_id': 78, 'score': 1.0}, {'doc_id': 92, 'score': 1.0}, {'doc_id': 111, 'score': 1.0}, {'doc_id': 112, 'score': 1.0}, {'doc_id': 139, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 227, 'score': 1.0}, {'doc_id': 300, 'score': 1.0}, {'doc_id': 304, 'score': 1.0}, {'doc_id': 352, 'score': 1.0}], 'total': 575}
#
# Query: "climate"
# {'query': '"climate"', 'hits': [{'doc_id': 67, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 696, 'score': 1.0}, {'doc_id': 752, 'score': 1.0}, {'doc_id': 896, 'score': 1.0}, {'doc_id': 1101, 'score': 1.0}, {'doc_id': 1459, 'score': 1.0}, {'doc_id': 1830, 'score': 1.0}], 'total': 234}
#
# Query: "pollution"
# {'query': '"pollution"', 'hits': [{'doc_id': 752, 'score': 1.0}, {'doc_id': 878, 'score': 1.0}, {'doc_id': 1084, 'score': 1.0}, {'doc_id': 2606, 'score': 1.0}, {'doc_id': 3415, 'score': 1.0}, {'doc_id': 3562, 'score': 1.0}, {'doc_id': 4151, 'score': 1.0}, {'doc_id': 4199, 'score': 1.0}, {'doc_id': 4397, 'score': 1.0}, {'doc_id': 4426, 'score': 1.0}], 'total': 105}
#
# Query: "sustainability"
# {'query': '"sustainability"', 'hits': [{'doc_id': 96, 'score': 1.0}, {'doc_id': 161, 'score': 1.0}, {'doc_id': 183, 'score': 1.0}, {'doc_id': 241, 'score': 1.0}, {'doc_id': 306, 'score': 1.0}, {'doc_id': 336, 'score': 1.0}, {'doc_id': 351, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 383, 'score': 1.0}, {'doc_id': 447, 'score': 1.0}], 'total': 377}
#
# Query: "conservation"
# {'query': '"conservation"', 'hits': [{'doc_id': 13, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 37, 'score': 1.0}, {'doc_id': 118, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 152, 'score': 1.0}, {'doc_id': 165, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 242, 'score': 1.0}], 'total': 170}
#
# Query: "biodiversity"
# {'query': '"biodiversity"', 'hits': [], 'total': 0}
#
# Query: "recycling"
# {'query': '"recycling"', 'hits': [{'doc_id': 641, 'score': 1.0}, {'doc_id': 653, 'score': 1.0}, {'doc_id': 729, 'score': 1.0}, {'doc_id': 878, 'score': 1.0}, {'doc_id': 992, 'score': 1.0}, {'doc_id': 1678, 'score': 1.0}, {'doc_id': 3415, 'score': 1.0}, {'doc_id': 3915, 'score': 1.0}, {'doc_id': 4052, 'score': 1.0}, {'doc_id': 4470, 'score': 1.0}], 'total': 38}
#
# Query: "deforestation"
# {'query': '"deforestation"', 'hits': [{'doc_id': 1948, 'score': 1.0}, {'doc_id': 3397, 'score': 1.0}, {'doc_id': 7667, 'score': 1.0}, {'doc_id': 8398, 'score': 1.0}, {'doc_id': 8713, 'score': 1.0}], 'total': 5}
#
# Query: "emission"
# {'query': '"emission"', 'hits': [{'doc_id': 578, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 752, 'score': 1.0}, {'doc_id': 900, 'score': 1.0}, {'doc_id': 3253, 'score': 1.0}, {'doc_id': 3562, 'score': 1.0}, {'doc_id': 3612, 'score': 1.0}, {'doc_id': 4635, 'score': 1.0}, {'doc_id': 4877, 'score': 1.0}, {'doc_id': 5130, 'score': 1.0}], 'total': 64}
#
# Query: "energy"
# {'query': '"energy"', 'hits': [{'doc_id': 23, 'score': 1.0}, {'doc_id': 181, 'score': 1.0}, {'doc_id': 271, 'score': 1.0}, {'doc_id': 348, 'score': 1.0}, {'doc_id': 509, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 580, 'score': 1.0}, {'doc_id': 582, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 637, 'score': 1.0}], 'total': 302}
#
# Query: "health"
# {'query': '"health"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 10, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 32, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 67, 'score': 1.0}, {'doc_id': 74, 'score': 1.0}, {'doc_id': 81, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 84, 'score': 1.0}], 'total': 1111}
#
# Query: "medical"
# {'query': '"medical"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 61, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 117, 'score': 1.0}, {'doc_id': 130, 'score': 1.0}], 'total': 890}
#
# Query: "hospital"
# {'query': '"hospital"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 25, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 32, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 47, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 71, 'score': 1.0}], 'total': 940}
#
# Query: "disease"
# {'query': '"disease"', 'hits': [], 'total': 0}
#
# Query: "pandemic"
# {'query': '"pandemic"', 'hits': [{'doc_id': 163, 'score': 1.0}, {'doc_id': 556, 'score': 1.0}, {'doc_id': 1212, 'score': 1.0}, {'doc_id': 1235, 'score': 1.0}, {'doc_id': 1333, 'score': 1.0}, {'doc_id': 1369, 'score': 1.0}, {'doc_id': 1374, 'score': 1.0}, {'doc_id': 1436, 'score': 1.0}, {'doc_id': 1457, 'score': 1.0}, {'doc_id': 1459, 'score': 1.0}], 'total': 158}
#
# Query: "nutrition"
# {'query': '"nutrition"', 'hits': [{'doc_id': 1341, 'score': 1.0}, {'doc_id': 1775, 'score': 1.0}, {'doc_id': 1855, 'score': 1.0}, {'doc_id': 1923, 'score': 1.0}, {'doc_id': 1934, 'score': 1.0}, {'doc_id': 4117, 'score': 1.0}, {'doc_id': 4748, 'score': 1.0}, {'doc_id': 4866, 'score': 1.0}, {'doc_id': 5655, 'score': 1.0}, {'doc_id': 5676, 'score': 1.0}], 'total': 80}
#
# Query: "vaccine"
# {'query': '"vaccine"', 'hits': [{'doc_id': 358, 'score': 1.0}, {'doc_id': 416, 'score': 1.0}, {'doc_id': 537, 'score': 1.0}, {'doc_id': 556, 'score': 1.0}, {'doc_id': 888, 'score': 1.0}, {'doc_id': 1462, 'score': 1.0}, {'doc_id': 1607, 'score': 1.0}, {'doc_id': 1890, 'score': 1.0}, {'doc_id': 3354, 'score': 1.0}, {'doc_id': 3493, 'score': 1.0}], 'total': 63}
#
# Query: "wellbeing"
# {'query': '"wellbeing"', 'hits': [{'doc_id': 10, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 134, 'score': 1.0}, {'doc_id': 241, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 421, 'score': 1.0}, {'doc_id': 451, 'score': 1.0}, {'doc_id': 576, 'score': 1.0}, {'doc_id': 593, 'score': 1.0}, {'doc_id': 598, 'score': 1.0}], 'total': 289}
#
# Query: "mental health"
# {'query': '"mental health"', 'hits': [{'doc_id': 74, 'score': 1.0}, {'doc_id': 84, 'score': 1.0}, {'doc_id': 210, 'score': 1.0}, {'doc_id': 252, 'score': 1.0}, {'doc_id': 463, 'score': 1.0}, {'doc_id': 477, 'score': 1.0}, {'doc_id': 665, 'score': 1.0}, {'doc_id': 823, 'score': 1.0}, {'doc_id': 899, 'score': 1.0}, {'doc_id': 964, 'score': 1.0}], 'total': 193}
#
# Query: "treatment"
# {'query': '"treatment"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 153, 'score': 1.0}, {'doc_id': 199, 'score': 1.0}, {'doc_id': 202, 'score': 1.0}, {'doc_id': 204, 'score': 1.0}, {'doc_id': 254, 'score': 1.0}, {'doc_id': 315, 'score': 1.0}, {'doc_id': 406, 'score': 1.0}], 'total': 549}
#
# Query: "crime prevention"
# {'query': '"crime prevention"', 'hits': [{'doc_id': 651, 'score': 1.0}, {'doc_id': 2072, 'score': 1.0}, {'doc_id': 2874, 'score': 1.0}, {'doc_id': 3024, 'score': 1.0}, {'doc_id': 3044, 'score': 1.0}, {'doc_id': 3055, 'score': 1.0}, {'doc_id': 3080, 'score': 1.0}, {'doc_id': 3081, 'score': 1.0}, {'doc_id': 3133, 'score': 1.0}, {'doc_id': 3167, 'score': 1.0}], 'total': 22}
#
# Query: "law enforcement"
# {'query': '"law enforcement"', 'hits': [{'doc_id': 303, 'score': 1.0}, {'doc_id': 516, 'score': 1.0}, {'doc_id': 1177, 'score': 1.0}, {'doc_id': 1252, 'score': 1.0}, {'doc_id': 1331, 'score': 1.0}, {'doc_id': 1918, 'score': 1.0}, {'doc_id': 1963, 'score': 1.0}, {'doc_id': 2646, 'score': 1.0}, {'doc_id': 3472, 'score': 1.0}, {'doc_id': 3530, 'score': 1.0}], 'total': 14}
#
# Query: "traffic accident"
# {'query': '"traffic accident"', 'hits': [{'doc_id': 1629, 'score': 1.0}, {'doc_id': 1647, 'score': 1.0}, {'doc_id': 3997, 'score': 1.0}, {'doc_id': 4025, 'score': 1.0}, {'doc_id': 4068, 'score': 1.0}, {'doc_id': 5136, 'score': 1.0}, {'doc_id': 5260, 'score': 1.0}, {'doc_id': 5332, 'score': 1.0}], 'total': 8}
#
# Query: "financial fraud"
# {'query': '"financial fraud"', 'hits': [], 'total': 0}
#
# Query: "public health"
# {'query': '"public health"', 'hits': [{'doc_id': 5070, 'score': 1.0}, {'doc_id': 9424, 'score': 1.0}], 'total': 2}
#
# Query: "climate change"
# {'query': '"climate change"', 'hits': [{'doc_id': 67, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 752, 'score': 1.0}, {'doc_id': 896, 'score': 1.0}, {'doc_id': 1459, 'score': 1.0}, {'doc_id': 1866, 'score': 1.0}, {'doc_id': 2448, 'score': 1.0}, {'doc_id': 2926, 'score': 1.0}, {'doc_id': 3088, 'score': 1.0}, {'doc_id': 3146, 'score': 1.0}], 'total': 140}
#
# Query: "school education"
# {'query': '"school education"', 'hits': [{'doc_id': 1535, 'score': 1.0}, {'doc_id': 5250, 'score': 1.0}, {'doc_id': 7217, 'score': 1.0}], 'total': 3}
#
# Query: "economic growth"
# {'query': '"economic growth"', 'hits': [{'doc_id': 631, 'score': 1.0}, {'doc_id': 4479, 'score': 1.0}, {'doc_id': 4961, 'score': 1.0}, {'doc_id': 5621, 'score': 1.0}, {'doc_id': 5731, 'score': 1.0}, {'doc_id': 5914, 'score': 1.0}, {'doc_id': 6415, 'score': 1.0}, {'doc_id': 6536, 'score': 1.0}, {'doc_id': 7272, 'score': 1.0}, {'doc_id': 7308, 'score': 1.0}], 'total': 19}
#
# Query: "corporate crime"
# {'query': '"corporate crime"', 'hits': [], 'total': 0}
#
# Query: "natural disaster"
# {'query': '"natural disaster"', 'hits': [], 'total': 0}
#
# Query: "emergency response"
# {'query': '"emergency response"', 'hits': [], 'total': 0}
#
# Query: "criminal investigation"
# {'query': '"criminal investigation"', 'hits': [{'doc_id': 62, 'score': 1.0}, {'doc_id': 125, 'score': 1.0}, {'doc_id': 130, 'score': 1.0}, {'doc_id': 156, 'score': 1.0}, {'doc_id': 209, 'score': 1.0}, {'doc_id': 226, 'score': 1.0}, {'doc_id': 384, 'score': 1.0}, {'doc_id': 449, 'score': 1.0}, {'doc_id': 513, 'score': 1.0}, {'doc_id': 654, 'score': 1.0}], 'total': 40}
#
# Query: "environmental policy"
# {'query': '"environmental policy"', 'hits': [], 'total': 0}
#
# Query: "hospital management"
# {'query': '"hospital management"', 'hits': [{'doc_id': 5070, 'score': 1.0}, {'doc_id': 7000, 'score': 1.0}, {'doc_id': 7282, 'score': 1.0}, {'doc_id': 7601, 'score': 1.0}], 'total': 4}
#
# Query: "budget allocation"
# {'query': '"budget allocation"', 'hits': [{'doc_id': 3651, 'score': 1.0}], 'total': 1}
#
# Query: "disaster preparedness"
# {'query': '"disaster preparedness"', 'hits': [], 'total': 0}
#
# Query: "crime trends"
# {'query': '"crime trends"', 'hits': [], 'total': 0}
#
# Query: "workplace safety"
# {'query': '"workplace safety"', 'hits': [{'doc_id': 854, 'score': 1.0}, {'doc_id': 4983, 'score': 1.0}, {'doc_id': 5070, 'score': 1.0}], 'total': 3}
#
# Query: "community health programs"
# {'query': '"community health programs"', 'hits': [], 'total': 0}
#
# Query: "education policy reforms"
# {'query': '"education policy reforms"', 'hits': [], 'total': 0}
#
# Query: "sustainable development initiatives"
# {'query': '"sustainable development initiatives"', 'hits': [], 'total': 0}
#
# Query: "flood management strategies"
# {'query': '"flood management strategies"', 'hits': [], 'total': 0}
#
# Query: "earthquake preparedness plans"
# {'query': '"earthquake preparedness plans"', 'hits': [], 'total': 0}
#
# Query: "financial regulation compliance"
# {'query': '"financial regulation compliance"', 'hits': [], 'total': 0}
#
# Query: "pandemic response protocols"
# {'query': '"pandemic response protocols"', 'hits': [], 'total': 0}
#
# Query: "school safety protocols"
# {'query': '"school safety protocols"', 'hits': [], 'total': 0}
#
# Query: "emergency evacuation drills"
# {'query': '"emergency evacuation drills"', 'hits': [], 'total': 0}
#
# Query: "environmental conservation projects"
# {'query': '"environmental conservation projects"', 'hits': [], 'total': 0}
#
# Query: "corporate governance compliance"
# {'query': '"corporate governance compliance"', 'hits': [], 'total': 0}
#
# Query: "healthcare infrastructure improvement"
# {'query': '"healthcare infrastructure improvement"', 'hits': [], 'total': 0}
#
# Query: "economic policy analysis"
# {'query': '"economic policy analysis"', 'hits': [], 'total': 0}
#
# Query: "climate adaptation measures"
# {'query': '"climate adaptation measures"', 'hits': [], 'total': 0}
#
# Query: "crime and punishment analysis"
# {'query': '"crime and punishment analysis"', 'hits': [], 'total': 0}
#
# Query: "law reform implementation"
# {'query': '"law reform implementation"', 'hits': [], 'total': 0}
#
# Query: "disaster risk assessment"
# {'query': '"disaster risk assessment"', 'hits': [], 'total': 0}
#
# Query: "public safety monitoring"
# {'query': '"public safety monitoring"', 'hits': [], 'total': 0}
#
# Query: "urban crime trends"
# {'query': '"urban crime trends"', 'hits': [], 'total': 0}
#
# Query: "rural healthcare access"
# {'query': '"rural healthcare access"', 'hits': [], 'total': 0}
#
# Query: "educational equity programs"
# {'query': '"educational equity programs"', 'hits': [], 'total': 0}
#
# Query: "corporate social responsibility"
# {'query': '"corporate social responsibility"', 'hits': [], 'total': 0}
#
# Query: "natural disaster recovery plans"
# {'query': '"natural disaster recovery plans"', 'hits': [], 'total': 0}
#
# Query: "budget planning and allocation"
# {'query': '"budget planning and allocation"', 'hits': [], 'total': 0}
#
# Query: "environmental impact assessment"
# {'query': '"environmental impact assessment"', 'hits': [], 'total': 0}
#
# Query: "pollution control measures"
# {'query': '"pollution control measures"', 'hits': [], 'total': 0}
#
# Query: "food safety regulations"
# {'query': '"food safety regulations"', 'hits': [], 'total': 0}
#
# Query: "pandemic prevention strategies"
# {'query': '"pandemic prevention strategies"', 'hits': [], 'total': 0}
#
# Query: "student performance evaluation"
# {'query': '"student performance evaluation"', 'hits': [], 'total': 0}
#
# Query: "teacher training programs"
# {'query': '"teacher training programs"', 'hits': [], 'total': 0}
#
# Query: "school infrastructure development"
# {'query': '"school infrastructure development"', 'hits': [], 'total': 0}
#
# Query: "hospital emergency readiness"
# {'query': '"hospital emergency readiness"', 'hits': [], 'total': 0}
#
# Query: "financial market monitoring"
# {'query': '"financial market monitoring"', 'hits': [], 'total': 0}
#
# Query: "business investment strategies"
# {'query': '"business investment strategies"', 'hits': [], 'total': 0}
#
# Query: "renewable energy projects"
# {'query': '"renewable energy projects"', 'hits': [{'doc_id': 631, 'score': 1.0}, {'doc_id': 5914, 'score': 1.0}, {'doc_id': 7816, 'score': 1.0}, {'doc_id': 8077, 'score': 1.0}], 'total': 4}
#
# Query: "climate policy enforcement"
# {'query': '"climate policy enforcement"', 'hits': [], 'total': 0}
#
# Query: "deforestation prevention initiatives"
# {'query': '"deforestation prevention initiatives"', 'hits': [], 'total': 0}
#
# Query: "biodiversity protection programs"
# {'query': '"biodiversity protection programs"', 'hits': [], 'total': 0}
#
# Query: "crime investigation techniques"
# {'query': '"crime investigation techniques"', 'hits': [], 'total': 0}
#
# Query: "law enforcement technology"
# {'query': '"law enforcement technology"', 'hits': [], 'total': 0}
#
# Query: "emergency response coordination"
# {'query': '"emergency response coordination"', 'hits': [], 'total': 0}
#
# Query: "disaster relief operations"
# {'query': '"disaster relief operations"', 'hits': [], 'total': 0}
#
# Query: "financial auditing standards"
# {'query': '"financial auditing standards"', 'hits': [], 'total': 0}
#
# Query: "pandemic vaccination campaigns"
# {'query': '"pandemic vaccination campaigns"', 'hits': [], 'total': 0}
#
# Query: "school curriculum development"
# {'query': '"school curriculum development"', 'hits': [], 'total': 0}
#
# Query: "education quality assessment"
# {'query': '"education quality assessment"', 'hits': [], 'total': 0}
#
# Query: "economic growth planning"
# {'query': '"economic growth planning"', 'hits': [], 'total': 0}
#
# Query: "corporate fraud detection"
# {'query': '"corporate fraud detection"', 'hits': [], 'total': 0}
#
# Query: "workplace accident prevention"
# {'query': '"workplace accident prevention"', 'hits': [], 'total': 0}
#
# Query: "public health monitoring"
# {'query': '"public health monitoring"', 'hits': [], 'total': 0}
#
# Query: "environmental law compliance"
# {'query': '"environmental law compliance"', 'hits': [], 'total': 0}
#
# Query: "climate change mitigation"
# {'query': '"climate change mitigation"', 'hits': [], 'total': 0}
#
# Query: "natural disaster insurance"
# {'query': '"natural disaster insurance"', 'hits': [], 'total': 0}
#
# Query: "urban planning and safety"
# {'query': '"urban planning and safety"', 'hits': [], 'total': 0}
#
# Query: "crime" OR "fraud"
# {'query': '"crime" OR "fraud"', 'hits': [{'doc_id': 3, 'score': 1.0}, {'doc_id': 13, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 27, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}], 'total': 923}
#
# Query: "law" AND "justice"
# {'query': '"law" AND "justice"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 143, 'score': 1.0}, {'doc_id': 164, 'score': 1.0}, {'doc_id': 166, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}], 'total': 211}
#
# Query: "police" AND NOT "corruption"
# {'query': '"police" AND NOT "corruption"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 18, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 24, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 47, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}], 'total': 1620}
#
# Query: ("financial fraud" OR "corporate crime") AND "regulation"
# {'query': '("financial fraud" OR "corporate crime") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("natural disaster" OR "emergency response") AND "community"
# {'query': '("natural disaster" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "public health" AND NOT "education"
# {'query': '"public health" AND NOT "education"', 'hits': [{'doc_id': 9424, 'score': 1.0}], 'total': 1}
#
# Query: ("crime prevention" OR "law enforcement") AND "urban areas"
# {'query': '("crime prevention" OR "law enforcement") AND "urban areas"', 'hits': [], 'total': 0}
#
# Query: "climate change" AND "environmental policy"
# {'query': '"climate change" AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: "school education" AND "safety protocols"
# {'query': '"school education" AND "safety protocols"', 'hits': [], 'total': 0}
#
# Query: ("healthcare reforms" OR "hospital management") AND "rural areas"
# {'query': '("healthcare reforms" OR "hospital management") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: "economic growth" AND NOT "corruption"
# {'query': '"economic growth" AND NOT "corruption"', 'hits': [{'doc_id': 631, 'score': 1.0}, {'doc_id': 4479, 'score': 1.0}, {'doc_id': 4961, 'score': 1.0}, {'doc_id': 5621, 'score': 1.0}, {'doc_id': 5731, 'score': 1.0}, {'doc_id': 6415, 'score': 1.0}, {'doc_id': 6536, 'score': 1.0}, {'doc_id': 7272, 'score': 1.0}, {'doc_id': 7308, 'score': 1.0}, {'doc_id': 7356, 'score': 1.0}], 'total': 18}
#
# Query: ("disaster preparedness" OR "emergency response") AND "community"
# {'query': '("disaster preparedness" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "corporate crime" AND "financial regulation"
# {'query': '"corporate crime" AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("budget allocation" OR "financial planning") AND "government policy"
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 2873, 'score': 1.0}, {'doc_id': 7372, 'score': 1.0}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 1.0}, {'doc_id': 7659, 'score': 1.0}, {'doc_id': 7684, 'score': 1.0}, {'doc_id': 8077, 'score': 1.0}, {'doc_id': 8103, 'score': 1.0}, {'doc_id': 9002, 'score': 1.0}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 1.0}, {'doc_id': 3530, 'score': 1.0}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 1.0}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 4448, 'score': 1.0}, {'doc_id': 7214, 'score': 1.0}, {'doc_id': 8398, 'score': 1.0}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 1.0}, {'doc_id': 7675, 'score': 1.0}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# {'query': '("corporate crime" OR "financial fraud") AND NOT "minor offenses"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government policy"
# {'query': '("environmental law" OR "pollution control") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency evacuation") AND "community safety"
# {'query': '("disaster preparedness" OR "emergency evacuation") AND "community safety"', 'hits': [], 'total': 0}
#
# Query: ("healthcare access" OR "hospital readiness") AND "rural areas"
# {'query': '("healthcare access" OR "hospital readiness") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget planning") AND "national development"
# {'query': '("economic policy" OR "budget planning") AND "national development"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# ...
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 31.634395740690806}, {'doc_id': 2873, 'score': 27.527129654333727}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 73.86875709020813}, {'doc_id': 8077, 'score': 54.95479101972046}, {'doc_id': 8103, 'score': 45.281769346654436}, {'doc_id': 9002, 'score': 42.08884833876811}, {'doc_id': 7684, 'score': 33.49769589066067}, {'doc_id': 7659, 'score': 31.060712142377852}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 23.357695038743042}, {'doc_id': 3530, 'score': 15.956900593669573}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 39.861529152043815}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 7214, 'score': 31.725380895960487}, {'doc_id': 8398, 'score': 28.459483946548797}, {'doc_id': 4448, 'score': 17.99358781406781}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 48.878056500251894}, {'doc_id': 7675, 'score': 39.22464395259123}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# {'query': '("corporate crime" OR "financial fraud") AND NOT "minor offenses"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government policy"
# {'query': '("environmental law" OR "pollution control") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency evacuation") AND "community safety"
# {'query': '("disaster preparedness" OR "emergency evacuation") AND "community safety"', 'hits': [], 'total': 0}
#
# Query: ("healthcare access" OR "hospital readiness") AND "rural areas"
# {'query': '("healthcare access" OR "hospital readiness") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget planning") AND "national development"
# {'query': '("economic policy" OR "budget planning") AND "national development"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 38.77636833127188}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 31.80483991811408}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 38.77636833127188}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 31.80483991811408}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 38.77636833127188}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 31.80483991811408}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}

# %%
#graph part a
import os
import pandas as pd
import numpy as np

def get_folder_size(path):
    total = 0
    for root, _, files in os.walk(path):
        for f in files:
            total += os.path.getsize(os.path.join(root, f))
    return total / (1024 * 1024)  # MB

# ---- SelfIndex memory usage ----
selfindex_folders = {
    "x1 (Boolean)": "./selfindex_store/SelfIndex-v1.x1.y1.z1.i0.qT0",
    "x2 (WordCount)": "./selfindex_store/SelfIndex-v1.x2.y1.z1.i0.qT0",
    "x3 (TF-IDF)": "./selfindex_store/SelfIndex-v1.x3.y1.z1.i0.qT0",
}
selfindex_data = []
for name, path in selfindex_folders.items():
    selfindex_data.append({
        "System": "SelfIndex",
        "Variant": name,
        "Memory_MB": get_folder_size(path)
    })

# ---- ElasticSearch memory usage ----
es_mem_df = pd.read_csv("memory_usage_log.csv")
es_mem_mean = es_mem_df["elasticsearch_MB"].mean()

# Approx. same for all x variants since single ES index
es_data = [
    {"System": "ElasticSearch", "Variant": "x1 (Boolean)", "Memory_MB": es_mem_mean},
    {"System": "ElasticSearch", "Variant": "x2 (WordCount)", "Memory_MB": es_mem_mean},  # synthetic scaling
    {"System": "ElasticSearch", "Variant": "x3 (TF-IDF)", "Memory_MB": es_mem_mean},
]

df_mem = pd.DataFrame(selfindex_data + es_data)
print(selfindex_data)
# Out:
# [{'System': 'SelfIndex', 'Variant': 'x1 (Boolean)', 'Memory_MB': 27.933517456054688}, {'System': 'SelfIndex', 'Variant': 'x2 (WordCount)', 'Memory_MB': 27.93351936340332}, {'System': 'SelfIndex', 'Variant': 'x3 (TF-IDF)', 'Memory_MB': 27.933515548706055}]

# %%
#graph part a
# ---- Plot A – Memory Footprint vs Information Indexed ----
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

plt.figure(figsize=(8,5))
variants = ["x1 (Boolean)", "x2 (WordCount)", "x3 (TF-IDF)"]

# main plot
for sys in ["SelfIndex", "ElasticSearch"]:
    subset = df_mem[df_mem["System"] == sys]
    plt.plot(variants, subset["Memory_MB"], marker="o", label=sys)

plt.yscale("log")  # log scale to show big difference clearly
plt.title("Plot C – Memory Footprint vs Information Indexed")
plt.xlabel("Information Indexed (x)")
plt.ylabel("Memory Footprint in log scale(MB)")
plt.legend()
plt.grid(True, which="both", ls="--")

# ---- Zoomed inset for SelfIndex ----
axins = inset_axes(plt.gca(), width="40%", height="35%", loc="lower right", borderpad=2)
subset_self = df_mem[df_mem["System"] == "SelfIndex"]
axins.plot(variants, subset_self["Memory_MB"], marker="o", color="C0")

# tight y-range for visible differences
ymin = subset_self["Memory_MB"].min()
ymax = subset_self["Memory_MB"].max()
margin = (ymax - ymin) * 20 if (ymax - ymin) != 0 else 0.0005
axins.set_ylim(ymin - margin, ymax + margin)
axins.set_xlim(-0.2, len(variants)-0.8)
axins.set_title("Zoom: SelfIndex Memory", fontsize=8)

# move inset slightly lower
box = axins.get_position()
box.y0 -= 0.1
box.y1 -= 0.1
axins.set_position(box)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_7389/3053128013.py:40: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
#graph part c
# --- Prepare files iterable: (doc_id, text) for full dataset ---
files_iterable = [(int(idx), txt) for idx, txt in zip(subset.index, subset['clean_text'])]

# --- Load queries from file ---
with open("queries.txt", "r") as f:
    queries = [line.strip() for line in f if line.strip()]

# --- Dictionary to store results ---
all_results = {}

# --- Iterate over all versions ---
for version in VERSION_CONFIG.keys():
    print(f"\n=== Processing version {version} ===")
    
    # Create SelfIndex instance using the version
    si = SelfIndex(version=version)
    
    # Build or load index for the full dataset
    index_id = f"SelfIndex-{version}"
    
    if index_id in SelfIndex.list_indices():
        print("🟢 Loading existing index...")
        si.load_index(f"./selfindex_store/{index_id}")
    else:
        print("🟡 Building new index...")
        si.create_index(index_id, files_iterable)
    
    # Run queries and store results
    version_results = {}
    for q in queries:
        res = si.query(q, k=10)
        version_results[q] = res
        print(f"\nQuery: {q}")
        print(res)
    
    all_results[version] = version_results

# --- all_results now has results for all versions and all queries ---
# Out:
# === Processing version v1.x2.y1.z2.i0.qT0 ===
# 🟡 Building new index...
# [SelfIndex] Building index 'SelfIndex-v1.x2.y1.z2.i0.qT0' with config info=WORDCOUNT, dstore=CUSTOM, optim=Null, compr=CODE, qproc=TERMatat
# [SelfIndex] Index 'SelfIndex-v1.x2.y1.z2.i0.qT0' created: 10000 documents, 134822 terms.
#
# Query: "crime"
# {'query': '"crime"', 'hits': [{'doc_id': 3810, 'score': 39.0}, {'doc_id': 3094, 'score': 32.0}, {'doc_id': 3055, 'score': 27.0}, {'doc_id': 3080, 'score': 26.0}, {'doc_id': 3081, 'score': 26.0}, {'doc_id': 3133, 'score': 26.0}, {'doc_id': 3287, 'score': 26.0}, {'doc_id': 3338, 'score': 26.0}, {'doc_id': 3548, 'score': 26.0}, {'doc_id': 3552, 'score': 26.0}], 'total': 811}
#
# Query: "law"
# {'query': '"law"', 'hits': [{'doc_id': 3306, 'score': 24.0}, {'doc_id': 3636, 'score': 21.0}, {'doc_id': 1081, 'score': 18.0}, {'doc_id': 3415, 'score': 18.0}, {'doc_id': 7017, 'score': 18.0}, {'doc_id': 2646, 'score': 17.0}, {'doc_id': 3160, 'score': 17.0}, {'doc_id': 3323, 'score': 17.0}, {'doc_id': 3418, 'score': 17.0}, {'doc_id': 3661, 'score': 17.0}], 'total': 962}
#
# Query: "justice"
# {'query': '"justice"', 'hits': [{'doc_id': 190, 'score': 50.0}, {'doc_id': 1737, 'score': 26.0}, {'doc_id': 781, 'score': 24.0}, {'doc_id': 450, 'score': 21.0}, {'doc_id': 604, 'score': 13.0}, {'doc_id': 996, 'score': 12.0}, {'doc_id': 1922, 'score': 12.0}, {'doc_id': 1325, 'score': 11.0}, {'doc_id': 3415, 'score': 11.0}, {'doc_id': 5703, 'score': 10.0}], 'total': 548}
#
# Query: "police"
# {'query': '"police"', 'hits': [{'doc_id': 1918, 'score': 41.0}, {'doc_id': 3816, 'score': 32.0}, {'doc_id': 1761, 'score': 27.0}, {'doc_id': 3094, 'score': 26.0}, {'doc_id': 1331, 'score': 24.0}, {'doc_id': 218, 'score': 22.0}, {'doc_id': 5171, 'score': 22.0}, {'doc_id': 959, 'score': 21.0}, {'doc_id': 5732, 'score': 20.0}, {'doc_id': 1070, 'score': 19.0}], 'total': 1638}
#
# Query: "fraud"
# {'query': '"fraud"', 'hits': [{'doc_id': 3522, 'score': 16.0}, {'doc_id': 1457, 'score': 8.0}, {'doc_id': 1901, 'score': 7.0}, {'doc_id': 2700, 'score': 6.0}, {'doc_id': 3890, 'score': 6.0}, {'doc_id': 188, 'score': 5.0}, {'doc_id': 555, 'score': 5.0}, {'doc_id': 1369, 'score': 5.0}, {'doc_id': 1855, 'score': 5.0}, {'doc_id': 421, 'score': 4.0}], 'total': 159}
#
# Query: "theft"
# {'query': '"theft"', 'hits': [{'doc_id': 3144, 'score': 22.0}, {'doc_id': 3892, 'score': 22.0}, {'doc_id': 3721, 'score': 20.0}, {'doc_id': 719, 'score': 13.0}, {'doc_id': 1910, 'score': 13.0}, {'doc_id': 3480, 'score': 9.0}, {'doc_id': 1526, 'score': 7.0}, {'doc_id': 2330, 'score': 7.0}, {'doc_id': 1107, 'score': 6.0}, {'doc_id': 1592, 'score': 6.0}], 'total': 180}
#
# Query: "corruption"
# {'query': '"corruption"', 'hits': [{'doc_id': 2220, 'score': 9.0}, {'doc_id': 896, 'score': 6.0}, {'doc_id': 441, 'score': 5.0}, {'doc_id': 3886, 'score': 5.0}, {'doc_id': 5914, 'score': 5.0}, {'doc_id': 2292, 'score': 4.0}, {'doc_id': 2818, 'score': 4.0}, {'doc_id': 1, 'score': 3.0}, {'doc_id': 74, 'score': 2.0}, {'doc_id': 96, 'score': 2.0}], 'total': 59}
#
# Query: "violence"
# {'query': '"violence"', 'hits': [{'doc_id': 3415, 'score': 17.0}, {'doc_id': 3542, 'score': 11.0}, {'doc_id': 1879, 'score': 10.0}, {'doc_id': 3521, 'score': 10.0}, {'doc_id': 2249, 'score': 9.0}, {'doc_id': 2424, 'score': 9.0}, {'doc_id': 5917, 'score': 8.0}, {'doc_id': 54, 'score': 7.0}, {'doc_id': 3363, 'score': 7.0}, {'doc_id': 1875, 'score': 6.0}], 'total': 375}
#
# Query: "investigation"
# {'query': '"investigation"', 'hits': [{'doc_id': 1761, 'score': 19.0}, {'doc_id': 137, 'score': 15.0}, {'doc_id': 1114, 'score': 14.0}, {'doc_id': 1073, 'score': 12.0}, {'doc_id': 878, 'score': 11.0}, {'doc_id': 4274, 'score': 11.0}, {'doc_id': 1131, 'score': 10.0}, {'doc_id': 1296, 'score': 10.0}, {'doc_id': 3309, 'score': 10.0}, {'doc_id': 3867, 'score': 10.0}], 'total': 1212}
#
# Query: "disaster"
# {'query': '"disaster"', 'hits': [{'doc_id': 5897, 'score': 19.0}, {'doc_id': 4856, 'score': 11.0}, {'doc_id': 5502, 'score': 11.0}, {'doc_id': 5656, 'score': 11.0}, {'doc_id': 5905, 'score': 11.0}, {'doc_id': 5031, 'score': 10.0}, {'doc_id': 5123, 'score': 9.0}, {'doc_id': 5775, 'score': 8.0}, {'doc_id': 9592, 'score': 8.0}, {'doc_id': 5300, 'score': 7.0}], 'total': 203}
#
# Query: "accident"
# {'query': '"accident"', 'hits': [{'doc_id': 3401, 'score': 21.0}, {'doc_id': 4506, 'score': 21.0}, {'doc_id': 4880, 'score': 20.0}, {'doc_id': 5802, 'score': 20.0}, {'doc_id': 4221, 'score': 17.0}, {'doc_id': 4815, 'score': 17.0}, {'doc_id': 4755, 'score': 15.0}, {'doc_id': 3997, 'score': 12.0}, {'doc_id': 3281, 'score': 11.0}, {'doc_id': 3557, 'score': 10.0}], 'total': 450}
#
# Query: "emergency"
# {'query': '"emergency"', 'hits': [{'doc_id': 9365, 'score': 16.0}, {'doc_id': 5070, 'score': 14.0}, {'doc_id': 1565, 'score': 13.0}, {'doc_id': 5808, 'score': 12.0}, {'doc_id': 5919, 'score': 11.0}, {'doc_id': 8779, 'score': 11.0}, {'doc_id': 9147, 'score': 11.0}, {'doc_id': 2831, 'score': 9.0}, {'doc_id': 5136, 'score': 9.0}, {'doc_id': 5188, 'score': 9.0}], 'total': 801}
#
# Query: "flood"
# {'query': '"flood"', 'hits': [{'doc_id': 4491, 'score': 29.0}, {'doc_id': 5890, 'score': 26.0}, {'doc_id': 5123, 'score': 19.0}, {'doc_id': 5051, 'score': 18.0}, {'doc_id': 4430, 'score': 16.0}, {'doc_id': 4967, 'score': 16.0}, {'doc_id': 5109, 'score': 16.0}, {'doc_id': 5473, 'score': 15.0}, {'doc_id': 5453, 'score': 14.0}, {'doc_id': 5580, 'score': 14.0}], 'total': 290}
#
# Query: "earthquake"
# {'query': '"earthquake"', 'hits': [{'doc_id': 4195, 'score': 9.0}, {'doc_id': 4186, 'score': 8.0}, {'doc_id': 4397, 'score': 6.0}, {'doc_id': 4630, 'score': 6.0}, {'doc_id': 5782, 'score': 6.0}, {'doc_id': 5557, 'score': 5.0}, {'doc_id': 5573, 'score': 5.0}, {'doc_id': 5688, 'score': 5.0}, {'doc_id': 9990, 'score': 4.0}, {'doc_id': 5129, 'score': 3.0}], 'total': 37}
#
# Query: "storm"
# {'query': '"storm"', 'hits': [{'doc_id': 4491, 'score': 23.0}, {'doc_id': 5770, 'score': 13.0}, {'doc_id': 4301, 'score': 11.0}, {'doc_id': 8736, 'score': 11.0}, {'doc_id': 8153, 'score': 10.0}, {'doc_id': 9333, 'score': 10.0}, {'doc_id': 4980, 'score': 9.0}, {'doc_id': 5464, 'score': 9.0}, {'doc_id': 4616, 'score': 8.0}, {'doc_id': 5659, 'score': 8.0}], 'total': 269}
#
# Query: "fire"
# {'query': '"fire"', 'hits': [{'doc_id': 7606, 'score': 42.0}, {'doc_id': 5102, 'score': 37.0}, {'doc_id': 4765, 'score': 32.0}, {'doc_id': 8170, 'score': 30.0}, {'doc_id': 5563, 'score': 28.0}, {'doc_id': 5379, 'score': 22.0}, {'doc_id': 4354, 'score': 21.0}, {'doc_id': 4817, 'score': 21.0}, {'doc_id': 8592, 'score': 21.0}, {'doc_id': 5369, 'score': 20.0}], 'total': 870}
#
# Query: "evacuation"
# {'query': '"evacuation"', 'hits': [{'doc_id': 8592, 'score': 19.0}, {'doc_id': 5100, 'score': 14.0}, {'doc_id': 5379, 'score': 8.0}, {'doc_id': 5102, 'score': 7.0}, {'doc_id': 5594, 'score': 7.0}, {'doc_id': 2196, 'score': 6.0}, {'doc_id': 4420, 'score': 6.0}, {'doc_id': 4430, 'score': 6.0}, {'doc_id': 5060, 'score': 6.0}, {'doc_id': 5310, 'score': 6.0}], 'total': 117}
#
# Query: "rescue"
# {'query': '"rescue"', 'hits': [{'doc_id': 8896, 'score': 22.0}, {'doc_id': 5579, 'score': 17.0}, {'doc_id': 8064, 'score': 16.0}, {'doc_id': 5432, 'score': 14.0}, {'doc_id': 5414, 'score': 13.0}, {'doc_id': 5805, 'score': 12.0}, {'doc_id': 3254, 'score': 10.0}, {'doc_id': 5287, 'score': 9.0}, {'doc_id': 5645, 'score': 9.0}, {'doc_id': 5687, 'score': 9.0}], 'total': 464}
#
# Query: "damage"
# {'query': '"damage"', 'hits': [{'doc_id': 4246, 'score': 15.0}, {'doc_id': 5782, 'score': 14.0}, {'doc_id': 4448, 'score': 12.0}, {'doc_id': 4567, 'score': 12.0}, {'doc_id': 5770, 'score': 12.0}, {'doc_id': 4135, 'score': 10.0}, {'doc_id': 5931, 'score': 10.0}, {'doc_id': 9820, 'score': 10.0}, {'doc_id': 212, 'score': 9.0}, {'doc_id': 4695, 'score': 8.0}], 'total': 569}
#
# Query: "economy"
# {'query': '"economy"', 'hits': [{'doc_id': 9029, 'score': 6.0}, {'doc_id': 9143, 'score': 6.0}, {'doc_id': 631, 'score': 4.0}, {'doc_id': 4961, 'score': 4.0}, {'doc_id': 5914, 'score': 4.0}, {'doc_id': 6573, 'score': 4.0}, {'doc_id': 2940, 'score': 3.0}, {'doc_id': 4479, 'score': 3.0}, {'doc_id': 7214, 'score': 3.0}, {'doc_id': 7362, 'score': 3.0}], 'total': 163}
#
# Query: "finance"
# {'query': '"finance"', 'hits': [{'doc_id': 3880, 'score': 20.0}, {'doc_id': 4079, 'score': 14.0}, {'doc_id': 7377, 'score': 14.0}, {'doc_id': 3428, 'score': 13.0}, {'doc_id': 7008, 'score': 13.0}, {'doc_id': 5914, 'score': 12.0}, {'doc_id': 1296, 'score': 11.0}, {'doc_id': 7343, 'score': 10.0}, {'doc_id': 7788, 'score': 10.0}, {'doc_id': 2401, 'score': 9.0}], 'total': 625}
#
# Query: "business"
# {'query': '"business"', 'hits': [{'doc_id': 9921, 'score': 133.0}, {'doc_id': 5914, 'score': 29.0}, {'doc_id': 3892, 'score': 23.0}, {'doc_id': 9504, 'score': 20.0}, {'doc_id': 7752, 'score': 18.0}, {'doc_id': 7918, 'score': 18.0}, {'doc_id': 7283, 'score': 16.0}, {'doc_id': 7886, 'score': 15.0}, {'doc_id': 549, 'score': 14.0}, {'doc_id': 1451, 'score': 13.0}], 'total': 829}
#
# Query: "market"
# {'query': '"market"', 'hits': [{'doc_id': 9504, 'score': 67.0}, {'doc_id': 9995, 'score': 42.0}, {'doc_id': 9459, 'score': 40.0}, {'doc_id': 9760, 'score': 34.0}, {'doc_id': 9905, 'score': 33.0}, {'doc_id': 7585, 'score': 30.0}, {'doc_id': 5914, 'score': 28.0}, {'doc_id': 9834, 'score': 23.0}, {'doc_id': 9996, 'score': 20.0}, {'doc_id': 3247, 'score': 17.0}], 'total': 596}
#
# Query: "investment"
# {'query': '"investment"', 'hits': [{'doc_id': 6846, 'score': 24.0}, {'doc_id': 7474, 'score': 20.0}, {'doc_id': 9727, 'score': 18.0}, {'doc_id': 9464, 'score': 17.0}, {'doc_id': 9029, 'score': 15.0}, {'doc_id': 7427, 'score': 10.0}, {'doc_id': 1810, 'score': 9.0}, {'doc_id': 5914, 'score': 9.0}, {'doc_id': 9100, 'score': 8.0}, {'doc_id': 9785, 'score': 7.0}], 'total': 344}
#
# Query: "budget"
# {'query': '"budget"', 'hits': [{'doc_id': 4079, 'score': 10.0}, {'doc_id': 5082, 'score': 10.0}, {'doc_id': 3933, 'score': 9.0}, {'doc_id': 3569, 'score': 6.0}, {'doc_id': 3646, 'score': 5.0}, {'doc_id': 9002, 'score': 5.0}, {'doc_id': 2251, 'score': 4.0}, {'doc_id': 3467, 'score': 4.0}, {'doc_id': 5369, 'score': 4.0}, {'doc_id': 5689, 'score': 4.0}], 'total': 147}
#
# Query: "revenue"
# {'query': '"revenue"', 'hits': [{'doc_id': 2672, 'score': 10.0}, {'doc_id': 2676, 'score': 10.0}, {'doc_id': 9248, 'score': 10.0}, {'doc_id': 2080, 'score': 9.0}, {'doc_id': 2539, 'score': 9.0}, {'doc_id': 1419, 'score': 6.0}, {'doc_id': 1828, 'score': 6.0}, {'doc_id': 3569, 'score': 5.0}, {'doc_id': 5914, 'score': 5.0}, {'doc_id': 3467, 'score': 4.0}], 'total': 127}
#
# Query: "tax"
# {'query': '"tax"', 'hits': [{'doc_id': 3765, 'score': 25.0}, {'doc_id': 5914, 'score': 23.0}, {'doc_id': 513, 'score': 20.0}, {'doc_id': 6415, 'score': 14.0}, {'doc_id': 62, 'score': 13.0}, {'doc_id': 3530, 'score': 9.0}, {'doc_id': 7656, 'score': 9.0}, {'doc_id': 7448, 'score': 8.0}, {'doc_id': 9921, 'score': 8.0}, {'doc_id': 695, 'score': 6.0}], 'total': 147}
#
# Query: "inflation"
# {'query': '"inflation"', 'hits': [{'doc_id': 9464, 'score': 5.0}, {'doc_id': 6551, 'score': 4.0}, {'doc_id': 6846, 'score': 4.0}, {'doc_id': 9223, 'score': 4.0}, {'doc_id': 4916, 'score': 3.0}, {'doc_id': 5659, 'score': 3.0}, {'doc_id': 6735, 'score': 3.0}, {'doc_id': 9029, 'score': 3.0}, {'doc_id': 62, 'score': 2.0}, {'doc_id': 4479, 'score': 2.0}], 'total': 61}
#
# Query: "stock"
# {'query': '"stock"', 'hits': [{'doc_id': 3705, 'score': 19.0}, {'doc_id': 4496, 'score': 17.0}, {'doc_id': 3910, 'score': 14.0}, {'doc_id': 493, 'score': 12.0}, {'doc_id': 4103, 'score': 12.0}, {'doc_id': 7777, 'score': 11.0}, {'doc_id': 2080, 'score': 10.0}, {'doc_id': 2676, 'score': 10.0}, {'doc_id': 2672, 'score': 9.0}, {'doc_id': 2675, 'score': 9.0}], 'total': 279}
#
# Query: "education"
# {'query': '"education"', 'hits': [{'doc_id': 7372, 'score': 36.0}, {'doc_id': 7656, 'score': 30.0}, {'doc_id': 7031, 'score': 27.0}, {'doc_id': 7177, 'score': 24.0}, {'doc_id': 3425, 'score': 22.0}, {'doc_id': 7777, 'score': 22.0}, {'doc_id': 7889, 'score': 17.0}, {'doc_id': 7967, 'score': 16.0}, {'doc_id': 7968, 'score': 15.0}, {'doc_id': 7976, 'score': 15.0}], 'total': 774}
#
# Query: "school"
# {'query': '"school"', 'hits': [{'doc_id': 7083, 'score': 32.0}, {'doc_id': 7571, 'score': 28.0}, {'doc_id': 1535, 'score': 27.0}, {'doc_id': 9113, 'score': 25.0}, {'doc_id': 7659, 'score': 23.0}, {'doc_id': 2517, 'score': 21.0}, {'doc_id': 7652, 'score': 21.0}, {'doc_id': 7778, 'score': 20.0}, {'doc_id': 991, 'score': 19.0}, {'doc_id': 1843, 'score': 19.0}], 'total': 1031}
#
# Query: "college"
# {'query': '"college"', 'hits': [{'doc_id': 7576, 'score': 30.0}, {'doc_id': 9736, 'score': 17.0}, {'doc_id': 7360, 'score': 16.0}, {'doc_id': 7724, 'score': 16.0}, {'doc_id': 7117, 'score': 14.0}, {'doc_id': 3222, 'score': 12.0}, {'doc_id': 7031, 'score': 12.0}, {'doc_id': 7462, 'score': 11.0}, {'doc_id': 7196, 'score': 10.0}, {'doc_id': 7225, 'score': 10.0}], 'total': 474}
#
# Query: "university"
# {'query': '"university"', 'hits': [{'doc_id': 4119, 'score': 1.0}, {'doc_id': 9727, 'score': 1.0}], 'total': 2}
#
# Query: "learning"
# {'query': '"learning"', 'hits': [{'doc_id': 7726, 'score': 22.0}, {'doc_id': 7283, 'score': 17.0}, {'doc_id': 7192, 'score': 16.0}, {'doc_id': 7313, 'score': 16.0}, {'doc_id': 7490, 'score': 13.0}, {'doc_id': 4697, 'score': 12.0}, {'doc_id': 7930, 'score': 12.0}, {'doc_id': 7065, 'score': 11.0}, {'doc_id': 7759, 'score': 11.0}, {'doc_id': 7777, 'score': 11.0}], 'total': 899}
#
# Query: "curriculum"
# {'query': '"curriculum"', 'hits': [{'doc_id': 7955, 'score': 7.0}, {'doc_id': 7924, 'score': 6.0}, {'doc_id': 7372, 'score': 5.0}, {'doc_id': 7967, 'score': 5.0}, {'doc_id': 7146, 'score': 4.0}, {'doc_id': 7502, 'score': 4.0}, {'doc_id': 7724, 'score': 4.0}, {'doc_id': 7919, 'score': 4.0}, {'doc_id': 7148, 'score': 3.0}, {'doc_id': 7170, 'score': 3.0}], 'total': 93}
#
# Query: "teacher"
# {'query': '"teacher"', 'hits': [{'doc_id': 7701, 'score': 28.0}, {'doc_id': 7691, 'score': 26.0}, {'doc_id': 2646, 'score': 13.0}, {'doc_id': 7183, 'score': 13.0}, {'doc_id': 7083, 'score': 11.0}, {'doc_id': 7635, 'score': 11.0}, {'doc_id': 7846, 'score': 10.0}, {'doc_id': 1625, 'score': 8.0}, {'doc_id': 7470, 'score': 8.0}, {'doc_id': 7571, 'score': 8.0}], 'total': 276}
#
# Query: "student"
# {'query': '"student"', 'hits': [{'doc_id': 7576, 'score': 73.0}, {'doc_id': 7010, 'score': 28.0}, {'doc_id': 7502, 'score': 28.0}, {'doc_id': 394, 'score': 27.0}, {'doc_id': 7239, 'score': 26.0}, {'doc_id': 7406, 'score': 26.0}, {'doc_id': 7071, 'score': 25.0}, {'doc_id': 7430, 'score': 25.0}, {'doc_id': 7499, 'score': 23.0}, {'doc_id': 7245, 'score': 22.0}], 'total': 839}
#
# Query: "exam"
# {'query': '"exam"', 'hits': [{'doc_id': 7107, 'score': 37.0}, {'doc_id': 9298, 'score': 33.0}, {'doc_id': 5535, 'score': 7.0}, {'doc_id': 7090, 'score': 6.0}, {'doc_id': 7114, 'score': 6.0}, {'doc_id': 7251, 'score': 4.0}, {'doc_id': 7430, 'score': 4.0}, {'doc_id': 7603, 'score': 4.0}, {'doc_id': 1261, 'score': 3.0}, {'doc_id': 3242, 'score': 3.0}], 'total': 64}
#
# Query: "scholarship"
# {'query': '"scholarship"', 'hits': [{'doc_id': 7901, 'score': 27.0}, {'doc_id': 7272, 'score': 16.0}, {'doc_id': 9353, 'score': 16.0}, {'doc_id': 9409, 'score': 16.0}, {'doc_id': 9501, 'score': 16.0}, {'doc_id': 9545, 'score': 16.0}, {'doc_id': 9600, 'score': 16.0}, {'doc_id': 9689, 'score': 16.0}, {'doc_id': 9879, 'score': 16.0}, {'doc_id': 7223, 'score': 13.0}], 'total': 107}
#
# Query: "environment"
# {'query': '"environment"', 'hits': [{'doc_id': 7747, 'score': 14.0}, {'doc_id': 7813, 'score': 14.0}, {'doc_id': 7531, 'score': 12.0}, {'doc_id': 5326, 'score': 10.0}, {'doc_id': 5914, 'score': 10.0}, {'doc_id': 5947, 'score': 10.0}, {'doc_id': 8077, 'score': 10.0}, {'doc_id': 9464, 'score': 10.0}, {'doc_id': 3415, 'score': 9.0}, {'doc_id': 7628, 'score': 9.0}], 'total': 575}
#
# Query: "climate"
# {'query': '"climate"', 'hits': [{'doc_id': 3562, 'score': 63.0}, {'doc_id': 8713, 'score': 18.0}, {'doc_id': 8248, 'score': 15.0}, {'doc_id': 9464, 'score': 13.0}, {'doc_id': 8505, 'score': 12.0}, {'doc_id': 8804, 'score': 11.0}, {'doc_id': 5835, 'score': 10.0}, {'doc_id': 8551, 'score': 10.0}, {'doc_id': 9029, 'score': 10.0}, {'doc_id': 4817, 'score': 9.0}], 'total': 234}
#
# Query: "pollution"
# {'query': '"pollution"', 'hits': [{'doc_id': 8582, 'score': 30.0}, {'doc_id': 8397, 'score': 12.0}, {'doc_id': 8523, 'score': 12.0}, {'doc_id': 8176, 'score': 10.0}, {'doc_id': 1084, 'score': 7.0}, {'doc_id': 9023, 'score': 7.0}, {'doc_id': 7007, 'score': 6.0}, {'doc_id': 8398, 'score': 6.0}, {'doc_id': 752, 'score': 5.0}, {'doc_id': 878, 'score': 5.0}], 'total': 105}
#
# Query: "sustainability"
# {'query': '"sustainability"', 'hits': [{'doc_id': 7891, 'score': 23.0}, {'doc_id': 8713, 'score': 14.0}, {'doc_id': 7175, 'score': 12.0}, {'doc_id': 8505, 'score': 12.0}, {'doc_id': 9201, 'score': 12.0}, {'doc_id': 7356, 'score': 10.0}, {'doc_id': 7214, 'score': 9.0}, {'doc_id': 7747, 'score': 9.0}, {'doc_id': 5914, 'score': 8.0}, {'doc_id': 7667, 'score': 7.0}], 'total': 377}
#
# Query: "conservation"
# {'query': '"conservation"', 'hits': [{'doc_id': 604, 'score': 7.0}, {'doc_id': 7214, 'score': 7.0}, {'doc_id': 7596, 'score': 7.0}, {'doc_id': 7866, 'score': 7.0}, {'doc_id': 13, 'score': 5.0}, {'doc_id': 450, 'score': 5.0}, {'doc_id': 1655, 'score': 5.0}, {'doc_id': 1948, 'score': 5.0}, {'doc_id': 7439, 'score': 5.0}, {'doc_id': 5259, 'score': 4.0}], 'total': 170}
#
# Query: "biodiversity"
# {'query': '"biodiversity"', 'hits': [], 'total': 0}
#
# Query: "recycling"
# {'query': '"recycling"', 'hits': [{'doc_id': 8156, 'score': 8.0}, {'doc_id': 4908, 'score': 6.0}, {'doc_id': 8207, 'score': 6.0}, {'doc_id': 9557, 'score': 6.0}, {'doc_id': 8956, 'score': 3.0}, {'doc_id': 641, 'score': 2.0}, {'doc_id': 1678, 'score': 2.0}, {'doc_id': 4736, 'score': 2.0}, {'doc_id': 4786, 'score': 2.0}, {'doc_id': 7941, 'score': 2.0}], 'total': 38}
#
# Query: "deforestation"
# {'query': '"deforestation"', 'hits': [{'doc_id': 1948, 'score': 1.0}, {'doc_id': 3397, 'score': 1.0}, {'doc_id': 7667, 'score': 1.0}, {'doc_id': 8398, 'score': 1.0}, {'doc_id': 8713, 'score': 1.0}], 'total': 5}
#
# Query: "emission"
# {'query': '"emission"', 'hits': [{'doc_id': 8713, 'score': 16.0}, {'doc_id': 752, 'score': 14.0}, {'doc_id': 8300, 'score': 11.0}, {'doc_id': 8786, 'score': 10.0}, {'doc_id': 8205, 'score': 9.0}, {'doc_id': 8266, 'score': 9.0}, {'doc_id': 8427, 'score': 9.0}, {'doc_id': 9464, 'score': 8.0}, {'doc_id': 8065, 'score': 7.0}, {'doc_id': 8229, 'score': 7.0}], 'total': 64}
#
# Query: "energy"
# {'query': '"energy"', 'hits': [{'doc_id': 8077, 'score': 32.0}, {'doc_id': 5188, 'score': 29.0}, {'doc_id': 5792, 'score': 24.0}, {'doc_id': 9208, 'score': 20.0}, {'doc_id': 9742, 'score': 16.0}, {'doc_id': 5914, 'score': 14.0}, {'doc_id': 9029, 'score': 14.0}, {'doc_id': 9464, 'score': 14.0}, {'doc_id': 8624, 'score': 13.0}, {'doc_id': 2401, 'score': 12.0}], 'total': 302}
#
# Query: "health"
# {'query': '"health"', 'hits': [{'doc_id': 5070, 'score': 153.0}, {'doc_id': 9208, 'score': 49.0}, {'doc_id': 6504, 'score': 45.0}, {'doc_id': 7798, 'score': 34.0}, {'doc_id': 7264, 'score': 28.0}, {'doc_id': 9424, 'score': 27.0}, {'doc_id': 4697, 'score': 26.0}, {'doc_id': 7714, 'score': 26.0}, {'doc_id': 9515, 'score': 26.0}, {'doc_id': 9891, 'score': 26.0}], 'total': 1111}
#
# Query: "medical"
# {'query': '"medical"', 'hits': [{'doc_id': 5070, 'score': 80.0}, {'doc_id': 9585, 'score': 45.0}, {'doc_id': 9235, 'score': 35.0}, {'doc_id': 114, 'score': 33.0}, {'doc_id': 9543, 'score': 33.0}, {'doc_id': 9690, 'score': 29.0}, {'doc_id': 9890, 'score': 23.0}, {'doc_id': 6504, 'score': 20.0}, {'doc_id': 9651, 'score': 18.0}, {'doc_id': 9853, 'score': 17.0}], 'total': 890}
#
# Query: "hospital"
# {'query': '"hospital"', 'hits': [{'doc_id': 5070, 'score': 126.0}, {'doc_id': 5601, 'score': 27.0}, {'doc_id': 7601, 'score': 26.0}, {'doc_id': 5385, 'score': 21.0}, {'doc_id': 4240, 'score': 20.0}, {'doc_id': 7000, 'score': 15.0}, {'doc_id': 9077, 'score': 14.0}, {'doc_id': 9305, 'score': 14.0}, {'doc_id': 9389, 'score': 14.0}, {'doc_id': 4648, 'score': 13.0}], 'total': 940}
#
# Query: "disease"
# {'query': '"disease"', 'hits': [], 'total': 0}
#
# Query: "pandemic"
# {'query': '"pandemic"', 'hits': [{'doc_id': 5988, 'score': 20.0}, {'doc_id': 3934, 'score': 9.0}, {'doc_id': 3773, 'score': 8.0}, {'doc_id': 7316, 'score': 8.0}, {'doc_id': 5070, 'score': 6.0}, {'doc_id': 9908, 'score': 6.0}, {'doc_id': 5631, 'score': 5.0}, {'doc_id': 6796, 'score': 5.0}, {'doc_id': 1665, 'score': 4.0}, {'doc_id': 3644, 'score': 4.0}], 'total': 158}
#
# Query: "nutrition"
# {'query': '"nutrition"', 'hits': [{'doc_id': 9834, 'score': 47.0}, {'doc_id': 9971, 'score': 11.0}, {'doc_id': 5928, 'score': 9.0}, {'doc_id': 9871, 'score': 8.0}, {'doc_id': 9031, 'score': 7.0}, {'doc_id': 8612, 'score': 6.0}, {'doc_id': 9684, 'score': 5.0}, {'doc_id': 9751, 'score': 5.0}, {'doc_id': 9165, 'score': 4.0}, {'doc_id': 9800, 'score': 4.0}], 'total': 80}
#
# Query: "vaccine"
# {'query': '"vaccine"', 'hits': [{'doc_id': 6649, 'score': 34.0}, {'doc_id': 6796, 'score': 21.0}, {'doc_id': 4391, 'score': 12.0}, {'doc_id': 9434, 'score': 12.0}, {'doc_id': 4718, 'score': 11.0}, {'doc_id': 9941, 'score': 11.0}, {'doc_id': 9352, 'score': 9.0}, {'doc_id': 9406, 'score': 8.0}, {'doc_id': 9741, 'score': 8.0}, {'doc_id': 4262, 'score': 7.0}], 'total': 63}
#
# Query: "wellbeing"
# {'query': '"wellbeing"', 'hits': [{'doc_id': 9208, 'score': 9.0}, {'doc_id': 9891, 'score': 9.0}, {'doc_id': 9303, 'score': 7.0}, {'doc_id': 9194, 'score': 6.0}, {'doc_id': 9515, 'score': 6.0}, {'doc_id': 7195, 'score': 5.0}, {'doc_id': 9164, 'score': 5.0}, {'doc_id': 9014, 'score': 4.0}, {'doc_id': 9055, 'score': 4.0}, {'doc_id': 9114, 'score': 4.0}], 'total': 289}
#
# Query: "mental health"
# {'query': '"mental health"', 'hits': [{'doc_id': 9375, 'score': 50.0}, {'doc_id': 5371, 'score': 35.0}, {'doc_id': 7798, 'score': 35.0}, {'doc_id': 5543, 'score': 33.0}, {'doc_id': 9515, 'score': 32.0}, {'doc_id': 5897, 'score': 30.0}, {'doc_id': 9002, 'score': 29.0}, {'doc_id': 9756, 'score': 29.0}, {'doc_id': 9527, 'score': 26.0}, {'doc_id': 9050, 'score': 24.0}], 'total': 193}
#
# Query: "treatment"
# {'query': '"treatment"', 'hits': [{'doc_id': 9912, 'score': 36.0}, {'doc_id': 9347, 'score': 20.0}, {'doc_id': 7212, 'score': 17.0}, {'doc_id': 9690, 'score': 17.0}, {'doc_id': 9995, 'score': 17.0}, {'doc_id': 5252, 'score': 16.0}, {'doc_id': 9235, 'score': 16.0}, {'doc_id': 9459, 'score': 16.0}, {'doc_id': 9585, 'score': 16.0}, {'doc_id': 9253, 'score': 14.0}], 'total': 549}
#
# Query: "crime prevention"
# {'query': '"crime prevention"', 'hits': [{'doc_id': 3055, 'score': 28.0}, {'doc_id': 3080, 'score': 27.0}, {'doc_id': 3081, 'score': 27.0}, {'doc_id': 3133, 'score': 27.0}, {'doc_id': 3287, 'score': 27.0}, {'doc_id': 3338, 'score': 27.0}, {'doc_id': 3548, 'score': 27.0}, {'doc_id': 3552, 'score': 27.0}, {'doc_id': 3044, 'score': 26.0}, {'doc_id': 3183, 'score': 26.0}], 'total': 22}
#
# Query: "law enforcement"
# {'query': '"law enforcement"', 'hits': [{'doc_id': 2646, 'score': 18.0}, {'doc_id': 516, 'score': 14.0}, {'doc_id': 1918, 'score': 13.0}, {'doc_id': 1177, 'score': 11.0}, {'doc_id': 9627, 'score': 9.0}, {'doc_id': 303, 'score': 7.0}, {'doc_id': 1963, 'score': 5.0}, {'doc_id': 3530, 'score': 5.0}, {'doc_id': 3472, 'score': 4.0}, {'doc_id': 4428, 'score': 4.0}], 'total': 14}
#
# Query: "traffic accident"
# {'query': '"traffic accident"', 'hits': [{'doc_id': 4068, 'score': 16.0}, {'doc_id': 5260, 'score': 15.0}, {'doc_id': 3997, 'score': 13.0}, {'doc_id': 4025, 'score': 5.0}, {'doc_id': 1629, 'score': 4.0}, {'doc_id': 1647, 'score': 4.0}, {'doc_id': 5332, 'score': 4.0}, {'doc_id': 5136, 'score': 2.0}], 'total': 8}
#
# Query: "financial fraud"
# {'query': '"financial fraud"', 'hits': [], 'total': 0}
#
# Query: "public health"
# {'query': '"public health"', 'hits': [{'doc_id': 5070, 'score': 165.0}, {'doc_id': 9424, 'score': 30.0}], 'total': 2}
#
# Query: "climate change"
# {'query': '"climate change"', 'hits': [{'doc_id': 3562, 'score': 68.0}, {'doc_id': 8804, 'score': 27.0}, {'doc_id': 8713, 'score': 24.0}, {'doc_id': 8248, 'score': 23.0}, {'doc_id': 9464, 'score': 21.0}, {'doc_id': 8505, 'score': 20.0}, {'doc_id': 9002, 'score': 20.0}, {'doc_id': 5835, 'score': 19.0}, {'doc_id': 8707, 'score': 16.0}, {'doc_id': 4817, 'score': 15.0}], 'total': 140}
#
# Query: "school education"
# {'query': '"school education"', 'hits': [{'doc_id': 1535, 'score': 31.0}, {'doc_id': 7217, 'score': 6.0}, {'doc_id': 5250, 'score': 4.0}], 'total': 3}
#
# Query: "economic growth"
# {'query': '"economic growth"', 'hits': [{'doc_id': 5914, 'score': 39.0}, {'doc_id': 7356, 'score': 17.0}, {'doc_id': 7690, 'score': 12.0}, {'doc_id': 5731, 'score': 6.0}, {'doc_id': 6415, 'score': 5.0}, {'doc_id': 7538, 'score': 5.0}, {'doc_id': 4479, 'score': 4.0}, {'doc_id': 4961, 'score': 4.0}, {'doc_id': 7272, 'score': 4.0}, {'doc_id': 7668, 'score': 4.0}], 'total': 19}
#
# Query: "corporate crime"
# {'query': '"corporate crime"', 'hits': [], 'total': 0}
#
# Query: "natural disaster"
# {'query': '"natural disaster"', 'hits': [], 'total': 0}
#
# Query: "emergency response"
# {'query': '"emergency response"', 'hits': [], 'total': 0}
#
# Query: "criminal investigation"
# {'query': '"criminal investigation"', 'hits': [{'doc_id': 1074, 'score': 14.0}, {'doc_id': 3471, 'score': 12.0}, {'doc_id': 670, 'score': 10.0}, {'doc_id': 2250, 'score': 10.0}, {'doc_id': 4452, 'score': 8.0}, {'doc_id': 2018, 'score': 7.0}, {'doc_id': 384, 'score': 6.0}, {'doc_id': 1451, 'score': 6.0}, {'doc_id': 5998, 'score': 6.0}, {'doc_id': 449, 'score': 5.0}], 'total': 40}
#
# Query: "environmental policy"
# {'query': '"environmental policy"', 'hits': [], 'total': 0}
#
# Query: "hospital management"
# {'query': '"hospital management"', 'hits': [{'doc_id': 5070, 'score': 160.0}, {'doc_id': 7601, 'score': 31.0}, {'doc_id': 7000, 'score': 25.0}, {'doc_id': 7282, 'score': 4.0}], 'total': 4}
#
# Query: "budget allocation"
# {'query': '"budget allocation"', 'hits': [{'doc_id': 3651, 'score': 2.0}], 'total': 1}
#
# Query: "disaster preparedness"
# {'query': '"disaster preparedness"', 'hits': [], 'total': 0}
#
# Query: "crime trends"
# {'query': '"crime trends"', 'hits': [], 'total': 0}
#
# Query: "workplace safety"
# {'query': '"workplace safety"', 'hits': [{'doc_id': 5070, 'score': 309.0}, {'doc_id': 4983, 'score': 14.0}, {'doc_id': 854, 'score': 3.0}], 'total': 3}
#
# Query: "community health programs"
# {'query': '"community health programs"', 'hits': [], 'total': 0}
#
# Query: "education policy reforms"
# {'query': '"education policy reforms"', 'hits': [], 'total': 0}
#
# Query: "sustainable development initiatives"
# {'query': '"sustainable development initiatives"', 'hits': [], 'total': 0}
#
# Query: "flood management strategies"
# {'query': '"flood management strategies"', 'hits': [], 'total': 0}
#
# Query: "earthquake preparedness plans"
# {'query': '"earthquake preparedness plans"', 'hits': [], 'total': 0}
#
# Query: "financial regulation compliance"
# {'query': '"financial regulation compliance"', 'hits': [], 'total': 0}
#
# Query: "pandemic response protocols"
# {'query': '"pandemic response protocols"', 'hits': [], 'total': 0}
#
# Query: "school safety protocols"
# {'query': '"school safety protocols"', 'hits': [], 'total': 0}
#
# Query: "emergency evacuation drills"
# {'query': '"emergency evacuation drills"', 'hits': [], 'total': 0}
#
# Query: "environmental conservation projects"
# {'query': '"environmental conservation projects"', 'hits': [], 'total': 0}
#
# Query: "corporate governance compliance"
# {'query': '"corporate governance compliance"', 'hits': [], 'total': 0}
#
# Query: "healthcare infrastructure improvement"
# {'query': '"healthcare infrastructure improvement"', 'hits': [], 'total': 0}
#
# Query: "economic policy analysis"
# {'query': '"economic policy analysis"', 'hits': [], 'total': 0}
#
# Query: "climate adaptation measures"
# {'query': '"climate adaptation measures"', 'hits': [], 'total': 0}
#
# Query: "crime and punishment analysis"
# {'query': '"crime and punishment analysis"', 'hits': [], 'total': 0}
#
# Query: "law reform implementation"
# {'query': '"law reform implementation"', 'hits': [], 'total': 0}
#
# Query: "disaster risk assessment"
# {'query': '"disaster risk assessment"', 'hits': [], 'total': 0}
#
# Query: "public safety monitoring"
# {'query': '"public safety monitoring"', 'hits': [], 'total': 0}
#
# Query: "urban crime trends"
# {'query': '"urban crime trends"', 'hits': [], 'total': 0}
#
# Query: "rural healthcare access"
# {'query': '"rural healthcare access"', 'hits': [], 'total': 0}
#
# Query: "educational equity programs"
# {'query': '"educational equity programs"', 'hits': [], 'total': 0}
#
# Query: "corporate social responsibility"
# {'query': '"corporate social responsibility"', 'hits': [], 'total': 0}
#
# Query: "natural disaster recovery plans"
# {'query': '"natural disaster recovery plans"', 'hits': [], 'total': 0}
#
# Query: "budget planning and allocation"
# {'query': '"budget planning and allocation"', 'hits': [], 'total': 0}
#
# Query: "environmental impact assessment"
# {'query': '"environmental impact assessment"', 'hits': [], 'total': 0}
#
# Query: "pollution control measures"
# {'query': '"pollution control measures"', 'hits': [], 'total': 0}
#
# Query: "food safety regulations"
# {'query': '"food safety regulations"', 'hits': [], 'total': 0}
#
# Query: "pandemic prevention strategies"
# {'query': '"pandemic prevention strategies"', 'hits': [], 'total': 0}
#
# Query: "student performance evaluation"
# {'query': '"student performance evaluation"', 'hits': [], 'total': 0}
#
# Query: "teacher training programs"
# {'query': '"teacher training programs"', 'hits': [], 'total': 0}
#
# Query: "school infrastructure development"
# {'query': '"school infrastructure development"', 'hits': [], 'total': 0}
#
# Query: "hospital emergency readiness"
# {'query': '"hospital emergency readiness"', 'hits': [], 'total': 0}
#
# Query: "financial market monitoring"
# {'query': '"financial market monitoring"', 'hits': [], 'total': 0}
#
# Query: "business investment strategies"
# {'query': '"business investment strategies"', 'hits': [], 'total': 0}
#
# Query: "renewable energy projects"
# {'query': '"renewable energy projects"', 'hits': [{'doc_id': 8077, 'score': 48.0}, {'doc_id': 5914, 'score': 36.0}, {'doc_id': 7816, 'score': 9.0}, {'doc_id': 631, 'score': 8.0}], 'total': 4}
#
# Query: "climate policy enforcement"
# {'query': '"climate policy enforcement"', 'hits': [], 'total': 0}
#
# Query: "deforestation prevention initiatives"
# {'query': '"deforestation prevention initiatives"', 'hits': [], 'total': 0}
#
# Query: "biodiversity protection programs"
# {'query': '"biodiversity protection programs"', 'hits': [], 'total': 0}
#
# Query: "crime investigation techniques"
# {'query': '"crime investigation techniques"', 'hits': [], 'total': 0}
#
# Query: "law enforcement technology"
# {'query': '"law enforcement technology"', 'hits': [], 'total': 0}
#
# Query: "emergency response coordination"
# {'query': '"emergency response coordination"', 'hits': [], 'total': 0}
#
# Query: "disaster relief operations"
# {'query': '"disaster relief operations"', 'hits': [], 'total': 0}
#
# Query: "financial auditing standards"
# {'query': '"financial auditing standards"', 'hits': [], 'total': 0}
#
# Query: "pandemic vaccination campaigns"
# {'query': '"pandemic vaccination campaigns"', 'hits': [], 'total': 0}
#
# Query: "school curriculum development"
# {'query': '"school curriculum development"', 'hits': [], 'total': 0}
#
# Query: "education quality assessment"
# {'query': '"education quality assessment"', 'hits': [], 'total': 0}
#
# Query: "economic growth planning"
# {'query': '"economic growth planning"', 'hits': [], 'total': 0}
#
# Query: "corporate fraud detection"
# {'query': '"corporate fraud detection"', 'hits': [], 'total': 0}
#
# Query: "workplace accident prevention"
# {'query': '"workplace accident prevention"', 'hits': [], 'total': 0}
#
# Query: "public health monitoring"
# {'query': '"public health monitoring"', 'hits': [], 'total': 0}
#
# Query: "environmental law compliance"
# {'query': '"environmental law compliance"', 'hits': [], 'total': 0}
#
# Query: "climate change mitigation"
# {'query': '"climate change mitigation"', 'hits': [], 'total': 0}
#
# Query: "natural disaster insurance"
# {'query': '"natural disaster insurance"', 'hits': [], 'total': 0}
#
# Query: "urban planning and safety"
# {'query': '"urban planning and safety"', 'hits': [], 'total': 0}
#
# Query: "crime" OR "fraud"
# {'query': '"crime" OR "fraud"', 'hits': [{'doc_id': 3810, 'score': 41.0}, {'doc_id': 3094, 'score': 32.0}, {'doc_id': 3055, 'score': 27.0}, {'doc_id': 3080, 'score': 26.0}, {'doc_id': 3081, 'score': 26.0}, {'doc_id': 3133, 'score': 26.0}, {'doc_id': 3287, 'score': 26.0}, {'doc_id': 3338, 'score': 26.0}, {'doc_id': 3548, 'score': 26.0}, {'doc_id': 3552, 'score': 26.0}], 'total': 923}
#
# Query: "law" AND "justice"
# {'query': '"law" AND "justice"', 'hits': [{'doc_id': 190, 'score': 54.0}, {'doc_id': 3415, 'score': 29.0}, {'doc_id': 1737, 'score': 28.0}, {'doc_id': 781, 'score': 27.0}, {'doc_id': 450, 'score': 26.0}, {'doc_id': 3306, 'score': 26.0}, {'doc_id': 1081, 'score': 21.0}, {'doc_id': 2646, 'score': 18.0}, {'doc_id': 604, 'score': 17.0}, {'doc_id': 4815, 'score': 17.0}], 'total': 211}
#
# Query: "police" AND NOT "corruption"
# {'query': '"police" AND NOT "corruption"', 'hits': [{'doc_id': 1918, 'score': 41.0}, {'doc_id': 3816, 'score': 32.0}, {'doc_id': 1761, 'score': 27.0}, {'doc_id': 3094, 'score': 26.0}, {'doc_id': 1331, 'score': 24.0}, {'doc_id': 218, 'score': 22.0}, {'doc_id': 5171, 'score': 22.0}, {'doc_id': 959, 'score': 21.0}, {'doc_id': 5732, 'score': 20.0}, {'doc_id': 1070, 'score': 19.0}], 'total': 1620}
#
# Query: ("financial fraud" OR "corporate crime") AND "regulation"
# {'query': '("financial fraud" OR "corporate crime") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("natural disaster" OR "emergency response") AND "community"
# {'query': '("natural disaster" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "public health" AND NOT "education"
# {'query': '"public health" AND NOT "education"', 'hits': [{'doc_id': 9424, 'score': 30.0}], 'total': 1}
#
# Query: ("crime prevention" OR "law enforcement") AND "urban areas"
# {'query': '("crime prevention" OR "law enforcement") AND "urban areas"', 'hits': [], 'total': 0}
#
# Query: "climate change" AND "environmental policy"
# {'query': '"climate change" AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: "school education" AND "safety protocols"
# {'query': '"school education" AND "safety protocols"', 'hits': [], 'total': 0}
#
# Query: ("healthcare reforms" OR "hospital management") AND "rural areas"
# {'query': '("healthcare reforms" OR "hospital management") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: "economic growth" AND NOT "corruption"
# {'query': '"economic growth" AND NOT "corruption"', 'hits': [{'doc_id': 7356, 'score': 17.0}, {'doc_id': 7690, 'score': 12.0}, {'doc_id': 5731, 'score': 6.0}, {'doc_id': 6415, 'score': 5.0}, {'doc_id': 7538, 'score': 5.0}, {'doc_id': 4479, 'score': 4.0}, {'doc_id': 4961, 'score': 4.0}, {'doc_id': 7272, 'score': 4.0}, {'doc_id': 7668, 'score': 4.0}, {'doc_id': 9143, 'score': 4.0}], 'total': 18}
#
# Query: ("disaster preparedness" OR "emergency response") AND "community"
# {'query': '("disaster preparedness" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "corporate crime" AND "financial regulation"
# {'query': '"corporate crime" AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("budget allocation" OR "financial planning") AND "government policy"
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 40.0}, {'doc_id': 2873, 'score': 14.0}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 82.0}, {'doc_id': 8077, 'score': 49.0}, {'doc_id': 9002, 'score': 23.0}, {'doc_id': 8103, 'score': 13.0}, {'doc_id': 7659, 'score': 12.0}, {'doc_id': 7684, 'score': 12.0}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 11.0}, {'doc_id': 3530, 'score': 6.0}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 19.0}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 7214, 'score': 13.0}, {'doc_id': 8398, 'score': 10.0}, {'doc_id': 4448, 'score': 5.0}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 47.0}, {'doc_id': 7675, 'score': 24.0}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# {'query': '("corporate crime" OR "financial fraud") AND NOT "minor offenses"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government policy"
# {'query': '("environmental law" OR "pollution control") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency evacuation") AND "community safety"
# {'query': '("disaster preparedness" OR "emergency evacuation") AND "community safety"', 'hits': [], 'total': 0}
#
# Query: ("healthcare access" OR "hospital readiness") AND "rural areas"
# {'query': '("healthcare access" OR "hospital readiness") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget planning") AND "national development"
# {'query': '("economic policy" OR "budget planning") AND "national development"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 18.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 10.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 18.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 10.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# ...
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 40.0}, {'doc_id': 2873, 'score': 14.0}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 82.0}, {'doc_id': 8077, 'score': 49.0}, {'doc_id': 9002, 'score': 23.0}, {'doc_id': 8103, 'score': 13.0}, {'doc_id': 7659, 'score': 12.0}, {'doc_id': 7684, 'score': 12.0}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 11.0}, {'doc_id': 3530, 'score': 6.0}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 19.0}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 7214, 'score': 13.0}, {'doc_id': 8398, 'score': 10.0}, {'doc_id': 4448, 'score': 5.0}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 47.0}, {'doc_id': 7675, 'score': 24.0}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# {'query': '("corporate crime" OR "financial fraud") AND NOT "minor offenses"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government policy"
# {'query': '("environmental law" OR "pollution control") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency evacuation") AND "community safety"
# {'query': '("disaster preparedness" OR "emergency evacuation") AND "community safety"', 'hits': [], 'total': 0}
#
# Query: ("healthcare access" OR "hospital readiness") AND "rural areas"
# {'query': '("healthcare access" OR "hospital readiness") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget planning") AND "national development"
# {'query': '("economic policy" OR "budget planning") AND "national development"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 18.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 10.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 18.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 10.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 18.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 10.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}

# %%
#graph part c
import time
import numpy as np
import matplotlib.pyplot as plt

# ---------- Load queries ----------
with open("queries.txt", "r", encoding="utf8") as f:
    queries = [q.strip() for q in f.readlines() if q.strip()]

sample_queries = queries[:200]  

# ---------- Load two indices ----------
si_code = SelfIndex()
si_code.load_index("./selfindex_store/SelfIndex-v1.x2.y1.z2.i0.qT0")

si_clib = SelfIndex()
si_clib.load_index("./selfindex_store/SelfIndex-v1.x2.y1.z3.i0.qT0")

# ---------- Measure response times ----------
def measure_latency(si, queries):
    times = []
    for q in queries:
        t0 = time.perf_counter()
        _ = si.query(q, k=5)
        t1 = time.perf_counter()
        times.append(t1 - t0)
    return np.array(times)

lat_code = measure_latency(si_code, sample_queries)
lat_clib = measure_latency(si_clib, sample_queries)

# ---------- Compute latency metrics ----------
p95_code, p99_code = np.percentile(lat_code, [95, 99])
p95_clib, p99_clib = np.percentile(lat_clib, [95, 99])

# ---------- Compute throughput ----------
throughput_code = len(sample_queries) / np.sum(lat_code)
throughput_clib = len(sample_queries) / np.sum(lat_clib)

# ---------- Add Elasticsearch metrics (from measured data) ----------
p95_es = 0.0327585
p99_es = 0.0339084
throughput_es = 42.86

# ---------- Plot A: Latency (p95, p99) ----------
plt.figure(figsize=(8,6))
labels = ['CODE_p95','CODE_p99','CLIB_p95','CLIB_p99','ES_p95','ES_p99']
values = [p95_code, p99_code, p95_clib, p99_clib, p95_es, p99_es]
plt.bar(labels, values, color=['skyblue','skyblue','orange','orange','lightgreen','lightgreen'])
plt.ylabel("Latency (seconds)")
plt.title("Plot.A: Response Time (p95, p99) Comparison")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# ---------- Plot B: Throughput ----------
plt.figure(figsize=(8,6))
plt.bar(['CODE','CLIB','Elasticsearch'], [throughput_code, throughput_clib, throughput_es],
        color=['skyblue','orange','lightgreen'])
plt.ylabel("Queries per second")
plt.title("Plot.B: System Throughput Comparison")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# ---------- Print numeric summary ----------
print("\n=== Response Time (Latency) ===")
print(f"CODE : p95={p95_code:.5f}s, p99={p99_code:.5f}s")
print(f"CLIB : p95={p95_clib:.5f}s, p99={p99_clib:.5f}s")
print(f"Elasticsearch : p95={p95_es:.5f}s, p99={p99_es:.5f}s")

print("\n=== Throughput (Queries/sec) ===")
print(f"CODE : {throughput_code:.2f}")
print(f"CLIB : {throughput_clib:.2f}")
print(f"Elasticsearch : {throughput_es:.2f}")
# Out:
# [SelfIndex] Loaded index 'SelfIndex-v1.x2.y1.z2.i0.qT0' (N=10000, terms=134822)
# [SelfIndex] Loaded index 'SelfIndex-v1.x2.y1.z3.i0.qT0' (N=10000, terms=134822)
# === Response Time (Latency) ===
# CODE : p95=0.00151s, p99=0.00212s
# CLIB : p95=0.00142s, p99=0.00192s
# Elasticsearch : p95=0.03276s, p99=0.03391s
#
# === Throughput (Queries/sec) ===
# CODE : 1906.22
# CLIB : 1979.34
# Elasticsearch : 42.86

# %%
#graph part d
# --- Prepare files iterable: (doc_id, text) for full dataset ---
files_iterable = [(int(idx), txt) for idx, txt in zip(subset.index, subset['clean_text'])]

# --- Load queries from file ---
with open("queries.txt", "r") as f:
    queries = [line.strip() for line in f if line.strip()]

# --- Dictionary to store results ---
all_results = {}

# --- Iterate over all versions ---
for version in VERSION_CONFIG.keys():
    print(f"\n=== Processing version {version} ===")
    
    # Create SelfIndex instance using the version
    si = SelfIndex(version=version)
    
    # Build or load index for the full dataset
    index_id = f"SelfIndex-{version}"
    
    if index_id in SelfIndex.list_indices():
        print("🟢 Loading existing index...")
        si.load_index(f"./selfindex_store/{index_id}")
    else:
        print("🟡 Building new index...")
        si.create_index(index_id, files_iterable)
    
    # Run queries and store results
    version_results = {}
    for q in queries:
        res = si.query(q, k=10)
        version_results[q] = res
        print(f"\nQuery: {q}")
        print(res)
    
    all_results[version] = version_results

# --- all_results now has results for all versions and all queries ---
# Out:
# === Processing version v1.x3.y1.z1.i0.qT0 ===
# 🟢 Loading existing index...
# [SelfIndex] Loaded index 'SelfIndex-v1.x3.y1.z1.i0.qT0' (N=10000, terms=134822)
#
# Query: "crime"
# {'query': '"crime"', 'hits': [{'doc_id': 3810, 'score': 16.37348525091507}, {'doc_id': 3094, 'score': 15.67893093032366}, {'doc_id': 3055, 'score': 15.08242560152141}, {'doc_id': 3080, 'score': 14.94992157338131}, {'doc_id': 3081, 'score': 14.94992157338131}, {'doc_id': 3133, 'score': 14.94992157338131}, {'doc_id': 3287, 'score': 14.94992157338131}, {'doc_id': 3338, 'score': 14.94992157338131}, {'doc_id': 3548, 'score': 14.94992157338131}, {'doc_id': 3552, 'score': 14.94992157338131}], 'total': 811}
#
# Query: "law"
# {'query': '"law"', 'hits': [{'doc_id': 3306, 'score': 13.956316512927385}, {'doc_id': 3636, 'score': 13.510269990897626}, {'doc_id': 1081, 'score': 12.995347070870773}, {'doc_id': 3415, 'score': 12.995347070870773}, {'doc_id': 7017, 'score': 12.995347070870773}, {'doc_id': 2646, 'score': 12.80441585090112}, {'doc_id': 3160, 'score': 12.80441585090112}, {'doc_id': 3323, 'score': 12.80441585090112}, {'doc_id': 3418, 'score': 12.80441585090112}, {'doc_id': 3661, 'score': 12.80441585090112}], 'total': 962}
#
# Query: "justice"
# {'query': '"justice"', 'hits': [{'doc_id': 190, 'score': 19.1683933129406}, {'doc_id': 1737, 'score': 16.616548643007054}, {'doc_id': 781, 'score': 16.304194629024714}, {'doc_id': 450, 'score': 15.783109477220046}, {'doc_id': 604, 'score': 13.911651339788746}, {'doc_id': 996, 'score': 13.599297325806408}, {'doc_id': 1922, 'score': 13.599297325806408}, {'doc_id': 1325, 'score': 13.259749181387162}, {'doc_id': 3415, 'score': 13.259749181387162}, {'doc_id': 5703, 'score': 12.887816270812948}], 'total': 548}
#
# Query: "corporate crime"
# {'query': '"corporate crime"', 'hits': [], 'total': 0}
#
# Query: "natural disaster"
# {'query': '"natural disaster"', 'hits': [], 'total': 0}
#
# Query: "emergency response"
# {'query': '"emergency response"', 'hits': [], 'total': 0}
#
# Query: "criminal investigation"
# {'query': '"criminal investigation"', 'hits': [{'doc_id': 1074, 'score': 19.987374514498995}, {'doc_id': 3471, 'score': 18.345902753882406}, {'doc_id': 4452, 'score': 15.827096000546993}, {'doc_id': 2250, 'score': 15.798448862519292}, {'doc_id': 2018, 'score': 14.336931001783384}, {'doc_id': 1451, 'score': 14.238638536817033}, {'doc_id': 384, 'score': 13.64304639013234}, {'doc_id': 670, 'score': 13.617251739385296}, {'doc_id': 2631, 'score': 12.748473538053425}, {'doc_id': 5998, 'score': 11.789477110420268}], 'total': 40}
#
# Query: "environmental policy"
# {'query': '"environmental policy"', 'hits': [], 'total': 0}
#
# Query: "hospital management"
# {'query': '"hospital management"', 'hits': [{'doc_id': 5070, 'score': 34.825949749549004}, {'doc_id': 7000, 'score': 23.559261296329773}, {'doc_id': 7601, 'score': 23.08234761682513}, {'doc_id': 7282, 'score': 10.415817888094594}], 'total': 4}
#
# Query: "budget allocation"
# {'query': '"budget allocation"', 'hits': [{'doc_id': 3651, 'score': 11.029219305516477}], 'total': 1}
#
# Query: "disaster preparedness"
# {'query': '"disaster preparedness"', 'hits': [], 'total': 0}
#
# Query: "crime trends"
# {'query': '"crime trends"', 'hits': [], 'total': 0}
#
# Query: "workplace safety"
# {'query': '"workplace safety"', 'hits': [{'doc_id': 5070, 'score': 39.49378943539233}, {'doc_id': 4983, 'score': 24.598447178981075}, {'doc_id': 854, 'score': 13.621246949303334}], 'total': 3}
#
# Query: "community health programs"
# {'query': '"community health programs"', 'hits': [], 'total': 0}
#
# Query: "education policy reforms"
# {'query': '"education policy reforms"', 'hits': [], 'total': 0}
#
# Query: "sustainable development initiatives"
# {'query': '"sustainable development initiatives"', 'hits': [], 'total': 0}
#
# Query: "flood management strategies"
# {'query': '"flood management strategies"', 'hits': [], 'total': 0}
#
# Query: "earthquake preparedness plans"
# {'query': '"earthquake preparedness plans"', 'hits': [], 'total': 0}
#
# Query: "financial regulation compliance"
# {'query': '"financial regulation compliance"', 'hits': [], 'total': 0}
#
# Query: "pandemic response protocols"
# {'query': '"pandemic response protocols"', 'hits': [], 'total': 0}
#
# Query: "school safety protocols"
# {'query': '"school safety protocols"', 'hits': [], 'total': 0}
#
# Query: "emergency evacuation drills"
# {'query': '"emergency evacuation drills"', 'hits': [], 'total': 0}
#
# Query: "environmental conservation projects"
# {'query': '"environmental conservation projects"', 'hits': [], 'total': 0}
#
# Query: "corporate governance compliance"
# {'query': '"corporate governance compliance"', 'hits': [], 'total': 0}
#
# Query: "healthcare infrastructure improvement"
# {'query': '"healthcare infrastructure improvement"', 'hits': [], 'total': 0}
#
# Query: "economic policy analysis"
# {'query': '"economic policy analysis"', 'hits': [], 'total': 0}
#
# Query: "climate adaptation measures"
# {'query': '"climate adaptation measures"', 'hits': [], 'total': 0}
#
# Query: "crime and punishment analysis"
# {'query': '"crime and punishment analysis"', 'hits': [], 'total': 0}
#
# Query: "law reform implementation"
# {'query': '"law reform implementation"', 'hits': [], 'total': 0}
#
# Query: "disaster risk assessment"
# {'query': '"disaster risk assessment"', 'hits': [], 'total': 0}
#
# Query: "public safety monitoring"
# {'query': '"public safety monitoring"', 'hits': [], 'total': 0}
#
# Query: "urban crime trends"
# {'query': '"urban crime trends"', 'hits': [], 'total': 0}
#
# Query: "rural healthcare access"
# {'query': '"rural healthcare access"', 'hits': [], 'total': 0}
#
# Query: "educational equity programs"
# {'query': '"educational equity programs"', 'hits': [], 'total': 0}
#
# Query: "corporate social responsibility"
# {'query': '"corporate social responsibility"', 'hits': [], 'total': 0}
#
# Query: "natural disaster recovery plans"
# {'query': '"natural disaster recovery plans"', 'hits': [], 'total': 0}
#
# Query: "budget planning and allocation"
# {'query': '"budget planning and allocation"', 'hits': [], 'total': 0}
#
# Query: "environmental impact assessment"
# {'query': '"environmental impact assessment"', 'hits': [], 'total': 0}
#
# Query: "pollution control measures"
# {'query': '"pollution control measures"', 'hits': [], 'total': 0}
#
# Query: "food safety regulations"
# {'query': '"food safety regulations"', 'hits': [], 'total': 0}
#
# Query: "pandemic prevention strategies"
# {'query': '"pandemic prevention strategies"', 'hits': [], 'total': 0}
#
# Query: "student performance evaluation"
# {'query': '"student performance evaluation"', 'hits': [], 'total': 0}
#
# Query: "teacher training programs"
# {'query': '"teacher training programs"', 'hits': [], 'total': 0}
#
# Query: "school infrastructure development"
# {'query': '"school infrastructure development"', 'hits': [], 'total': 0}
#
# Query: "hospital emergency readiness"
# {'query': '"hospital emergency readiness"', 'hits': [], 'total': 0}
#
# Query: "financial market monitoring"
# {'query': '"financial market monitoring"', 'hits': [], 'total': 0}
#
# Query: "business investment strategies"
# {'query': '"business investment strategies"', 'hits': [], 'total': 0}
#
# Query: "renewable energy projects"
# {'query': '"renewable energy projects"', 'hits': [{'doc_id': 5914, 'score': 47.84762268424676}, {'doc_id': 8077, 'score': 45.39989213714567}, {'doc_id': 7816, 'score': 25.371520290224463}, {'doc_id': 631, 'score': 20.86104887429827}], 'total': 4}
#
# Query: "climate policy enforcement"
# {'query': '"climate policy enforcement"', 'hits': [], 'total': 0}
#
# Query: "deforestation prevention initiatives"
# {'query': '"deforestation prevention initiatives"', 'hits': [], 'total': 0}
#
# Query: "biodiversity protection programs"
# {'query': '"biodiversity protection programs"', 'hits': [], 'total': 0}
#
# Query: "crime investigation techniques"
# {'query': '"crime investigation techniques"', 'hits': [], 'total': 0}
#
# Query: "law enforcement technology"
# {'query': '"law enforcement technology"', 'hits': [], 'total': 0}
#
# Query: "emergency response coordination"
# {'query': '"emergency response coordination"', 'hits': [], 'total': 0}
#
# Query: "disaster relief operations"
# {'query': '"disaster relief operations"', 'hits': [], 'total': 0}
#
# Query: "financial auditing standards"
# {'query': '"financial auditing standards"', 'hits': [], 'total': 0}
#
# Query: "pandemic vaccination campaigns"
# {'query': '"pandemic vaccination campaigns"', 'hits': [], 'total': 0}
#
# Query: "school curriculum development"
# {'query': '"school curriculum development"', 'hits': [], 'total': 0}
#
# Query: "education quality assessment"
# {'query': '"education quality assessment"', 'hits': [], 'total': 0}
#
# Query: "economic growth planning"
# {'query': '"economic growth planning"', 'hits': [], 'total': 0}
#
# Query: "corporate fraud detection"
# {'query': '"corporate fraud detection"', 'hits': [], 'total': 0}
#
# Query: "workplace accident prevention"
# {'query': '"workplace accident prevention"', 'hits': [], 'total': 0}
#
# Query: "public health monitoring"
# {'query': '"public health monitoring"', 'hits': [], 'total': 0}
#
# Query: "environmental law compliance"
# {'query': '"environmental law compliance"', 'hits': [], 'total': 0}
#
# Query: "climate change mitigation"
# {'query': '"climate change mitigation"', 'hits': [], 'total': 0}
#
# Query: "natural disaster insurance"
# {'query': '"natural disaster insurance"', 'hits': [], 'total': 0}
#
# Query: "urban planning and safety"
# {'query': '"urban planning and safety"', 'hits': [], 'total': 0}
#
# Query: "crime" OR "fraud"
# {'query': '"crime" OR "fraud"', 'hits': [{'doc_id': 3810, 'score': 25.068247334421997}, {'doc_id': 3890, 'score': 24.138129088589878}, {'doc_id': 3415, 'score': 22.70674001126624}, {'doc_id': 1457, 'score': 21.758291354552004}, {'doc_id': 2700, 'score': 20.280967230354356}, {'doc_id': 3522, 'score': 19.37324867879964}, {'doc_id': 1855, 'score': 19.34469743808871}, {'doc_id': 33, 'score': 16.721471698590122}, {'doc_id': 358, 'score': 16.721471698590122}, {'doc_id': 190, 'score': 16.06286396855729}], 'total': 923}
#
# Query: "law" AND "justice"
# {'query': '"law" AND "justice"', 'hits': [{'doc_id': 190, 'score': 27.139539868041236}, {'doc_id': 3415, 'score': 26.255096252257935}, {'doc_id': 450, 'score': 24.499641840262846}, {'doc_id': 781, 'score': 23.314371742068737}, {'doc_id': 1737, 'score': 22.272315398146567}, {'doc_id': 604, 'score': 21.88279789488938}, {'doc_id': 3810, 'score': 21.85751366815391}, {'doc_id': 1922, 'score': 21.570443880907042}, {'doc_id': 4815, 'score': 21.220446861439708}, {'doc_id': 1081, 'score': 21.184849790240563}], 'total': 211}
#
# Query: "police" AND NOT "corruption"
# {'query': '"police" AND NOT "corruption"', 'hits': [], 'total': 0}
#
# Query: ("financial fraud" OR "corporate crime") AND "regulation"
# {'query': '("financial fraud" OR "corporate crime") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("natural disaster" OR "emergency response") AND "community"
# {'query': '("natural disaster" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "public health" AND NOT "education"
# {'query': '"public health" AND NOT "education"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "law enforcement") AND "urban areas"
# {'query': '("crime prevention" OR "law enforcement") AND "urban areas"', 'hits': [], 'total': 0}
#
# Query: "climate change" AND "environmental policy"
# {'query': '"climate change" AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: "school education" AND "safety protocols"
# {'query': '"school education" AND "safety protocols"', 'hits': [], 'total': 0}
#
# Query: ("healthcare reforms" OR "hospital management") AND "rural areas"
# {'query': '("healthcare reforms" OR "hospital management") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: "economic growth" AND NOT "corruption"
# {'query': '"economic growth" AND NOT "corruption"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency response") AND "community"
# {'query': '("disaster preparedness" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "corporate crime" AND "financial regulation"
# {'query': '"corporate crime" AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("budget allocation" OR "financial planning") AND "government policy"
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 31.634395740690806}, {'doc_id': 2873, 'score': 27.527129654333727}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 73.86875709020813}, {'doc_id': 8077, 'score': 54.95479101972046}, {'doc_id': 8103, 'score': 45.281769346654436}, {'doc_id': 9002, 'score': 42.08884833876811}, {'doc_id': 7684, 'score': 33.49769589066067}, {'doc_id': 7659, 'score': 31.060712142377852}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 23.357695038743042}, {'doc_id': 3530, 'score': 15.956900593669573}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 39.861529152043815}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 7214, 'score': 31.725380895960487}, {'doc_id': 8398, 'score': 28.459483946548797}, {'doc_id': 4448, 'score': 17.99358781406781}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 48.878056500251894}, {'doc_id': 7675, 'score': 39.22464395259123}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# ...
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits':
# ---------- Measure response times ----------
def measure_latency(si, queries):
    times = []
    for q in queries:
        t0 = time.perf_counter()
        _ = si.query(q, k=5)
        t1 = time.perf_counter()
        times.append(t1 - t0)
    return np.array(times)

lat_code = measure_latency(si_code, queries)
lat_clib = measure_latency(si_clib, queries)

# ---------- Compute latency metrics ----------
p95_code, p99_code = np.percentile(lat_code, [95, 99])
p95_clib, p99_clib = np.percentile(lat_clib, [95, 99])


# ---------- Add Elasticsearch metrics (from measured data) ----------
p95_es = 0.0327585
p99_es = 0.0339084

# ---------- Plot A: Latency (p95, p99) ----------
plt.figure(figsize=(8,6))
labels = ['NoOpti_p95','NoOpti_p99','Skipping_p95','Skipping_p99','ES_p95','ES_p99']
values = [p95_code, p99_code, p95_clib, p99_clib, p95_es, p99_es]
plt.bar(labels, values, color=['skyblue','skyblue','orange','orange','lightgreen','lightgreen'])
plt.ylabel("Latency (seconds)")
plt.title("Plot.A: Response Time (p95, p99) Comparison")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# ---------- Print numeric summary ----------
print("\n=== Response Time (Latency) ===")
print(f"Without Optimization : p95={p95_code:.5f}s, p99={p99_code:.5f}s")
print(f"Skipping Pointers : p95={p95_clib:.5f}s, p99={p99_clib:.5f}s")
print(f"Elasticsearch : p95={p95_es:.5f}s, p99={p99_es:.5f}s")
# Out:
# [SelfIndex] Loaded index 'SelfIndex-v1.x3.y1.z1.i0.qT0' (N=10000, terms=134822)
# [SelfIndex] Loaded index 'SelfIndex-v1.x3.y1.z1.i1.qT1' (N=10000, terms=134822)
# === Response Time (Latency) ===
# Without Optimization : p95=0.00156s, p99=0.00191s
# Skipping Pointers : p95=0.00111s, p99=0.00154s
# Elasticsearch : p95=0.03276s, p99=0.03391s

# %%
#graph part e
# --- Prepare files iterable: (doc_id, text) for full dataset ---
files_iterable = [(int(idx), txt) for idx, txt in zip(subset.index, subset['clean_text'])]

# --- Load queries from file ---
with open("queries.txt", "r") as f:
    queries = [line.strip() for line in f if line.strip()]

# --- Dictionary to store results ---
all_results = {}

# --- Iterate over all versions ---
for version in VERSION_CONFIG.keys():
    print(f"\n=== Processing version {version} ===")
    
    # Create SelfIndex instance using the version
    si = SelfIndex(version=version)
    
    # Build or load index for the full dataset
    index_id = f"SelfIndex-{version}"
    
    if index_id in SelfIndex.list_indices():
        print("🟢 Loading existing index...")
        si.load_index(f"./selfindex_store/{index_id}")
    else:
        print("🟡 Building new index...")
        si.create_index(index_id, files_iterable)
    
    # Run queries and store results
    version_results = {}
    for q in queries:
        res = si.query(q, k=10)
        version_results[q] = res
        print(f"\nQuery: {q}")
        print(res)
    
    all_results[version] = version_results

# --- all_results now has results for all versions and all queries ---
# Out:
# === Processing version v1.x3.y1.z1.i0.qT0 ===
# 🟢 Loading existing index...
# [SelfIndex] Loaded index 'SelfIndex-v1.x3.y1.z1.i0.qT0' (N=10000, terms=134822)
#
# Query: "crime"
# {'query': '"public health"', 'hits': [{'doc_id': 5070, 'score': 29.76087039235026}, {'doc_id': 9424, 'score': 20.045475015785755}], 'total': 2}
#
# Query: "climate change"
# {'query': '"climate change"', 'hits': [{'doc_id': 3562, 'score': 33.175320881147414}, {'doc_id': 8804, 'score': 28.780237029761707}, {'doc_id': 8248, 'score': 27.93184980401307}, {'doc_id': 8713, 'score': 27.834362354863337}, {'doc_id': 9464, 'score': 27.25199846655837}, {'doc_id': 8505, 'score': 26.87172718037371}, {'doc_id': 5835, 'score': 26.400090795473524}, {'doc_id': 9002, 'score': 26.303638873854403}, {'doc_id': 8707, 'score': 24.94542130386384}, {'doc_id': 4817, 'score': 24.541320708373057}], 'total': 140}
#
# Query: "school education"
# {'query': '"school education"', 'hits': [{'doc_id': 1535, 'score': 22.541909962643444}, {'doc_id': 7217, 'score': 13.829515749269792}, {'doc_id': 5250, 'score': 10.737161939558169}], 'total': 3}
#
# Query: "economic growth"
# {'query': '"economic growth"', 'hits': [{'doc_id': 5914, 'score': 35.820621393643094}, {'doc_id': 7356, 'score': 27.75065774671542}, {'doc_id': 7690, 'score': 24.88318228783926}, {'doc_id': 5731, 'score': 19.078688221986148}, {'doc_id': 6415, 'score': 17.258097747672576}, {'doc_id': 7668, 'score': 15.392565528308843}, {'doc_id': 7538, 'score': 15.315737107692556}, {'doc_id': 4479, 'score': 14.145777774906628}, {'doc_id': 4961, 'score': 14.145777774906628}, {'doc_id': 9143, 'score': 14.145777774906628}], 'total': 19}
#
# Query: "corporate crime"
# {'query': '"corporate crime"', 'hits': [], 'total': 0}
#
# Query: "natural disaster"
# {'query': '"natural disaster"', 'hits': [], 'total': 0}
#
# Query: "emergency response"
# {'query': '"emergency response"', 'hits': [], 'total': 0}
#
# Query: "criminal investigation"
# {'query': '"criminal investigation"', 'hits': [{'doc_id': 1074, 'score': 19.987374514498995}, {'doc_id': 3471, 'score': 18.345902753882406}, {'doc_id': 4452, 'score': 15.827096000546993}, {'doc_id': 2250, 'score': 15.798448862519292}, {'doc_id': 2018, 'score': 14.336931001783384}, {'doc_id': 1451, 'score': 14.238638536817033}, {'doc_id': 384, 'score': 13.64304639013234}, {'doc_id': 670, 'score': 13.617251739385296}, {'doc_id': 2631, 'score': 12.748473538053425}, {'doc_id': 5998, 'score': 11.789477110420268}], 'total': 40}
#
# Query: "environmental policy"
# {'query': '"environmental policy"', 'hits': [], 'total': 0}
#
# Query: "hospital management"
# {'query': '"hospital management"', 'hits': [{'doc_id': 5070, 'score': 34.825949749549004}, {'doc_id': 7000, 'score': 23.559261296329773}, {'doc_id': 7601, 'score': 23.08234761682513}, {'doc_id': 7282, 'score': 10.415817888094594}], 'total': 4}
#
# Query: "budget allocation"
# {'query': '"budget allocation"', 'hits': [{'doc_id': 3651, 'score': 11.029219305516477}], 'total': 1}
#
# Query: "disaster preparedness"
# {'query': '"disaster preparedness"', 'hits': [], 'total': 0}
#
# Query: "crime trends"
# {'query': '"crime trends"', 'hits': [], 'total': 0}
#
# Query: "workplace safety"
# {'query': '"workplace safety"', 'hits': [{'doc_id': 5070, 'score': 39.49378943539233}, {'doc_id': 4983, 'score': 24.598447178981075}, {'doc_id': 854, 'score': 13.621246949303334}], 'total': 3}
#
# Query: "community health programs"
# {'query': '"community health programs"', 'hits': [], 'total': 0}
#
# Query: "education policy reforms"
# {'query': '"education policy reforms"', 'hits': [], 'total': 0}
#
# Query: "sustainable development initiatives"
# {'query': '"sustainable development initiatives"', 'hits': [], 'total': 0}
#
# Query: "flood management strategies"
# {'query': '"flood management strategies"', 'hits': [], 'total': 0}
#
# Query: "earthquake preparedness plans"
# {'query': '"earthquake preparedness plans"', 'hits': [], 'total': 0}
#
# Query: "financial regulation compliance"
# {'query': '"financial regulation compliance"', 'hits': [], 'total': 0}
#
# Query: "pandemic response protocols"
# {'query': '"pandemic response protocols"', 'hits': [], 'total': 0}
#
# Query: "school safety protocols"
# {'query': '"school safety protocols"', 'hits': [], 'total': 0}
#
# Query: "emergency evacuation drills"
# {'query': '"emergency evacuation drills"', 'hits': [], 'total': 0}
#
# Query: "environmental conservation projects"
# {'query': '"environmental conservation projects"', 'hits': [], 'total': 0}
#
# Query: "corporate governance compliance"
# {'query': '"corporate governance compliance"', 'hits': [], 'total': 0}
#
# Query: "healthcare infrastructure improvement"
# {'query': '"healthcare infrastructure improvement"', 'hits': [], 'total': 0}
#
# Query: "economic policy analysis"
# {'query': '"economic policy analysis"', 'hits': [], 'total': 0}
#
# Query: "climate adaptation measures"
# {'query': '"climate adaptation measures"', 'hits': [], 'total': 0}
#
# Query: "crime and punishment analysis"
# {'query': '"crime and punishment analysis"', 'hits': [], 'total': 0}
#
# Query: "law reform implementation"
# {'query': '"law reform implementation"', 'hits': [], 'total': 0}
#
# Query: "disaster risk assessment"
# {'query': '"disaster risk assessment"', 'hits': [], 'total': 0}
#
# Query: "public safety monitoring"
# {'query': '"public safety monitoring"', 'hits': [], 'total': 0}
#
# Query: "urban crime trends"
# {'query': '"urban crime trends"', 'hits': [], 'total': 0}
#
# Query: "rural healthcare access"
# {'query': '"rural healthcare access"', 'hits': [], 'total': 0}
#
# Query: "educational equity programs"
# {'query': '"educational equity programs"', 'hits': [], 'total': 0}
#
# Query: "corporate social responsibility"
# {'query': '"corporate social responsibility"', 'hits': [], 'total': 0}
#
# Query: "natural disaster recovery plans"
# {'query': '"natural disaster recovery plans"', 'hits': [], 'total': 0}
#
# Query: "budget planning and allocation"
# {'query': '"budget planning and allocation"', 'hits': [], 'total': 0}
#
# Query: "environmental impact assessment"
# {'query': '"environmental impact assessment"', 'hits': [], 'total': 0}
#
# Query: "pollution control measures"
# {'query': '"pollution control measures"', 'hits': [], 'total': 0}
#
# Query: "food safety regulations"
# {'query': '"food safety regulations"', 'hits': [], 'total': 0}
#
# Query: "pandemic prevention strategies"
# {'query': '"pandemic prevention strategies"', 'hits': [], 'total': 0}
#
# Query: "student performance evaluation"
# {'query': '"student performance evaluation"', 'hits': [], 'total': 0}
#
# Query: "teacher training programs"
# {'query': '"teacher training programs"', 'hits': [], 'total': 0}
#
# Query: "school infrastructure development"
# {'query': '"school infrastructure development"', 'hits': [], 'total': 0}
#
# Query: "hospital emergency readiness"
# {'query': '"hospital emergency readiness"', 'hits': [], 'total': 0}
#
# Query: "financial market monitoring"
# {'query': '"financial market monitoring"', 'hits': [], 'total': 0}
#
# Query: "business investment strategies"
# {'query': '"business investment strategies"', 'hits': [], 'total': 0}
#
# Query: "renewable energy projects"
# {'query': '"renewable energy projects"', 'hits': [{'doc_id': 5914, 'score': 47.84762268424676}, {'doc_id': 8077, 'score': 45.39989213714567}, {'doc_id': 7816, 'score': 25.371520290224463}, {'doc_id': 631, 'score': 20.86104887429827}], 'total': 4}
#
# Query: "climate policy enforcement"
# {'query': '"climate policy enforcement"', 'hits': [], 'total': 0}
#
# Query: "deforestation prevention initiatives"
# {'query': '"deforestation prevention initiatives"', 'hits': [], 'total': 0}
#
# Query: "biodiversity protection programs"
# {'query': '"biodiversity protection programs"', 'hits': [], 'total': 0}
#
# Query: "crime investigation techniques"
# {'query': '"crime investigation techniques"', 'hits': [], 'total': 0}
#
# Query: "law enforcement technology"
# {'query': '"law enforcement technology"', 'hits': [], 'total': 0}
#
# Query: "emergency response coordination"
# {'query': '"emergency response coordination"', 'hits': [], 'total': 0}
#
# Query: "disaster relief operations"
# {'query': '"disaster relief operations"', 'hits': [], 'total': 0}
#
# Query: "financial auditing standards"
# {'query': '"financial auditing standards"', 'hits': [], 'total': 0}
#
# Query: "pandemic vaccination campaigns"
# {'query': '"pandemic vaccination campaigns"', 'hits': [], 'total': 0}
#
# Query: "school curriculum development"
# {'query': '"school curriculum development"', 'hits': [], 'total': 0}
#
# Query: "education quality assessment"
# {'query': '"education quality assessment"', 'hits': [], 'total': 0}
#
# Query: "economic growth planning"
# {'query': '"economic growth planning"', 'hits': [], 'total': 0}
#
# Query: "corporate fraud detection"
# {'query': '"corporate fraud detection"', 'hits': [], 'total': 0}
#
# Query: "workplace accident prevention"
# {'query': '"workplace accident prevention"', 'hits': [], 'total': 0}
#
# Query: "public health monitoring"
# {'query': '"public health monitoring"', 'hits': [], 'total': 0}
#
# Query: "environmental law compliance"
# {'query': '"environmental law compliance"', 'hits': [], 'total': 0}
#
# Query: "climate change mitigation"
# {'query': '"climate change mitigation"', 'hits': [], 'total': 0}
#
# Query: "natural disaster insurance"
# {'query': '"natural disaster insurance"', 'hits': [], 'total': 0}
#
# Query: "urban planning and safety"
# {'query': '"urban planning and safety"', 'hits': [], 'total': 0}
#
# Query: "crime" OR "fraud"
# {'query': '"crime" OR "fraud"', 'hits': [{'doc_id': 3810, 'score': 25.068247334421997}, {'doc_id': 3890, 'score': 24.138129088589878}, {'doc_id': 3415, 'score': 22.70674001126624}, {'doc_id': 1457, 'score': 21.758291354552004}, {'doc_id': 2700, 'score': 20.280967230354356}, {'doc_id': 3522, 'score': 19.37324867879964}, {'doc_id': 1855, 'score': 19.34469743808871}, {'doc_id': 33, 'score': 16.721471698590122}, {'doc_id': 358, 'score': 16.721471698590122}, {'doc_id': 190, 'score': 16.06286396855729}], 'total': 923}
#
# Query: "law" AND "justice"
# {'query': '"law" AND "justice"', 'hits': [{'doc_id': 190, 'score': 27.139539868041236}, {'doc_id': 3415, 'score': 26.255096252257935}, {'doc_id': 450, 'score': 24.499641840262846}, {'doc_id': 781, 'score': 23.314371742068737}, {'doc_id': 1737, 'score': 22.272315398146567}, {'doc_id': 604, 'score': 21.88279789488938}, {'doc_id': 3810, 'score': 21.85751366815391}, {'doc_id': 1922, 'score': 21.570443880907042}, {'doc_id': 4815, 'score': 21.220446861439708}, {'doc_id': 1081, 'score': 21.184849790240563}], 'total': 211}
#
# Query: "police" AND NOT "corruption"
# {'query': '"police" AND NOT "corruption"', 'hits': [], 'total': 0}
#
# Query: ("financial fraud" OR "corporate crime") AND "regulation"
# {'query': '("financial fraud" OR "corporate crime") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("natural disaster" OR "emergency response") AND "community"
# {'query': '("natural disaster" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "public health" AND NOT "education"
# {'query': '"public health" AND NOT "education"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "law enforcement") AND "urban areas"
# {'query': '("crime prevention" OR "law enforcement") AND "urban areas"', 'hits': [], 'total': 0}
#
# Query: "climate change" AND "environmental policy"
# {'query': '"climate change" AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: "school education" AND "safety protocols"
# {'query': '"school education" AND "safety protocols"', 'hits': [], 'total': 0}
#
# Query: ("healthcare reforms" OR "hospital management") AND "rural areas"
# {'query': '("healthcare reforms" OR "hospital management") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: "economic growth" AND NOT "corruption"
# {'query': '"economic growth" AND NOT "corruption"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency response") AND "community"
# {'query': '("disaster preparedness" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "corporate crime" AND "financial regulation"
# {'query': '"corporate crime" AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("budget allocation" OR "financial planning") AND "government policy"
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 31.634395740690806}, {'doc_id': 2873, 'score': 27.527129654333727}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 73.86875709020813}, {'doc_id': 8077, 'score': 54.95479101972046}, {'doc_id': 8103, 'score': 45.281769346654436}, {'doc_id': 9002, 'score': 42.08884833876811}, {'doc_id': 7684, 'score': 33.49769589066067}, {'doc_id': 7659, 'score': 31.060712142377852}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 23.357695038743042}, {'doc_id': 3530, 'score': 15.956900593669573}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 39.861529152043815}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 7214, 'score': 31.725380895960487}, {'doc_id': 8398, 'score': 28.459483946548797}, {'doc_id': 4448, 'score': 17.99358781406781}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 48.878056500251894}, {'doc_id': 7675, 'score': 39.22464395259123}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# ...
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [{'doc_id': 5070, 'score': 78.56949901692829}, {'doc_id': 5988, 'score': 55.483754955162276}, {'doc_id': 5781, 'score': 44.991596104106755}, {'doc_id': 9406, 'score': 38.29652155537048}, {'doc_id': 9434, 'score': 37.47176834833131}, {'doc_id': 4560, 'score': 37.29695338408591}, {'doc_id': 9352, 'score': 35.730843807419745}, {'doc_id': 3415, 'score': 35.677689187933}, {'doc_id': 9741, 'score': 35.018073020106854}, {'doc_id': 9986, 'score': 31.288228297643446}], 'total': 22}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [{'doc_id': 4491, 'score': 54.21778535327314}, {'doc_id': 8736, 'score': 37.66035568081004}, {'doc_id': 4616, 'score': 36.42315277523535}, {'doc_id': 8781, 'score': 36.38279202324558}, {'doc_id': 5287, 'score': 36.24363953782866}, {'doc_id': 5609, 'score': 35.81718965598786}, {'doc_id': 5890, 'score': 32.774102693987345}, {'doc_id': 5300, 'score': 32.46862436877046}, {'doc_id': 5310, 'score': 30.818066814850933}, {'doc_id': 5051, 'score': 30.661929393435152}], 'total': 139}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [{'doc_id': 7691, 'score': 49.42810167936041}, {'doc_id': 7652, 'score': 46.38221223253206}, {'doc_id': 7071, 'score': 45.407049721472546}, {'doc_id': 7031, 'score': 44.429256868682714}, {'doc_id': 7576, 'score': 44.31464075203648}, {'doc_id': 9515, 'score': 43.82021579672914}, {'doc_id': 7502, 'score': 41.95926142486194}, {'doc_id': 7777, 'score': 41.489319014767815}, {'doc_id': 7726, 'score': 40.86857013560301}, {'doc_id': 7924, 'score': 40.83878046016359}], 'total': 421}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits':

#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [{'doc_id': 5914, 'score': 47.30627279145253}, {'doc_id': 5022, 'score': 39.45621367561288}, {'doc_id': 96, 'score': 38.68124771926292}, {'doc_id': 659, 'score': 38.68124771926292}, {'doc_id': 3415, 'score': 37.679086099833576}, {'doc_id': 896, 'score': 37.15856786522597}, {'doc_id': 4079, 'score': 34.85131646027907}, {'doc_id': 6415, 'score': 34.81145125427573}, {'doc_id': 7356, 'score': 31.875287978978356}, {'doc_id': 3562, 'score': 27.052863740779824}], 'total': 101}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [{'doc_id': 3562, 'score': 58.468962699096224}, {'doc_id': 8077, 'score': 58.46081703173287}, {'doc_id': 5914, 'score': 56.51330254846542}, {'doc_id': 896, 'score': 52.875144156628174}, {'doc_id': 8829, 'score': 49.647841655013856}, {'doc_id': 9002, 'score': 43.54026233819505}, {'doc_id': 8248, 'score': 42.16834371355971}, {'doc_id': 3415, 'score': 41.57792993926398}, {'doc_id': 9025, 'score': 40.85859074125665}, {'doc_id': 5022, 'score': 39.22217144666803}], 'total': 49}

# %%
#graph part e
import time
import numpy as np
import matplotlib.pyplot as plt

# ---------- Load queries ----------
with open("queries.txt", "r", encoding="utf8") as f:
    queries = [q.strip() for q in f.readlines() if q.strip()]

# ---------- Load two indices ----------
si_code = SelfIndex()
si_code.load_index("./selfindex_store/SelfIndex-v1.x3.y1.z1.i1.qT1")

si_clib = SelfIndex()
si_clib.load_index("./selfindex_store/SelfIndex-v1.x3.y1.z1.i1.qD1")

# ---------- Measure response times ----------
def measure_latency(si, queries):
    times = []
    for q in queries:
        t0 = time.perf_counter()
        _ = si.query(q, k=5)
        t1 = time.perf_counter()
        times.append(t1 - t0)
    return np.array(times)

lat_code = measure_latency(si_code, queries)
lat_clib = measure_latency(si_clib, queries)

# ---------- Compute latency metrics ----------
p95_code, p99_code = np.percentile(lat_code, [95, 99])
p95_clib, p99_clib = np.percentile(lat_clib, [95, 99])


# ---------- Add Elasticsearch metrics (from measured data) ----------
p95_es = 0.0327585
p99_es = 0.0339084

# ---------- Plot A: Latency (p95, p99) ----------
plt.figure(figsize=(8,6))
labels = ['TaaT_p95','TaaT_p99','DaaT_p95','DaaT_p99','ES_p95','ES_p99']
values = [p95_code, p99_code, p95_clib, p99_clib, p95_es, p99_es]
plt.bar(labels, values, color=['skyblue','skyblue','orange','orange','lightgreen','lightgreen'])
plt.ylabel("Latency (seconds)")
plt.title("Plot.A: Response Time (p95, p99) Comparison")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# ---------- Print numeric summary ----------
print("\n=== Response Time (Latency) ===")
print(f"Term-at-a-time : p95={p95_code:.5f}s, p99={p99_code:.5f}s")
print(f"Document-at-a-time : p95={p95_clib:.5f}s, p99={p99_clib:.5f}s")
print(f"Elasticsearch : p95={p95_es:.5f}s, p99={p99_es:.5f}s")
# Out:
# [SelfIndex] Loaded index 'SelfIndex-v1.x3.y1.z1.i1.qT1' (N=10000, terms=134822)
# [SelfIndex] Loaded index 'SelfIndex-v1.x3.y1.z1.i1.qD1' (N=10000, terms=134822)
# === Response Time (Latency) ===
# Term-at-a-time : p95=0.00106s, p99=0.00182s
# Document-at-a-time : p95=0.01368s, p99=0.02582s
# Elasticsearch : p95=0.03276s, p99=0.03391s

# %%
#graph part e
import os
import pandas as pd
import numpy as np

def get_folder_size(path):
    total = 0
    for root, _, files in os.walk(path):
        for f in files:
            total += os.path.getsize(os.path.join(root, f))
    return total / (1024 * 1024)  # MB

# ---- SelfIndex memory usage ----
selfindex_folders = {
    "qT0": "./selfindex_store/SelfIndex-v1.x3.y1.z1.i0.qT0",
    "qD0": "./selfindex_store/SelfIndex-v1.x3.y1.z1.i0.qD0",
}
selfindex_data = []
for name, path in selfindex_folders.items():
    selfindex_data.append({
        "System": "SelfIndex",
        "Variant": name,
        "Memory_MB": get_folder_size(path)
    })

# ---- ElasticSearch memory usage ----
es_mem_df = pd.read_csv("memory_usage_log.csv")
es_mem_mean = es_mem_df["elasticsearch_MB"].mean()

# Approx. same for all x variants since single ES index
es_data = [
    {"System": "ElasticSearch", "Variant":"qT0", "Memory_MB": es_mem_mean},
    {"System": "ElasticSearch", "Variant": "qD0", "Memory_MB": es_mem_mean},  # synthetic scaling
]

df_mem = pd.DataFrame(selfindex_data + es_data)
print(selfindex_data)
# Out:
# [{'System': 'SelfIndex', 'Variant': 'qT0', 'Memory_MB': 27.933515548706055}, {'System': 'SelfIndex', 'Variant': 'qD0', 'Memory_MB': 27.93351459503174}]

# %%
#graph part e
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import pandas as pd

# ✅ Use your existing variables from the earlier code
# selfindex_data and es_mem_mean are already defined

# Combine both SelfIndex and Elasticsearch data
es_data = [
    {"System": "ElasticSearch", "Variant": "qT0", "Memory_MB": es_mem_mean},
    {"System": "ElasticSearch", "Variant": "qD0", "Memory_MB": es_mem_mean},
]

df_mem = pd.DataFrame(selfindex_data + es_data)

# --- Base Plot ---
fig, ax = plt.subplots(figsize=(8, 5))
variants = ["qT0", "qD0"]

for sys in ["SelfIndex", "ElasticSearch"]:
    subset = df_mem[df_mem["System"] == sys]
    ax.plot(variants, subset["Memory_MB"], marker="o", label=sys)

ax.set_title("Plot E – Memory Footprint: TaaT (qT0) vs DaaT (qD0)")
ax.set_xlabel("Query Processing Strategy")
ax.set_ylabel("Memory Footprint in log scale(MB)")
ax.legend()
ax.grid(True, linestyle="--", alpha=0.5)

# --- Log scale for the main axis ---
ax.set_yscale("log")

# --- Inset for zoomed-in SelfIndex memory difference ---
axins = inset_axes(ax, width="40%", height="40%", loc="upper left", borderpad=2)
subset_self = df_mem[df_mem["System"] == "SelfIndex"]
axins.plot(variants, subset_self["Memory_MB"], marker="o", color="tab:blue")
axins.set_title("Zoom: SelfIndex Memory", fontsize=9)
axins.tick_params(axis='both', which='major', labelsize=8)
axins.grid(True, linestyle="--", alpha=0.5)

# Automatically zoom around SelfIndex range
min_mem = subset_self["Memory_MB"].min()
max_mem = subset_self["Memory_MB"].max()
axins.set_ylim(min_mem - 0.00001, max_mem + 0.00001)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_7519/509708045.py:47: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
#graph part b
# --- Prepare files iterable: (doc_id, text) for full dataset ---
files_iterable = [(int(idx), txt) for idx, txt in zip(subset.index, subset['clean_text'])]

# --- Load queries from file ---
with open("queries.txt", "r") as f:
    queries = [line.strip() for line in f if line.strip()]

# --- Dictionary to store results ---
all_results = {}

# --- Iterate over all versions ---
for version in VERSION_CONFIG.keys():
    print(f"\n=== Processing version {version} ===")
    
    # Create SelfIndex instance using the version
    si = SelfIndex(version=version)
    
    # Build or load index for the full dataset
    index_id = f"SelfIndex-{version}"
    
    if index_id in SelfIndex.list_indices():
        print("🟢 Loading existing index...")
        si.load_index(f"./selfindex_store/{index_id}")
    else:
        print("🟡 Building new index...")
        si.create_index(index_id, files_iterable)
    
    # Run queries and store results
    version_results = {}
    for q in queries:
        res = si.query(q, k=10)
        version_results[q] = res
        print(f"\nQuery: {q}")
        print(res)
    
    all_results[version] = version_results

# --- all_results now has results for all versions and all queries ---
# Out:
# === Processing version v1.x1.y1.z1.i0.qT0 ===
# 🟢 Loading existing index...
# [SelfIndex] Loaded index 'SelfIndex-v1.x1.y1.z1.i0.qT0' (N=10000, terms=134822)
#
# Query: "crime"
# {'query': '"crime"', 'hits': [{'doc_id': 3, 'score': 1.0}, {'doc_id': 13, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 27, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 46, 'score': 1.0}], 'total': 811}
#
# Query: "law"
# {'query': '"law"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 45, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 67, 'score': 1.0}, {'doc_id': 74, 'score': 1.0}, {'doc_id': 86, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 91, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}], 'total': 962}
#
# Query: "justice"
# {'query': '"justice"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 13, 'score': 1.0}, {'doc_id': 20, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 68, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}], 'total': 548}
#
# Query: "police"
# {'query': '"police"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 18, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 24, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 47, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}], 'total': 1638}
#
# Query: "fraud"
# {'query': '"fraud"', 'hits': [{'doc_id': 13, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 52, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 115, 'score': 1.0}, {'doc_id': 130, 'score': 1.0}, {'doc_id': 188, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}], 'total': 159}
#
# Query: "theft"
# {'query': '"theft"', 'hits': [{'doc_id': 26, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 103, 'score': 1.0}, {'doc_id': 106, 'score': 1.0}, {'doc_id': 281, 'score': 1.0}, {'doc_id': 282, 'score': 1.0}, {'doc_id': 312, 'score': 1.0}, {'doc_id': 326, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}], 'total': 180}
#
# Query: "corruption"
# {'query': '"corruption"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 23, 'score': 1.0}, {'doc_id': 74, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 139, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 234, 'score': 1.0}, {'doc_id': 241, 'score': 1.0}, {'doc_id': 304, 'score': 1.0}, {'doc_id': 416, 'score': 1.0}], 'total': 59}
#
# Query: "violence"
# {'query': '"violence"', 'hits': [{'doc_id': 23, 'score': 1.0}, {'doc_id': 54, 'score': 1.0}, {'doc_id': 68, 'score': 1.0}, {'doc_id': 78, 'score': 1.0}, {'doc_id': 89, 'score': 1.0}, {'doc_id': 116, 'score': 1.0}, {'doc_id': 139, 'score': 1.0}, {'doc_id': 164, 'score': 1.0}, {'doc_id': 168, 'score': 1.0}, {'doc_id': 185, 'score': 1.0}], 'total': 375}
#
# Query: "investigation"
# {'query': '"investigation"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 8, 'score': 1.0}, {'doc_id': 11, 'score': 1.0}, {'doc_id': 15, 'score': 1.0}, {'doc_id': 18, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 24, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}], 'total': 1212}
#
# Query: "disaster"
# {'query': '"disaster"', 'hits': [{'doc_id': 54, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 446, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 773, 'score': 1.0}, {'doc_id': 793, 'score': 1.0}, {'doc_id': 1457, 'score': 1.0}, {'doc_id': 1510, 'score': 1.0}], 'total': 203}
#
# Query: "accident"
# {'query': '"accident"', 'hits': [{'doc_id': 20, 'score': 1.0}, {'doc_id': 75, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 107, 'score': 1.0}, {'doc_id': 116, 'score': 1.0}, {'doc_id': 160, 'score': 1.0}, {'doc_id': 179, 'score': 1.0}, {'doc_id': 265, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 288, 'score': 1.0}], 'total': 450}
#
# Query: "emergency"
# {'query': '"emergency"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}, {'doc_id': 54, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 87, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 129, 'score': 1.0}], 'total': 801}
#
# Query: "flood"
# {'query': '"flood"', 'hits': [{'doc_id': 428, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 588, 'score': 1.0}, {'doc_id': 820, 'score': 1.0}, {'doc_id': 878, 'score': 1.0}, {'doc_id': 1258, 'score': 1.0}, {'doc_id': 1469, 'score': 1.0}, {'doc_id': 1496, 'score': 1.0}, {'doc_id': 1510, 'score': 1.0}, {'doc_id': 1511, 'score': 1.0}], 'total': 290}
#
# Query: "earthquake"
# {'query': '"earthquake"', 'hits': [{'doc_id': 446, 'score': 1.0}, {'doc_id': 3088, 'score': 1.0}, {'doc_id': 3146, 'score': 1.0}, {'doc_id': 3299, 'score': 1.0}, {'doc_id': 4186, 'score': 1.0}, {'doc_id': 4195, 'score': 1.0}, {'doc_id': 4273, 'score': 1.0}, {'doc_id': 4355, 'score': 1.0}, {'doc_id': 4397, 'score': 1.0}, {'doc_id': 4450, 'score': 1.0}], 'total': 37}
#
# Query: "storm"
# {'query': '"storm"', 'hits': [{'doc_id': 82, 'score': 1.0}, {'doc_id': 161, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 302, 'score': 1.0}, {'doc_id': 527, 'score': 1.0}, {'doc_id': 615, 'score': 1.0}, {'doc_id': 677, 'score': 1.0}, {'doc_id': 736, 'score': 1.0}, {'doc_id': 824, 'score': 1.0}, {'doc_id': 1101, 'score': 1.0}], 'total': 269}
#
# Query: "fire"
# {'query': '"fire"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 8, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 42, 'score': 1.0}, {'doc_id': 80, 'score': 1.0}, {'doc_id': 87, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 112, 'score': 1.0}, {'doc_id': 124, 'score': 1.0}, {'doc_id': 144, 'score': 1.0}], 'total': 870}
#
# Query: "evacuation"
# {'query': '"evacuation"', 'hits': [{'doc_id': 54, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 161, 'score': 1.0}, {'doc_id': 286, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 993, 'score': 1.0}, {'doc_id': 1497, 'score': 1.0}, {'doc_id': 1661, 'score': 1.0}, {'doc_id': 1897, 'score': 1.0}, {'doc_id': 2130, 'score': 1.0}], 'total': 117}
#
# Query: "rescue"
# {'query': '"rescue"', 'hits': [{'doc_id': 33, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 57, 'score': 1.0}, {'doc_id': 118, 'score': 1.0}, {'doc_id': 153, 'score': 1.0}, {'doc_id': 165, 'score': 1.0}, {'doc_id': 346, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 421, 'score': 1.0}, {'doc_id': 453, 'score': 1.0}], 'total': 464}
#
# Query: "damage"
# {'query': '"damage"', 'hits': [{'doc_id': 4, 'score': 1.0}, {'doc_id': 7, 'score': 1.0}, {'doc_id': 10, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 64, 'score': 1.0}, {'doc_id': 72, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 134, 'score': 1.0}, {'doc_id': 135, 'score': 1.0}], 'total': 569}
#
# Query: "economy"
# {'query': '"economy"', 'hits': [{'doc_id': 34, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 95, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 163, 'score': 1.0}, {'doc_id': 284, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 659, 'score': 1.0}, {'doc_id': 666, 'score': 1.0}], 'total': 163}
#
# Query: "finance"
# {'query': '"finance"', 'hits': [{'doc_id': 23, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 72, 'score': 1.0}, {'doc_id': 78, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 103, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 123, 'score': 1.0}, {'doc_id': 183, 'score': 1.0}], 'total': 625}
#
# Query: "business"
# {'query': '"business"', 'hits': [{'doc_id': 1, 'score': 1.0}, {'doc_id': 16, 'score': 1.0}, {'doc_id': 34, 'score': 1.0}, {'doc_id': 45, 'score': 1.0}, {'doc_id': 46, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 67, 'score': 1.0}, {'doc_id': 68, 'score': 1.0}], 'total': 829}
#
# Query: "market"
# {'query': '"market"', 'hits': [{'doc_id': 4, 'score': 1.0}, {'doc_id': 7, 'score': 1.0}, {'doc_id': 34, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 64, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 95, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 103, 'score': 1.0}], 'total': 596}
#
# Query: "investment"
# {'query': '"investment"', 'hits': [{'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 154, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 164, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 330, 'score': 1.0}, {'doc_id': 421, 'score': 1.0}, {'doc_id': 476, 'score': 1.0}, {'doc_id': 576, 'score': 1.0}], 'total': 344}
#
# Query: "budget"
# {'query': '"budget"', 'hits': [{'doc_id': 29, 'score': 1.0}, {'doc_id': 72, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 172, 'score': 1.0}, {'doc_id': 215, 'score': 1.0}, {'doc_id': 470, 'score': 1.0}, {'doc_id': 472, 'score': 1.0}, {'doc_id': 538, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}], 'total': 147}
#
# Query: "revenue"
# {'query': '"revenue"', 'hits': [{'doc_id': 70, 'score': 1.0}, {'doc_id': 86, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 370, 'score': 1.0}, {'doc_id': 437, 'score': 1.0}, {'doc_id': 673, 'score': 1.0}, {'doc_id': 719, 'score': 1.0}, {'doc_id': 731, 'score': 1.0}, {'doc_id': 779, 'score': 1.0}, {'doc_id': 812, 'score': 1.0}], 'total': 127}
#
# Query: "tax"
# {'query': '"tax"', 'hits': [{'doc_id': 45, 'score': 1.0}, {'doc_id': 62, 'score': 1.0}, {'doc_id': 64, 'score': 1.0}, {'doc_id': 151, 'score': 1.0}, {'doc_id': 194, 'score': 1.0}, {'doc_id': 207, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}, {'doc_id': 335, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 372, 'score': 1.0}], 'total': 147}
#
# Query: "inflation"
# {'query': '"inflation"', 'hits': [{'doc_id': 62, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 163, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}, {'doc_id': 372, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 865, 'score': 1.0}, {'doc_id': 1441, 'score': 1.0}, {'doc_id': 1665, 'score': 1.0}, {'doc_id': 1683, 'score': 1.0}], 'total': 61}
#
# Query: "stock"
# {'query': '"stock"', 'hits': [{'doc_id': 34, 'score': 1.0}, {'doc_id': 92, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 159, 'score': 1.0}, {'doc_id': 399, 'score': 1.0}, {'doc_id': 445, 'score': 1.0}, {'doc_id': 452, 'score': 1.0}, {'doc_id': 493, 'score': 1.0}, {'doc_id': 525, 'score': 1.0}, {'doc_id': 615, 'score': 1.0}], 'total': 279}
#
# Query: "education"
# {'query': '"education"', 'hits': [{'doc_id': 29, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 128, 'score': 1.0}, {'doc_id': 154, 'score': 1.0}, {'doc_id': 177, 'score': 1.0}, {'doc_id': 267, 'score': 1.0}, {'doc_id': 277, 'score': 1.0}, {'doc_id': 282, 'score': 1.0}], 'total': 774}
#
# Query: "school"
# {'query': '"school"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 42, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 57, 'score': 1.0}, {'doc_id': 77, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 100, 'score': 1.0}], 'total': 1031}
#
# Query: "college"
# {'query': '"college"', 'hits': [{'doc_id': 33, 'score': 1.0}, {'doc_id': 77, 'score': 1.0}, {'doc_id': 108, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 196, 'score': 1.0}, {'doc_id': 243, 'score': 1.0}, {'doc_id': 245, 'score': 1.0}, {'doc_id': 264, 'score': 1.0}, {'doc_id': 271, 'score': 1.0}], 'total': 474}
#
# Query: "university"
# {'query': '"university"', 'hits': [{'doc_id': 4119, 'score': 1.0}, {'doc_id': 9727, 'score': 1.0}], 'total': 2}
#
# Query: "learning"
# {'query': '"learning"', 'hits': [{'doc_id': 32, 'score': 1.0}, {'doc_id': 37, 'score': 1.0}, {'doc_id': 54, 'score': 1.0}, {'doc_id': 56, 'score': 1.0}, {'doc_id': 80, 'score': 1.0}, {'doc_id': 81, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 129, 'score': 1.0}, {'doc_id': 137, 'score': 1.0}], 'total': 899}
#
# Query: "curriculum"
# {'query': '"curriculum"', 'hits': [{'doc_id': 454, 'score': 1.0}, {'doc_id': 1731, 'score': 1.0}, {'doc_id': 3300, 'score': 1.0}, {'doc_id': 3425, 'score': 1.0}, {'doc_id': 3586, 'score': 1.0}, {'doc_id': 3711, 'score': 1.0}, {'doc_id': 5070, 'score': 1.0}, {'doc_id': 5717, 'score': 1.0}, {'doc_id': 5998, 'score': 1.0}, {'doc_id': 6036, 'score': 1.0}], 'total': 93}
#
# Query: "teacher"
# {'query': '"teacher"', 'hits': [{'doc_id': 29, 'score': 1.0}, {'doc_id': 42, 'score': 1.0}, {'doc_id': 43, 'score': 1.0}, {'doc_id': 121, 'score': 1.0}, {'doc_id': 142, 'score': 1.0}, {'doc_id': 177, 'score': 1.0}, {'doc_id': 245, 'score': 1.0}, {'doc_id': 282, 'score': 1.0}, {'doc_id': 301, 'score': 1.0}, {'doc_id': 328, 'score': 1.0}], 'total': 276}
#
# Query: "student"
# {'query': '"student"', 'hits': [{'doc_id': 15, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 57, 'score': 1.0}, {'doc_id': 77, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 121, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 128, 'score': 1.0}, {'doc_id': 137, 'score': 1.0}, {'doc_id': 142, 'score': 1.0}], 'total': 839}
#
# Query: "exam"
# {'query': '"exam"', 'hits': [{'doc_id': 464, 'score': 1.0}, {'doc_id': 898, 'score': 1.0}, {'doc_id': 1261, 'score': 1.0}, {'doc_id': 1301, 'score': 1.0}, {'doc_id': 1342, 'score': 1.0}, {'doc_id': 1412, 'score': 1.0}, {'doc_id': 1843, 'score': 1.0}, {'doc_id': 2020, 'score': 1.0}, {'doc_id': 2065, 'score': 1.0}, {'doc_id': 2259, 'score': 1.0}], 'total': 64}
#
# Query: "scholarship"
# {'query': '"scholarship"', 'hits': [{'doc_id': 96, 'score': 1.0}, {'doc_id': 219, 'score': 1.0}, {'doc_id': 461, 'score': 1.0}, {'doc_id': 659, 'score': 1.0}, {'doc_id': 686, 'score': 1.0}, {'doc_id': 1064, 'score': 1.0}, {'doc_id': 1958, 'score': 1.0}, {'doc_id': 1980, 'score': 1.0}, {'doc_id': 2089, 'score': 1.0}, {'doc_id': 2589, 'score': 1.0}], 'total': 107}
#
# Query: "environment"
# {'query': '"environment"', 'hits': [{'doc_id': 78, 'score': 1.0}, {'doc_id': 92, 'score': 1.0}, {'doc_id': 111, 'score': 1.0}, {'doc_id': 112, 'score': 1.0}, {'doc_id': 139, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 227, 'score': 1.0}, {'doc_id': 300, 'score': 1.0}, {'doc_id': 304, 'score': 1.0}, {'doc_id': 352, 'score': 1.0}], 'total': 575}
#
# Query: "climate"
# {'query': '"climate"', 'hits': [{'doc_id': 67, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 696, 'score': 1.0}, {'doc_id': 752, 'score': 1.0}, {'doc_id': 896, 'score': 1.0}, {'doc_id': 1101, 'score': 1.0}, {'doc_id': 1459, 'score': 1.0}, {'doc_id': 1830, 'score': 1.0}], 'total': 234}
#
# Query: "pollution"
# {'query': '"pollution"', 'hits': [{'doc_id': 752, 'score': 1.0}, {'doc_id': 878, 'score': 1.0}, {'doc_id': 1084, 'score': 1.0}, {'doc_id': 2606, 'score': 1.0}, {'doc_id': 3415, 'score': 1.0}, {'doc_id': 3562, 'score': 1.0}, {'doc_id': 4151, 'score': 1.0}, {'doc_id': 4199, 'score': 1.0}, {'doc_id': 4397, 'score': 1.0}, {'doc_id': 4426, 'score': 1.0}], 'total': 105}
#
# Query: "sustainability"
# {'query': '"sustainability"', 'hits': [{'doc_id': 96, 'score': 1.0}, {'doc_id': 161, 'score': 1.0}, {'doc_id': 183, 'score': 1.0}, {'doc_id': 241, 'score': 1.0}, {'doc_id': 306, 'score': 1.0}, {'doc_id': 336, 'score': 1.0}, {'doc_id': 351, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 383, 'score': 1.0}, {'doc_id': 447, 'score': 1.0}], 'total': 377}
#
# Query: "conservation"
# {'query': '"conservation"', 'hits': [{'doc_id': 13, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 37, 'score': 1.0}, {'doc_id': 118, 'score': 1.0}, {'doc_id': 127, 'score': 1.0}, {'doc_id': 152, 'score': 1.0}, {'doc_id': 165, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 242, 'score': 1.0}], 'total': 170}
#
# Query: "biodiversity"
# {'query': '"biodiversity"', 'hits': [], 'total': 0}
#
# Query: "recycling"
# {'query': '"recycling"', 'hits': [{'doc_id': 641, 'score': 1.0}, {'doc_id': 653, 'score': 1.0}, {'doc_id': 729, 'score': 1.0}, {'doc_id': 878, 'score': 1.0}, {'doc_id': 992, 'score': 1.0}, {'doc_id': 1678, 'score': 1.0}, {'doc_id': 3415, 'score': 1.0}, {'doc_id': 3915, 'score': 1.0}, {'doc_id': 4052, 'score': 1.0}, {'doc_id': 4470, 'score': 1.0}], 'total': 38}
#
# Query: "deforestation"
# {'query': '"deforestation"', 'hits': [{'doc_id': 1948, 'score': 1.0}, {'doc_id': 3397, 'score': 1.0}, {'doc_id': 7667, 'score': 1.0}, {'doc_id': 8398, 'score': 1.0}, {'doc_id': 8713, 'score': 1.0}], 'total': 5}
#
# Query: "emission"
# {'query': '"emission"', 'hits': [{'doc_id': 578, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 752, 'score': 1.0}, {'doc_id': 900, 'score': 1.0}, {'doc_id': 3253, 'score': 1.0}, {'doc_id': 3562, 'score': 1.0}, {'doc_id': 3612, 'score': 1.0}, {'doc_id': 4635, 'score': 1.0}, {'doc_id': 4877, 'score': 1.0}, {'doc_id': 5130, 'score': 1.0}], 'total': 64}
#
# Query: "energy"
# {'query': '"energy"', 'hits': [{'doc_id': 23, 'score': 1.0}, {'doc_id': 181, 'score': 1.0}, {'doc_id': 271, 'score': 1.0}, {'doc_id': 348, 'score': 1.0}, {'doc_id': 509, 'score': 1.0}, {'doc_id': 562, 'score': 1.0}, {'doc_id': 580, 'score': 1.0}, {'doc_id': 582, 'score': 1.0}, {'doc_id': 631, 'score': 1.0}, {'doc_id': 637, 'score': 1.0}], 'total': 302}
#
# Query: "health"
# {'query': '"health"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 10, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 32, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 67, 'score': 1.0}, {'doc_id': 74, 'score': 1.0}, {'doc_id': 81, 'score': 1.0}, {'doc_id': 82, 'score': 1.0}, {'doc_id': 84, 'score': 1.0}], 'total': 1111}
#
# Query: "medical"
# {'query': '"medical"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 61, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 117, 'score': 1.0}, {'doc_id': 130, 'score': 1.0}], 'total': 890}
#
# Query: "hospital"
# {'query': '"hospital"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 25, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 32, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}, {'doc_id': 47, 'score': 1.0}, {'doc_id': 48, 'score': 1.0}, {'doc_id': 63, 'score': 1.0}, {'doc_id': 71, 'score': 1.0}], 'total': 940}
#
# Query: "disease"
# {'query': '"disease"', 'hits': [], 'total': 0}
#
# Query: "pandemic"
# {'query': '"pandemic"', 'hits': [{'doc_id': 163, 'score': 1.0}, {'doc_id': 556, 'score': 1.0}, {'doc_id': 1212, 'score': 1.0}, {'doc_id': 1235, 'score': 1.0}, {'doc_id': 1333, 'score': 1.0}, {'doc_id': 1369, 'score': 1.0}, {'doc_id': 1374, 'score': 1.0}, {'doc_id': 1436, 'score': 1.0}, {'doc_id': 1457, 'score': 1.0}, {'doc_id': 1459, 'score': 1.0}], 'total': 158}
#
# Query: "nutrition"
# {'query': '"nutrition"', 'hits': [{'doc_id': 1341, 'score': 1.0}, {'doc_id': 1775, 'score': 1.0}, {'doc_id': 1855, 'score': 1.0}, {'doc_id': 1923, 'score': 1.0}, {'doc_id': 1934, 'score': 1.0}, {'doc_id': 4117, 'score': 1.0}, {'doc_id': 4748, 'score': 1.0}, {'doc_id': 4866, 'score': 1.0}, {'doc_id': 5655, 'score': 1.0}, {'doc_id': 5676, 'score': 1.0}], 'total': 80}
#
# Query: "vaccine"
# {'query': '"vaccine"', 'hits': [{'doc_id': 358, 'score': 1.0}, {'doc_id': 416, 'score': 1.0}, {'doc_id': 537, 'score': 1.0}, {'doc_id': 556, 'score': 1.0}, {'doc_id': 888, 'score': 1.0}, {'doc_id': 1462, 'score': 1.0}, {'doc_id': 1607, 'score': 1.0}, {'doc_id': 1890, 'score': 1.0}, {'doc_id': 3354, 'score': 1.0}, {'doc_id': 3493, 'score': 1.0}], 'total': 63}
#
# Query: "wellbeing"
# {'query': '"wellbeing"', 'hits': [{'doc_id': 10, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 134, 'score': 1.0}, {'doc_id': 241, 'score': 1.0}, {'doc_id': 358, 'score': 1.0}, {'doc_id': 421, 'score': 1.0}, {'doc_id': 451, 'score': 1.0}, {'doc_id': 576, 'score': 1.0}, {'doc_id': 593, 'score': 1.0}, {'doc_id': 598, 'score': 1.0}], 'total': 289}
#
# Query: "mental health"
# {'query': '"mental health"', 'hits': [{'doc_id': 74, 'score': 1.0}, {'doc_id': 84, 'score': 1.0}, {'doc_id': 210, 'score': 1.0}, {'doc_id': 252, 'score': 1.0}, {'doc_id': 463, 'score': 1.0}, {'doc_id': 477, 'score': 1.0}, {'doc_id': 665, 'score': 1.0}, {'doc_id': 823, 'score': 1.0}, {'doc_id': 899, 'score': 1.0}, {'doc_id': 964, 'score': 1.0}], 'total': 193}
#
# Query: "treatment"
# {'query': '"treatment"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 93, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 153, 'score': 1.0}, {'doc_id': 199, 'score': 1.0}, {'doc_id': 202, 'score': 1.0}, {'doc_id': 204, 'score': 1.0}, {'doc_id': 254, 'score': 1.0}, {'doc_id': 315, 'score': 1.0}, {'doc_id': 406, 'score': 1.0}], 'total': 549}
#
# Query: "crime prevention"
# {'query': '"crime prevention"', 'hits': [{'doc_id': 651, 'score': 1.0}, {'doc_id': 2072, 'score': 1.0}, {'doc_id': 2874, 'score': 1.0}, {'doc_id': 3024, 'score': 1.0}, {'doc_id': 3044, 'score': 1.0}, {'doc_id': 3055, 'score': 1.0}, {'doc_id': 3080, 'score': 1.0}, {'doc_id': 3081, 'score': 1.0}, {'doc_id': 3133, 'score': 1.0}, {'doc_id': 3167, 'score': 1.0}], 'total': 22}
#
# Query: "law enforcement"
# {'query': '"law enforcement"', 'hits': [{'doc_id': 303, 'score': 1.0}, {'doc_id': 516, 'score': 1.0}, {'doc_id': 1177, 'score': 1.0}, {'doc_id': 1252, 'score': 1.0}, {'doc_id': 1331, 'score': 1.0}, {'doc_id': 1918, 'score': 1.0}, {'doc_id': 1963, 'score': 1.0}, {'doc_id': 2646, 'score': 1.0}, {'doc_id': 3472, 'score': 1.0}, {'doc_id': 3530, 'score': 1.0}], 'total': 14}
#
# Query: "traffic accident"
# {'query': '"traffic accident"', 'hits': [{'doc_id': 1629, 'score': 1.0}, {'doc_id': 1647, 'score': 1.0}, {'doc_id': 3997, 'score': 1.0}, {'doc_id': 4025, 'score': 1.0}, {'doc_id': 4068, 'score': 1.0}, {'doc_id': 5136, 'score': 1.0}, {'doc_id': 5260, 'score': 1.0}, {'doc_id': 5332, 'score': 1.0}], 'total': 8}
#
# Query: "financial fraud"
# {'query': '"financial fraud"', 'hits': [], 'total': 0}
#
# Query: "public health"
# {'query': '"public health"', 'hits': [{'doc_id': 5070, 'score': 1.0}, {'doc_id': 9424, 'score': 1.0}], 'total': 2}
#
# Query: "climate change"
# {'query': '"climate change"', 'hits': [{'doc_id': 67, 'score': 1.0}, {'doc_id': 200, 'score': 1.0}, {'doc_id': 752, 'score': 1.0}, {'doc_id': 896, 'score': 1.0}, {'doc_id': 1459, 'score': 1.0}, {'doc_id': 1866, 'score': 1.0}, {'doc_id': 2448, 'score': 1.0}, {'doc_id': 2926, 'score': 1.0}, {'doc_id': 3088, 'score': 1.0}, {'doc_id': 3146, 'score': 1.0}], 'total': 140}
#
# Query: "school education"
# {'query': '"school education"', 'hits': [{'doc_id': 1535, 'score': 1.0}, {'doc_id': 5250, 'score': 1.0}, {'doc_id': 7217, 'score': 1.0}], 'total': 3}
#
# Query: "economic growth"
# {'query': '"economic growth"', 'hits': [{'doc_id': 631, 'score': 1.0}, {'doc_id': 4479, 'score': 1.0}, {'doc_id': 4961, 'score': 1.0}, {'doc_id': 5621, 'score': 1.0}, {'doc_id': 5731, 'score': 1.0}, {'doc_id': 5914, 'score': 1.0}, {'doc_id': 6415, 'score': 1.0}, {'doc_id': 6536, 'score': 1.0}, {'doc_id': 7272, 'score': 1.0}, {'doc_id': 7308, 'score': 1.0}], 'total': 19}
#
# Query: "corporate crime"
# {'query': '"corporate crime"', 'hits': [], 'total': 0}
#
# Query: "natural disaster"
# {'query': '"natural disaster"', 'hits': [], 'total': 0}
#
# Query: "emergency response"
# {'query': '"emergency response"', 'hits': [], 'total': 0}
#
# Query: "criminal investigation"
# {'query': '"criminal investigation"', 'hits': [{'doc_id': 62, 'score': 1.0}, {'doc_id': 125, 'score': 1.0}, {'doc_id': 130, 'score': 1.0}, {'doc_id': 156, 'score': 1.0}, {'doc_id': 209, 'score': 1.0}, {'doc_id': 226, 'score': 1.0}, {'doc_id': 384, 'score': 1.0}, {'doc_id': 449, 'score': 1.0}, {'doc_id': 513, 'score': 1.0}, {'doc_id': 654, 'score': 1.0}], 'total': 40}
#
# Query: "environmental policy"
# {'query': '"environmental policy"', 'hits': [], 'total': 0}
#
# Query: "hospital management"
# {'query': '"hospital management"', 'hits': [{'doc_id': 5070, 'score': 1.0}, {'doc_id': 7000, 'score': 1.0}, {'doc_id': 7282, 'score': 1.0}, {'doc_id': 7601, 'score': 1.0}], 'total': 4}
#
# Query: "budget allocation"
# {'query': '"budget allocation"', 'hits': [{'doc_id': 3651, 'score': 1.0}], 'total': 1}
#
# Query: "disaster preparedness"
# {'query': '"disaster preparedness"', 'hits': [], 'total': 0}
#
# Query: "crime trends"
# {'query': '"crime trends"', 'hits': [], 'total': 0}
#
# Query: "workplace safety"
# {'query': '"workplace safety"', 'hits': [{'doc_id': 854, 'score': 1.0}, {'doc_id': 4983, 'score': 1.0}, {'doc_id': 5070, 'score': 1.0}], 'total': 3}
#
# Query: "community health programs"
# {'query': '"community health programs"', 'hits': [], 'total': 0}
#
# Query: "education policy reforms"
# {'query': '"education policy reforms"', 'hits': [], 'total': 0}
#
# Query: "sustainable development initiatives"
# {'query': '"sustainable development initiatives"', 'hits': [], 'total': 0}
#
# Query: "flood management strategies"
# {'query': '"flood management strategies"', 'hits': [], 'total': 0}
#
# Query: "earthquake preparedness plans"
# {'query': '"earthquake preparedness plans"', 'hits': [], 'total': 0}
#
# Query: "financial regulation compliance"
# {'query': '"financial regulation compliance"', 'hits': [], 'total': 0}
#
# Query: "pandemic response protocols"
# {'query': '"pandemic response protocols"', 'hits': [], 'total': 0}
#
# Query: "school safety protocols"
# {'query': '"school safety protocols"', 'hits': [], 'total': 0}
#
# Query: "emergency evacuation drills"
# {'query': '"emergency evacuation drills"', 'hits': [], 'total': 0}
#
# Query: "environmental conservation projects"
# {'query': '"environmental conservation projects"', 'hits': [], 'total': 0}
#
# Query: "corporate governance compliance"
# {'query': '"corporate governance compliance"', 'hits': [], 'total': 0}
#
# Query: "healthcare infrastructure improvement"
# {'query': '"healthcare infrastructure improvement"', 'hits': [], 'total': 0}
#
# Query: "economic policy analysis"
# {'query': '"economic policy analysis"', 'hits': [], 'total': 0}
#
# Query: "climate adaptation measures"
# {'query': '"climate adaptation measures"', 'hits': [], 'total': 0}
#
# Query: "crime and punishment analysis"
# {'query': '"crime and punishment analysis"', 'hits': [], 'total': 0}
#
# Query: "law reform implementation"
# {'query': '"law reform implementation"', 'hits': [], 'total': 0}
#
# Query: "disaster risk assessment"
# {'query': '"disaster risk assessment"', 'hits': [], 'total': 0}
#
# Query: "public safety monitoring"
# {'query': '"public safety monitoring"', 'hits': [], 'total': 0}
#
# Query: "urban crime trends"
# {'query': '"urban crime trends"', 'hits': [], 'total': 0}
#
# Query: "rural healthcare access"
# {'query': '"rural healthcare access"', 'hits': [], 'total': 0}
#
# Query: "educational equity programs"
# {'query': '"educational equity programs"', 'hits': [], 'total': 0}
#
# Query: "corporate social responsibility"
# {'query': '"corporate social responsibility"', 'hits': [], 'total': 0}
#
# Query: "natural disaster recovery plans"
# {'query': '"natural disaster recovery plans"', 'hits': [], 'total': 0}
#
# Query: "budget planning and allocation"
# {'query': '"budget planning and allocation"', 'hits': [], 'total': 0}
#
# Query: "environmental impact assessment"
# {'query': '"environmental impact assessment"', 'hits': [], 'total': 0}
#
# Query: "pollution control measures"
# {'query': '"pollution control measures"', 'hits': [], 'total': 0}
#
# Query: "food safety regulations"
# {'query': '"food safety regulations"', 'hits': [], 'total': 0}
#
# Query: "pandemic prevention strategies"
# {'query': '"pandemic prevention strategies"', 'hits': [], 'total': 0}
#
# Query: "student performance evaluation"
# {'query': '"student performance evaluation"', 'hits': [], 'total': 0}
#
# Query: "teacher training programs"
# {'query': '"teacher training programs"', 'hits': [], 'total': 0}
#
# Query: "school infrastructure development"
# {'query': '"school infrastructure development"', 'hits': [], 'total': 0}
#
# Query: "hospital emergency readiness"
# {'query': '"hospital emergency readiness"', 'hits': [], 'total': 0}
#
# Query: "financial market monitoring"
# {'query': '"financial market monitoring"', 'hits': [], 'total': 0}
#
# Query: "business investment strategies"
# {'query': '"business investment strategies"', 'hits': [], 'total': 0}
#
# Query: "renewable energy projects"
# {'query': '"renewable energy projects"', 'hits': [{'doc_id': 631, 'score': 1.0}, {'doc_id': 5914, 'score': 1.0}, {'doc_id': 7816, 'score': 1.0}, {'doc_id': 8077, 'score': 1.0}], 'total': 4}
#
# Query: "climate policy enforcement"
# {'query': '"climate policy enforcement"', 'hits': [], 'total': 0}
#
# Query: "deforestation prevention initiatives"
# {'query': '"deforestation prevention initiatives"', 'hits': [], 'total': 0}
#
# Query: "biodiversity protection programs"
# {'query': '"biodiversity protection programs"', 'hits': [], 'total': 0}
#
# Query: "crime investigation techniques"
# {'query': '"crime investigation techniques"', 'hits': [], 'total': 0}
#
# Query: "law enforcement technology"
# {'query': '"law enforcement technology"', 'hits': [], 'total': 0}
#
# Query: "emergency response coordination"
# {'query': '"emergency response coordination"', 'hits': [], 'total': 0}
#
# Query: "disaster relief operations"
# {'query': '"disaster relief operations"', 'hits': [], 'total': 0}
#
# Query: "financial auditing standards"
# {'query': '"financial auditing standards"', 'hits': [], 'total': 0}
#
# Query: "pandemic vaccination campaigns"
# {'query': '"pandemic vaccination campaigns"', 'hits': [], 'total': 0}
#
# Query: "school curriculum development"
# {'query': '"school curriculum development"', 'hits': [], 'total': 0}
#
# Query: "education quality assessment"
# {'query': '"education quality assessment"', 'hits': [], 'total': 0}
#
# Query: "economic growth planning"
# {'query': '"economic growth planning"', 'hits': [], 'total': 0}
#
# Query: "corporate fraud detection"
# {'query': '"corporate fraud detection"', 'hits': [], 'total': 0}
#
# Query: "workplace accident prevention"
# {'query': '"workplace accident prevention"', 'hits': [], 'total': 0}
#
# Query: "public health monitoring"
# {'query': '"public health monitoring"', 'hits': [], 'total': 0}
#
# Query: "environmental law compliance"
# {'query': '"environmental law compliance"', 'hits': [], 'total': 0}
#
# Query: "climate change mitigation"
# {'query': '"climate change mitigation"', 'hits': [], 'total': 0}
#
# Query: "natural disaster insurance"
# {'query': '"natural disaster insurance"', 'hits': [], 'total': 0}
#
# Query: "urban planning and safety"
# {'query': '"urban planning and safety"', 'hits': [], 'total': 0}
#
# Query: "crime" OR "fraud"
# {'query': '"crime" OR "fraud"', 'hits': [{'doc_id': 3, 'score': 1.0}, {'doc_id': 13, 'score': 1.0}, {'doc_id': 19, 'score': 1.0}, {'doc_id': 26, 'score': 1.0}, {'doc_id': 27, 'score': 1.0}, {'doc_id': 29, 'score': 1.0}, {'doc_id': 31, 'score': 1.0}, {'doc_id': 33, 'score': 1.0}, {'doc_id': 39, 'score': 1.0}, {'doc_id': 41, 'score': 1.0}], 'total': 923}
#
# Query: "law" AND "justice"
# {'query': '"law" AND "justice"', 'hits': [{'doc_id': 2, 'score': 1.0}, {'doc_id': 53, 'score': 1.0}, {'doc_id': 90, 'score': 1.0}, {'doc_id': 96, 'score': 1.0}, {'doc_id': 114, 'score': 1.0}, {'doc_id': 143, 'score': 1.0}, {'doc_id': 164, 'score': 1.0}, {'doc_id': 166, 'score': 1.0}, {'doc_id': 190, 'score': 1.0}, {'doc_id': 232, 'score': 1.0}], 'total': 211}
#
# Query: "police" AND NOT "corruption"
# {'query': '"police" AND NOT "corruption"', 'hits': [], 'total': 0}
#
# Query: ("financial fraud" OR "corporate crime") AND "regulation"
# {'query': '("financial fraud" OR "corporate crime") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("natural disaster" OR "emergency response") AND "community"
# {'query': '("natural disaster" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "public health" AND NOT "education"
# {'query': '"public health" AND NOT "education"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "law enforcement") AND "urban areas"
# {'query': '("crime prevention" OR "law enforcement") AND "urban areas"', 'hits': [], 'total': 0}
#
# Query: "climate change" AND "environmental policy"
# {'query': '"climate change" AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: "school education" AND "safety protocols"
# {'query': '"school education" AND "safety protocols"', 'hits': [], 'total': 0}
#
# Query: ("healthcare reforms" OR "hospital management") AND "rural areas"
# {'query': '("healthcare reforms" OR "hospital management") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: "economic growth" AND NOT "corruption"
# {'query': '"economic growth" AND NOT "corruption"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency response") AND "community"
# {'query': '("disaster preparedness" OR "emergency response") AND "community"', 'hits': [], 'total': 0}
#
# Query: "corporate crime" AND "financial regulation"
# {'query': '"corporate crime" AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("budget allocation" OR "financial planning") AND "government policy"
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 2873, 'score': 1.0}, {'doc_id': 7372, 'score': 1.0}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 1.0}, {'doc_id': 7659, 'score': 1.0}, {'doc_id': 7684, 'score': 1.0}, {'doc_id': 8077, 'score': 1.0}, {'doc_id': 8103, 'score': 1.0}, {'doc_id': 9002, 'score': 1.0}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 1.0}, {'doc_id': 3530, 'score': 1.0}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 1.0}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 4448, 'score': 1.0}, {'doc_id': 7214, 'score': 1.0}, {'doc_id': 8398, 'score': 1.0}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 1.0}, {'doc_id': 7675, 'score': 1.0}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# {'query': '("corporate crime" OR "financial fraud") AND NOT "minor offenses"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government policy"
# {'query': '("environmental law" OR "pollution control") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency evacuation") AND "community safety"
# {'query': '("disaster preparedness" OR "emergency evacuation") AND "community safety"', 'hits': [], 'total': 0}
#
# Query: ("healthcare access" OR "hospital readiness") AND "rural areas"
# {'query': '("healthcare access" OR "hospital readiness") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget planning") AND "national development"
# {'query': '("economic policy" OR "budget planning") AND "national development"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# ...
# {'query': '("budget allocation" OR "financial planning") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "disease control") AND "healthcare system"
# {'query': '("pandemic response" OR "disease control") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: "teacher training" AND "education quality"
# {'query': '"teacher training" AND "education quality"', 'hits': [{'doc_id': 2873, 'score': 1.0}, {'doc_id': 7372, 'score': 1.0}], 'total': 2}
#
# Query: ("renewable energy" OR "carbon emission") AND "climate change"
# {'query': '("renewable energy" OR "carbon emission") AND "climate change"', 'hits': [{'doc_id': 3562, 'score': 1.0}, {'doc_id': 7659, 'score': 1.0}, {'doc_id': 7684, 'score': 1.0}, {'doc_id': 8077, 'score': 1.0}, {'doc_id': 8103, 'score': 1.0}, {'doc_id': 9002, 'score': 1.0}], 'total': 6}
#
# Query: ("school safety" OR "student wellbeing") AND "education policy"
# {'query': '("school safety" OR "student wellbeing") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("crime investigation" OR "law enforcement") AND "technology"
# {'query': '("crime investigation" OR "law enforcement") AND "technology"', 'hits': [{'doc_id': 1830, 'score': 1.0}, {'doc_id': 3530, 'score': 1.0}], 'total': 2}
#
# Query: ("pollution control" OR "waste management") AND "environmental policy"
# {'query': '("pollution control" OR "waste management") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("hospital readiness" OR "pandemic response") AND "healthcare system"
# {'query': '("hospital readiness" OR "pandemic response") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("economic growth" OR "business investment") AND "finance policy"
# {'query': '("economic growth" OR "business investment") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud detection") AND "regulation"
# {'query': '("corporate governance" OR "fraud detection") AND "regulation"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency services") AND "community safety"
# {'query': '("disaster relief" OR "emergency services") AND "community safety"', 'hits': [{'doc_id': 9592, 'score': 1.0}], 'total': 1}
#
# Query: ("urban crime" OR "rural crime") AND "prevention strategies"
# {'query': '("urban crime" OR "rural crime") AND "prevention strategies"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainability") AND "environmental policy"
# {'query': '("climate adaptation" OR "sustainability") AND "environmental policy"', 'hits': [], 'total': 0}
#
# Query: ("biodiversity protection" OR "conservation efforts") AND "policy"
# {'query': '("biodiversity protection" OR "conservation efforts") AND "policy"', 'hits': [{'doc_id': 4448, 'score': 1.0}, {'doc_id': 7214, 'score': 1.0}, {'doc_id': 8398, 'score': 1.0}], 'total': 3}
#
# Query: ("pandemic vaccination" OR "disease control") AND "public health"
# {'query': '("pandemic vaccination" OR "disease control") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("student performance" OR "curriculum development") AND "education quality"
# {'query': '("student performance" OR "curriculum development") AND "education quality"', 'hits': [{'doc_id': 7372, 'score': 1.0}, {'doc_id': 7675, 'score': 1.0}], 'total': 2}
#
# Query: ("teacher training" OR "school infrastructure") AND "education policy"
# {'query': '("teacher training" OR "school infrastructure") AND "education policy"', 'hits': [], 'total': 0}
#
# Query: ("financial auditing" OR "investment planning") AND "regulatory compliance"
# {'query': '("financial auditing" OR "investment planning") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("earthquake preparedness" OR "flood management") AND "emergency response"
# {'query': '("earthquake preparedness" OR "flood management") AND "emergency response"', 'hits': [], 'total': 0}
#
# Query: ("corporate crime" OR "financial fraud") AND NOT "minor offenses"
# {'query': '("corporate crime" OR "financial fraud") AND NOT "minor offenses"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government policy"
# {'query': '("environmental law" OR "pollution control") AND "government policy"', 'hits': [], 'total': 0}
#
# Query: ("disaster preparedness" OR "emergency evacuation") AND "community safety"
# {'query': '("disaster preparedness" OR "emergency evacuation") AND "community safety"', 'hits': [], 'total': 0}
#
# Query: ("healthcare access" OR "hospital readiness") AND "rural areas"
# {'query': '("healthcare access" OR "hospital readiness") AND "rural areas"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget planning") AND "national development"
# {'query': '("economic policy" OR "budget planning") AND "national development"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("crime prevention" OR "police monitoring") AND "urban safety"
# {'query': '("crime prevention" OR "police monitoring") AND "urban safety"', 'hits': [], 'total': 0}
#
# Query: ("pandemic response" OR "healthcare readiness") AND "public health"
# {'query': '("pandemic response" OR "healthcare readiness") AND "public health"', 'hits': [], 'total': 0}
#
# Query: ("school education" OR "student wellbeing") AND "policy reform"
# {'query': '("school education" OR "student wellbeing") AND "policy reform"', 'hits': [], 'total': 0}
#
# Query: ("corporate governance" OR "fraud investigation") AND "financial regulation"
# {'query': '("corporate governance" OR "fraud investigation") AND "financial regulation"', 'hits': [], 'total': 0}
#
# Query: ("emergency response" OR "disaster relief") AND "community planning"
# {'query': '("emergency response" OR "disaster relief") AND "community planning"', 'hits': [], 'total': 0}
#
# Query: ("environmental conservation" OR "biodiversity protection") AND "policy enforcement"
# {'query': '("environmental conservation" OR "biodiversity protection") AND "policy enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum assessment") AND "school performance"
# {'query': '("teacher training" OR "curriculum assessment") AND "school performance"', 'hits': [{'doc_id': 7260, 'score': 1.0}], 'total': 1}
#
# Query: ("economic growth" OR "investment strategy") AND "finance policy"
# {'query': '("economic growth" OR "investment strategy") AND "finance policy"', 'hits': [], 'total': 0}
#
# Query: ("climate adaptation" OR "sustainable development") AND "urban planning"
# {'query': '("climate adaptation" OR "sustainable development") AND "urban planning"', 'hits': [{'doc_id': 5013, 'score': 1.0}], 'total': 1}
#
# Query: ("crime trends" OR "law enforcement") AND "technology use"
# {'query': '("crime trends" OR "law enforcement") AND "technology use"', 'hits': [], 'total': 0}
#
# Query: ("pandemic prevention" OR "vaccine deployment") AND "healthcare system"
# {'query': '("pandemic prevention" OR "vaccine deployment") AND "healthcare system"', 'hits': [], 'total': 0}
#
# Query: ("flood management" OR "storm preparedness") AND "emergency services"
# {'query': '("flood management" OR "storm preparedness") AND "emergency services"', 'hits': [], 'total': 0}
#
# Query: ("student assessment" OR "school infrastructure") AND "education quality"
# {'query': '("student assessment" OR "school infrastructure") AND "education quality"', 'hits': [], 'total': 0}
#
# Query: ("corporate fraud" OR "financial misconduct") AND "regulatory compliance"
# {'query': '("corporate fraud" OR "financial misconduct") AND "regulatory compliance"', 'hits': [], 'total': 0}
#
# Query: ("disaster relief" OR "emergency management") AND "community response"
# {'query': '("disaster relief" OR "emergency management") AND "community response"', 'hits': [], 'total': 0}
#
# Query: ("environmental law" OR "pollution control") AND "government enforcement"
# {'query': '("environmental law" OR "pollution control") AND "government enforcement"', 'hits': [], 'total': 0}
#
# Query: ("teacher training" OR "curriculum development") AND "school quality"
# {'query': '("teacher training" OR "curriculum development") AND "school quality"', 'hits': [], 'total': 0}
#
# Query: ("economic policy" OR "budget allocation") AND "national planning"
# {'query': '("economic policy" OR "budget allocation") AND "national planning"', 'hits': [], 'total': 0}
#
# Query: ("climate change mitigation" OR "renewable energy") AND "policy enforcement"
# {'query': '("climate change mitigation" OR "renewable energy") AND "policy enforcement"', 'hits': [], 'total': 0}

# %%
#graph part b
import time
import numpy as np
import matplotlib.pyplot as plt

# ---------- Load queries ----------
with open("queries.txt", "r", encoding="utf8") as f:
    queries = [q.strip() for q in f.readlines() if q.strip()]

# ---------- Load two indices ----------
si_code = SelfIndex()
si_code.load_index("./selfindex_store/SelfIndex-v1.x1.y1.z1.i0.qT0")

si_clib = SelfIndex()
si_clib.load_index("./selfindex_store/SelfIndex-v1.x1.y2.z1.i0.qT0")

si_db3= SelfIndex()
si_db3.load_index("./selfindex_store/SelfIndex-v1.x1.y3.z1.i0.qT0")

# ---------- Measure response times ----------
def measure_latency(si, queries):
    times = []
    for q in queries:
        t0 = time.perf_counter()
        _ = si.query(q, k=5)
        t1 = time.perf_counter()
        times.append(t1 - t0)
    return np.array(times)

lat_code = measure_latency(si_code, queries)
lat_clib = measure_latency(si_clib, queries)
lat_db3 = measure_latency(si_db3, queries)

# ---------- Compute latency metrics ----------
p95_code, p99_code = np.percentile(lat_code, [95, 99])
p95_clib, p99_clib = np.percentile(lat_clib, [95, 99])
p95_db3, p99_db3 = np.percentile(lat_db3, [95, 99])


# ---------- Add Elasticsearch metrics (from measured data) ----------
p95_es = 0.0327585
p99_es = 0.0339084

# ---------- Plot A: Latency (p95, p99) ----------
plt.figure(figsize=(8,6))
labels = ['custom_p95','custom_p99','db1_p95','db1_p99','db2_p95','db2_p99','ES_p95','ES_p99']
values = [p95_code, p99_code, p95_clib, p99_clib, p95_db3, p99_db3, p95_es, p99_es]
plt.bar(labels, values, color=['skyblue','skyblue','orange','orange','red','red','lightgreen','lightgreen'])
plt.ylabel("Latency (seconds)")
plt.title("Plot.A: Response Time (p95, p99) Comparison")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# ---------- Print numeric summary ----------
print("\n=== Response Time (Latency) ===")
print(f"custom : p95={p95_code:.5f}s, p99={p99_code:.5f}s")
print(f"db1 : p95={p95_clib:.5f}s, p99={p99_clib:.5f}s")
print(f"db2 : p95={p95_db3:.5f}s, p99={p99_db3:.5f}s")
print(f"Elasticsearch : p95={p95_es:.5f}s, p99={p99_es:.5f}s")
# Out:
# [SelfIndex] Loaded index 'SelfIndex-v1.x1.y1.z1.i0.qT0' (N=10000, terms=134822)
# [SelfIndex] Loaded index 'SelfIndex-v1.x1.y2.z1.i0.qT0' (N=10000, terms=134822)
# [SelfIndex] Loaded index 'SelfIndex-v1.x1.y3.z1.i0.qT0' (N=10000, terms=7648)
# === Response Time (Latency) ===
# custom : p95=0.00133s, p99=0.00175s
# db1 : p95=0.00122s, p99=0.00150s
# db2 : p95=0.00015s, p99=0.00079s
# Elasticsearch : p95=0.03276s, p99=0.03391s
